# %% [markdown]
# enerate random parameters

# %%
#Install a conda package in the current Jupyter kernel
import sys
# !conda install --yes --prefix {sys.prefix} numpy
# !conda install --yes --prefix {sys.prefix} tensorflow
# !conda install --yes --prefix {sys.prefix} keras
# !conda install --yes --prefix {sys.prefix} pandas
# !conda install --yes --prefix {sys.prefix} scikit-learn 

from keras.wrappers.scikit_learn import KerasClassifier
from itertools import combinations
from math import sqrt, isnan
from scipy.io import arff	
from sklearn.metrics import f1_score as f1
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, matthews_corrcoef
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn import preprocessing
import numpy as np
import random
import pandas as pd
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.12.5  |       ha878542_0         137 KB  conda-forge
#     certifi-2020.12.5          |   py37h89c1867_1         143 KB  conda-forge
#     libblas-3.9.0              |       7_openblas          11 KB  conda-forge
#     libcblas-3.9.0             |       7_openblas          11 KB  conda-forge
#     libgcc-ng-9.3.0            |      h5dbcf3e_17         7.8 MB  conda-forge
#     libgfortran-ng-9.3.0       |      he4bcb1c_17          22 KB  conda-forge
#     libgfortran5-9.3.0         |      he4bcb1c_17         2.0 MB  conda-forge
#     libgomp-9.3.0              |      h5dbcf3e_17         378 KB  conda-forge
#     liblapack-3.9.0            |       7_openblas          11 KB  conda-forge
#     libopenblas-0.3.12         |pthreads_h4812303_1         8.9 MB  conda-forge
#     numpy-1.19.5               |   py37haa41c4c_1         5.3 MB  conda-forge
#     openssl-1.1.1i             |       h7f98852_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        26.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   libblas            conda-forge/linux-64::libblas-3.9.0-7_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-7_openblas
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-9.3.0-he4bcb1c_17
#   libgfortran5       conda-forge/linux-64::libgfortran5-9.3.0-he4bcb1c_17
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-7_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.12-pthreads_h4812303_1
#   numpy              conda-forge/linux-64::numpy-1.19.5-py37haa41c4c_1
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2020.6.20-hecda079_0 --> 2020.12.5-ha878542_0
#   certifi                          2020.6.20-py37hc8dfbb8_0 --> 2020.12.5-py37h89c1867_1
#   libgcc-ng                                9.2.0-h24d8f2e_2 --> 9.3.0-h5dbcf3e_17
#   libgomp                                  9.2.0-h24d8f2e_2 --> 9.3.0-h5dbcf3e_17
#   openssl                                 1.1.1g-h516909a_0 --> 1.1.1i-h7f98852_0
#
#
#
# Downloading and Extracting Packages
# libopenblas-0.3.12   | 8.9 MB    | ##################################### | 100%
# openssl-1.1.1i       | 2.1 MB    | ##################################### | 100%
# libgcc-ng-9.3.0      | 7.8 MB    | ##################################### | 100%
# numpy-1.19.5         | 5.3 MB    | ##################################### | 100%
# libgfortran5-9.3.0   | 2.0 MB    | ##################################### | 100%
# certifi-2020.12.5    | 143 KB    | ##################################### | 100%
# libblas-3.9.0        | 11 KB     | ##################################### | 100%
# libcblas-3.9.0       | 11 KB     | ##################################### | 100%
# ca-certificates-2020 | 137 KB    | ##################################### | 100%
# libgomp-9.3.0        | 378 KB    | ##################################### | 100%
# liblapack-3.9.0      | 11 KB     | ##################################### | 100%
# libgfortran-ng-9.3.0 | 22 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     absl-py-0.11.0             |   py37h89c1867_0         168 KB  conda-forge
#     astor-0.8.1                |     pyh9f0ad1d_0          25 KB  conda-forge
#     c-ares-1.17.1              |       h36c2ea0_0         111 KB  conda-forge
#     cached-property-1.5.1      |             py_0          10 KB  conda-forge
#     gast-0.4.0                 |     pyh9f0ad1d_0          12 KB  conda-forge
#     google-pasta-0.2.0         |     pyh8c360ce_0          42 KB  conda-forge
#     grpcio-1.33.2              |   py37haffed2e_2         1.8 MB  conda-forge
#     h5py-3.1.0                 |nompi_py37h1e651dc_100         1.2 MB  conda-forge
#     hdf5-1.10.6                |nompi_h7c3c948_1111         3.1 MB  conda-forge
#     keras-applications-1.0.8   |             py_1          30 KB  conda-forge
#     keras-preprocessing-1.1.0  |             py_0          33 KB  conda-forge
#     libgfortran-ng-7.5.0       |      hae1eefd_17          22 KB  conda-forge
#     libgfortran4-7.5.0         |      hae1eefd_17         1.3 MB  conda-forge
#     libopenblas-0.3.12         |pthreads_hb3c22a3_1         8.2 MB  conda-forge
#     libpng-1.6.37              |       h21135ba_2         306 KB  conda-forge
#     libprotobuf-3.13.0.1       |       h8b12597_0         2.3 MB  conda-forge
#     markdown-3.3.3             |     pyh9f0ad1d_0          66 KB  conda-forge
#     protobuf-3.13.0.1          |   py37he6710b0_1         634 KB  defaults
#     scipy-1.5.3                |   py37h8911b10_0        18.5 MB  conda-forge
#     tensorboard-1.14.0         |           py37_0         3.2 MB  conda-forge
#     tensorflow-1.14.0          |       h4531e10_0          23 KB  conda-forge
#     tensorflow-base-1.14.0     |   py37h4531e10_0        87.6 MB  conda-forge
#     tensorflow-estimator-1.14.0|   py37h5ca1d4c_0         645 KB  conda-forge
#     termcolor-1.1.0            |             py_2           6 KB  conda-forge
#     werkzeug-1.0.1             |     pyh9f0ad1d_0         239 KB  conda-forge
#     wrapt-1.12.1               |   py37h5e8e339_3          47 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       129.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   absl-py            conda-forge/linux-64::absl-py-0.11.0-py37h89c1867_0
#   astor              conda-forge/noarch::astor-0.8.1-pyh9f0ad1d_0
#   c-ares             conda-forge/linux-64::c-ares-1.17.1-h36c2ea0_0
#   cached-property    conda-forge/noarch::cached-property-1.5.1-py_0
#   gast               conda-forge/noarch::gast-0.4.0-pyh9f0ad1d_0
#   google-pasta       conda-forge/noarch::google-pasta-0.2.0-pyh8c360ce_0
#   grpcio             conda-forge/linux-64::grpcio-1.33.2-py37haffed2e_2
#   h5py               conda-forge/linux-64::h5py-3.1.0-nompi_py37h1e651dc_100
#   hdf5               conda-forge/linux-64::hdf5-1.10.6-nompi_h7c3c948_1111
#   keras-applications conda-forge/noarch::keras-applications-1.0.8-py_1
#   keras-preprocessi~ conda-forge/noarch::keras-preprocessing-1.1.0-py_0
#   libgfortran4       conda-forge/linux-64::libgfortran4-7.5.0-hae1eefd_17
#   libpng             conda-forge/linux-64::libpng-1.6.37-h21135ba_2
#   libprotobuf        conda-forge/linux-64::libprotobuf-3.13.0.1-h8b12597_0
#   markdown           conda-forge/noarch::markdown-3.3.3-pyh9f0ad1d_0
#   protobuf           pkgs/main/linux-64::protobuf-3.13.0.1-py37he6710b0_1
#   scipy              conda-forge/linux-64::scipy-1.5.3-py37h8911b10_0
#   tensorboard        conda-forge/linux-64::tensorboard-1.14.0-py37_0
#   tensorflow         conda-forge/linux-64::tensorflow-1.14.0-h4531e10_0
#   tensorflow-base    conda-forge/linux-64::tensorflow-base-1.14.0-py37h4531e10_0
#   tensorflow-estima~ conda-forge/linux-64::tensorflow-estimator-1.14.0-py37h5ca1d4c_0
#   termcolor          conda-forge/noarch::termcolor-1.1.0-py_2
#   werkzeug           conda-forge/noarch::werkzeug-1.0.1-pyh9f0ad1d_0
#   wrapt              conda-forge/linux-64::wrapt-1.12.1-py37h5e8e339_3
#
# The following packages will be REMOVED:
#
#   libgfortran5-9.3.0-he4bcb1c_17
#
# The following packages will be DOWNGRADED:
#
#   libgfortran-ng                          9.3.0-he4bcb1c_17 --> 7.5.0-hae1eefd_17
#   libopenblas                    0.3.12-pthreads_h4812303_1 --> 0.3.12-pthreads_hb3c22a3_1
#
#
#
# Downloading and Extracting Packages
# libgfortran-ng-7.5.0 | 22 KB     | ##################################### | 100%
# wrapt-1.12.1         | 47 KB     | ##################################### | 100%
# tensorflow-1.14.0    | 23 KB     | ##################################### | 100%
# absl-py-0.11.0       | 168 KB    | ##################################### | 100%
# astor-0.8.1          | 25 KB     | ##################################### | 100%
# libprotobuf-3.13.0.1 | 2.3 MB    | ##################################### | 100%
# libpng-1.6.37        | 306 KB    | ##################################### | 100%
# grpcio-1.33.2        | 1.8 MB    | ##################################### | 100%
# libgfortran4-7.5.0   | 1.3 MB    | ##################################### | 100%
# protobuf-3.13.0.1    | 634 KB    | ##################################### | 100%
# cached-property-1.5. | 10 KB     | ##################################### | 100%
# tensorflow-base-1.14 | 87.6 MB   | ##################################### | 100%
# werkzeug-1.0.1       | 239 KB    | ##################################### | 100%
# scipy-1.5.3          | 18.5 MB   | ##################################### | 100%
# keras-applications-1 | 30 KB     | ##################################### | 100%
# gast-0.4.0           | 12 KB     | ##################################### | 100%
# tensorboard-1.14.0   | 3.2 MB    | ##################################### | 100%
# libopenblas-0.3.12   | 8.2 MB    | ##################################### | 100%
# h5py-3.1.0           | 1.2 MB    | ##################################### | 100%
# keras-preprocessing- | 33 KB     | ##################################### | 100%
# tensorflow-estimator | 645 KB    | ##################################### | 100%
# c-ares-1.17.1        | 111 KB    | ##################################### | 100%
# google-pasta-0.2.0   | 42 KB     | ##################################### | 100%
# hdf5-1.10.6          | 3.1 MB    | ##################################### | 100%
# markdown-3.3.3       | 66 KB     | ##################################### | 100%
# termcolor-1.1.0      | 6 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - keras
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     binutils_impl_linux-64-2.31.1|       h6176602_1         3.9 MB  defaults
#     binutils_linux-64-2.31.1   |       h6176602_9          26 KB  defaults
#     gcc_impl_linux-64-7.3.0    |       habb00fd_1        41.9 MB  defaults
#     gcc_linux-64-7.3.0         |       h553295d_9          27 KB  defaults
#     gxx_impl_linux-64-7.3.0    |       hdf63c60_1        15.0 MB  defaults
#     gxx_linux-64-7.3.0         |       h553295d_9          26 KB  defaults
#     keras-2.3.1                |           py37_0         591 KB  conda-forge
#     libgpuarray-0.7.6          |    h14c3975_1003         263 KB  conda-forge
#     pygpu-0.7.6                |py37h902c9e0_1002         663 KB  conda-forge
#     pyyaml-5.3.1               |   py37h5e8e339_2         199 KB  conda-forge
#     theano-1.0.5               |   py37h745909e_1         3.7 MB  conda-forge
#     yaml-0.2.5                 |       h516909a_0          82 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        66.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   binutils_impl_lin~ pkgs/main/linux-64::binutils_impl_linux-64-2.31.1-h6176602_1
#   binutils_linux-64  pkgs/main/linux-64::binutils_linux-64-2.31.1-h6176602_9
#   gcc_impl_linux-64  pkgs/main/linux-64::gcc_impl_linux-64-7.3.0-habb00fd_1
#   gcc_linux-64       pkgs/main/linux-64::gcc_linux-64-7.3.0-h553295d_9
#   gxx_impl_linux-64  pkgs/main/linux-64::gxx_impl_linux-64-7.3.0-hdf63c60_1
#   gxx_linux-64       pkgs/main/linux-64::gxx_linux-64-7.3.0-h553295d_9
#   keras              conda-forge/linux-64::keras-2.3.1-py37_0
#   libgpuarray        conda-forge/linux-64::libgpuarray-0.7.6-h14c3975_1003
#   pygpu              conda-forge/linux-64::pygpu-0.7.6-py37h902c9e0_1002
#   pyyaml             conda-forge/linux-64::pyyaml-5.3.1-py37h5e8e339_2
#   theano             conda-forge/linux-64::theano-1.0.5-py37h745909e_1
#   yaml               conda-forge/linux-64::yaml-0.2.5-h516909a_0
#
#
#
# Downloading and Extracting Packages
# gxx_impl_linux-64-7. | 15.0 MB   | ##################################### | 100%
# theano-1.0.5         | 3.7 MB    | ##################################### | 100%
# binutils_impl_linux- | 3.9 MB    | ##################################### | 100%
# binutils_linux-64-2. | 26 KB     | ##################################### | 100%
# gcc_linux-64-7.3.0   | 27 KB     | ##################################### | 100%
# pygpu-0.7.6          | 663 KB    | ##################################### | 100%
# pyyaml-5.3.1         | 199 KB    | ##################################### | 100%
# libgpuarray-0.7.6    | 263 KB    | ##################################### | 100%
# yaml-0.2.5           | 82 KB     | ##################################### | 100%
# keras-2.3.1          | 591 KB    | ##################################### | 100%
# gcc_impl_linux-64-7. | 41.9 MB   | ##################################### | 100%
# gxx_linux-64-7.3.0   | 26 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pandas-1.1.4               |   py37h10a2094_0        10.5 MB  conda-forge
#     pytz-2020.5                |     pyhd8ed1ab_0         244 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        10.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas             conda-forge/linux-64::pandas-1.1.4-py37h10a2094_0
#   pytz               conda-forge/noarch::pytz-2020.5-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# pandas-1.1.4         | 10.5 MB   | ##################################### | 100%
# pytz-2020.5          | 244 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     joblib-1.0.0               |     pyhd8ed1ab_0         206 KB  conda-forge
#     scikit-learn-0.23.2        |   py37hddcf8d6_3         6.8 MB  conda-forge
#     threadpoolctl-2.1.0        |     pyh5ca1d4c_0          15 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         7.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   joblib             conda-forge/noarch::joblib-1.0.0-pyhd8ed1ab_0
#   scikit-learn       conda-forge/linux-64::scikit-learn-0.23.2-py37hddcf8d6_3
#   threadpoolctl      conda-forge/noarch::threadpoolctl-2.1.0-pyh5ca1d4c_0
#
#
#
# Downloading and Extracting Packages
# threadpoolctl-2.1.0  | 15 KB     | ##################################### | 100%
# joblib-1.0.0         | 206 KB    | ##################################### | 100%
# scikit-learn-0.23.2  | 6.8 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Using TensorFlow backend.
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def SVM_params():
    list_of_parameters= ["C", "kernel", "degree", "gamma","coef0","shrinking","probability","tol","cache_size","class_weight", "verbose","max_iter", "decision_function_shape",
                         "break_ties"]
    default_values=[1.0, "rbf", 3,"scale", 0.0, True, False, 0.001, 200, None, False, -1, 'ovr', False, None]
    return default_values

# %%
def SVM_paramsRandom():
    kernel = ['linear', 'poly', 'rbf', 'sigmoid']
    kernel_index = random.randint(0, len(kernel)-1)
    TF=[True, False]
    BN=["balanced", None]
    RN=[random.randint(0, 100), None]
    list_of_parameters= ["C", "kernel", "degree", "gamma","coef0","shrinking","probability","tol","cache_size","class_weight", "verbose","max_iter",
                         "decision_function_shape", "break_ties"]
    random_values=[random.uniform(0,100), kernel[kernel_index], random.randint(0,100), 0.001, random.uniform(0, 1),
                    TF[random.randint(0,len(TF)-1)], TF[random.randint(0,len(TF)-1)], 0.001, 200,
                    BN[random.randint(0,len(BN)-1)], TF[random.randint(0,len(TF)-1)], -1, 'ovr',
                   False,  RN[random.randint(0,len(RN)-1)]]
    return random_values
def KNN_params():
    list_of_parameters= ["n_neighbors", "weights", "algorithm", "leaf_size", "p", "metric", "metric_params", "n_jobs" ]
    default_values=[5, 'uniform', 'auto', 30, 2, 'minkowski', None, None]
    return default_values
def KNN_paramsRandom():
    weights=['uniform', "distance"]
    metric=['minkowski', 'euclidean', 'manhattan']
    list_of_parameters= ["n_neighbors", "weights", "algorithm", "leaf_size", "p", "metric", "metric_params", "n_jobs" ]
    random_values=[random.randint(1,10),weights[random.randint(0, len(weights)-1)], 'auto',
                   random.randint(30,100), random.randint(2,10), metric[random.randint(0, len(metric)-1)], None, None]
    return random_values
def LR_params():
    list_of_parameters= ["penalty","dual", "tol", "C", "fit_intercept","intercept_scaling", "class_weight", "random_state", "solver","max_iter",
                         "multi_class", "verbose", "warm_start", "n_jobs", "l1_ratio"]
    default_values=[ 'l2',False, 0.0001,1.0, True, 1, None, None, 'lbfgs', 100, 'auto', 0, False, None, None]
    return default_values
def LR_paramsRandom():
    penalty=['l1', 'l2', 'elasticnet', None]
    TF=[True, False]
    BN=["balanced", None]
    RN=[random.randint(0, 100), None]
    l1_ratio=[0,1, random.uniform(0,1),None]
    solver=['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
    s= solver[random.randint(0,len(solver)-1)]
    if(s=="lbgs" or s=='sag'):
        p='l2'
    else:
        p=penalty[random.randint(0,len(penalty)-1)]
    list_of_parameters= ["penalty","dual", "tol", "C", "fit_intercept","intercept_scaling", "class_weight",
                         "random_state", "solver","max_iter", "multi_class", "verbose", "warm_start", "n_jobs",
                         "l1_ratio"]
    random_values=[ p,TF[random.randint(0,len(TF)-1)], 0.0001,
                     random.uniform(0,100), True, random.uniform(0,100), BN[random.randint(0,len(BN)-1)],
                     RN[random.randint(0,len(RN)-1)], s, random.randint(50,200),
                     'ovr', random.randint(0,20), TF[random.randint(0,len(TF)-1)],
                     None, l1_ratio[random.randint(0,len(l1_ratio)-1)]]
    return random_values
def RF_params():
    list_of_parameters= ["n_estimators", "criterion", "max_depth", "min_samples_split", "min_samples_leaf", "min_weight_fraction_leaf", "max_features","max_leaf_nodes", "min_impurity_decrease",
                                          "min_impurity_split","bootstrap", "oob_score", "n_jobs", "random_state", "verbose", "warm_start","class_weight", "ccp_alpha", "max_samples"]
    default_values=[100,"gini",None, 2, 1, 0.0,"auto",None,0.0, None, True, False,None,None, 0, False,None,0.0,None ]
    return default_values
def RF_paramsRandom():
    criterion =["gini", "entropy"]
    max_features=['auto', 'sqrt', 'log2',None]
    BN= ['balanced', 'balanced_subsample', None]
    RN=[random.randint(0,100), None]
    TF=[True,False]
    list_of_parameters= ["n_estimators", "criterion", "max_depth", "min_samples_split", "min_samples_leaf",
                         "min_weight_fraction_leaf", "max_features","max_leaf_nodes", "min_impurity_decrease",
                         "min_impurity_split","bootstrap", "oob_score", "n_jobs", "random_state", "verbose",
                         "warm_start","class_weight", "ccp_alpha", "max_samples"]
    random_values=[random.randint(100,200),criterion[random.randint(0,len(criterion)-1)],None,
                   random.randint(2,10),random.randint(1,10),
                   0.0,max_features[random.randint(0,len(max_features)-1)],
                   None,0.0, None, TF[random.randint(0,len(TF)-1)], False,None,
                   RN[random.randint(0,len(RN)-1)],random.randint(0,100), False,
                   BN[random.randint(0,len(BN)-1)],0.0,None ]
    return random_values
def DT_params():
    list_of_parameters= ["criterion","splitter","max_depth","min_samples_split","min_samples_leaf","min_weight_fraction_leaf","max_features",
                         "random_state","max_leaf_nodes","min_impurity_decrease","class_weight","ccp_alpha" ]
    default_values=["gini","best",None, 2, 1, 0.0,None, None,None,0.0,None,None,0.0]
    return default_values
def DT_paramsRandom():
    criterion =["gini", "entropy"]
    BN= ['balanced', None]
    RN=[random.randint(0,100), None]
    list_of_parameters= ["criterion","splitter","max_depth","min_samples_split","min_samples_leaf","min_weight_fraction_leaf","max_features",
                         "random_state","max_leaf_nodes","min_impurity_decrease","class_weight","ccp_alpha" ]
    random_values=[criterion[random.randint(0,len(criterion)-1)],"best",None,
                   random.randint(2, 10), random.randint(1, 10),0.0,None, RN[random.randint(0,len(RN)-1)],None,0.0,None,
                   BN[random.randint(0,len(BN)-1)],0.0]
    return random_values
def ANN_params():
    return ""
def ANN_paramsRandom():
    return [random.randint(10,100)]
#these functions split the datasets into target and data and return the preprocessed form
def BugCatcherDatasetPreprocess():
    data = arff.loadarff('Bugcatchers-unified-file.arff')
    BugCatchers= pd.DataFrame(data[0])
    BugCatchers_data=BugCatchers.iloc[:, 0:6]
    BugCatchers_target = BugCatchers.iloc[:, 16]

    label_encoder = preprocessing.LabelEncoder()
    label_encoder.fit(BugCatchers_target)
    BugCatchers_target=label_encoder.transform(BugCatchers_target)
    BugCatchers_data_normalized = preprocessing.normalize(BugCatchers_data)
    BugCatchers_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(BugCatchers_data)
    BugCatchers_data_standardized= preprocessing.StandardScaler().fit_transform(BugCatchers_data)
    print( "Bug Catchers dataset is preprocessed \n")
    return BugCatchers_target,BugCatchers_data_normalized,BugCatchers_data_minmax_scalled,BugCatchers_data_standardized
def PromiseDatasetPreprocess():
    data = arff.loadarff('PROMISE-unified-class.arff')
    PROMISE = pd.DataFrame(data[0])
    PROMISE_data = PROMISE.iloc[:, 0:60]
    PROMISE_target = PROMISE.iloc[:, 80]

    label_encoder = preprocessing.LabelEncoder()
    label_encoder.fit(PROMISE_target)
    PROMISE_target=label_encoder.transform(PROMISE_target)
    PROMISE_data_normalized = preprocessing.normalize(PROMISE_data)
    PROMISE_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(PROMISE_data)
    PROMISE_data_standardized= preprocessing.StandardScaler().fit_transform(PROMISE_data)
    print("PROMISE dataset is preprocessed \n")
    return PROMISE_target,PROMISE_data_normalized,PROMISE_data_minmax_scalled,PROMISE_data_standardized
def EclipseDatasetPreprocess():
    data = arff.loadarff('Zimmerman-unified-file.arff')
    Eclipse= pd.DataFrame(data[0])
    Eclipse_data=Eclipse.iloc[:, 0:6]
    Eclipse_target = Eclipse.iloc[:, 204]

    label_encoder = preprocessing.LabelEncoder()
    label_encoder.fit(Eclipse_target)
    Eclipse_target=label_encoder.transform(Eclipse_target)
    Eclipse_data_normalized = preprocessing.normalize(Eclipse_data)
    Eclipse_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(Eclipse_data)
    Eclipse_data_standardized= preprocessing.StandardScaler().fit_transform(Eclipse_data)
    print("Eclipse dataset is preprocessed \n")
    return Eclipse_target, Eclipse_data_normalized,Eclipse_data_minmax_scalled,Eclipse_data_standardized
def BugPredictionDatasetPreprocess():
    data = arff.loadarff('BugPrediction-unified-class.arff')
    BugPrediction= pd.DataFrame(data[0])
    BugPrediction_data=BugPrediction.iloc[:, 0:60]
    BugPrediction_target = BugPrediction.iloc[:, 97]

    label_encoder = preprocessing.LabelEncoder()
    label_encoder.fit(BugPrediction_target)
    BugPrediction_target=label_encoder.transform(BugPrediction_target)
    BugPrediction_data_normalized = preprocessing.normalize(BugPrediction_data)
    BugPrediction_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(BugPrediction_data)
    BugPrediction_data_standardized= preprocessing.StandardScaler().fit_transform(BugPrediction_data)
    print( "Bug Prediction dataset is preprocessed \n")
    return BugPrediction_target,BugPrediction_data_normalized,BugPrediction_data_minmax_scalled,BugPrediction_data_standardized
def GitHubFileDatasetPreprocess():
    data = arff.loadarff('GitHub-unified-file.arff')
    GitHub_File= pd.DataFrame(data[0])
    GitHub_File_data=GitHub_File.iloc[:, 0:6]
    GitHub_File_target = GitHub_File.iloc[:, 10]

    label_encoder = preprocessing.LabelEncoder()
    label_encoder.fit(GitHub_File_target)
    GitHub_File_target=label_encoder.transform(GitHub_File_target)
    GitHub_File_data_normalized = preprocessing.normalize(GitHub_File_data)
    GitHub_File_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(GitHub_File_data)
    GitHub_File_data_standardized= preprocessing.StandardScaler().fit_transform(GitHub_File_data)
    print( "GitHub File dataset is preprocessed \n")
    return GitHub_File_target,GitHub_File_data_normalized,GitHub_File_data_minmax_scalled,GitHub_File_data_standardized
def GitHubClassDatasetPreprocess():
    data = arff.loadarff('GitHub-unified-class.arff')
    GitHub_class= np.array(dataset['data'])
    GitHub_class_data=GitHub_class.iloc[:, 0:60]
    GitHub_class_target = GitHub_class.iloc[:, 60]
    GitHub_class_data=data

    label_encoder = preprocessing.LabelEncoder()
    label_encoder.fit(GitHub_class_target)
    GitHub_class_target=label_encoder.transform(GitHub_class_target)
    GitHub_class_data_normalized = preprocessing.normalize(GitHub_class_data)
    GitHub_class_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(GitHub_class_data)
    GitHub_class_data_standardized= preprocessing.StandardScaler().fit_transform(GitHub_class_data)
    print( "GitHub Class dataset is preprocessed \n")
    return GitHub_class_target,GitHub_class_data_normalized,GitHub_class_data_minmax_scalled,GitHub_class_data_standardized

# %%
BugPrediction_target,BugPrediction_data_normalized,BugPrediction_data_minmax_scalled,BugPrediction_data_standardized=BugPredictionDatasetPreprocess()
PROMISE_target,PROMISE_data_normalized,PROMISE_data_minmax_scalled,PROMISE_data_standardized=PromiseDatasetPreprocess()
# Out:
# Bug Prediction dataset is preprocessed
#
# PROMISE dataset is preprocessed

# %%
X=PROMISE_data_normalized
y=PROMISE_target
def balanced_subsample(X,y,  min_elems = 5000):
    #return a balnced subsample of min_elems of each class
    x=[]
    y_s=[]
    for yi in np.unique(y):
        elems = X[(y == yi)]
        np.random.shuffle(elems)
        for e in elems[0:min_elems,:]:
            xx=[]
            for c in e:
                xx.append(c)
            x.append(xx)
        for e in range(0,min_elems):
            y_s.append(0 if yi == 0 else 1)
    return x,y_s

# %%
def generateInitialPopulation(SVM=1, KNN=1, DT=1, RF=1, LR=1, ANN=1):
    included_clf=["SVM", "KNN", "DT", "RF", "LR", "ANN"]
    included=[1,1,1,1,1,1]
    if(SVM==0):
        included[0]=0
    if (KNN == 0):
        included[1] = 0
    if (DT == 0):
        included[2] = 0
    if (RF == 0):
        included[3] = 0
    if (LR == 0):
        included[4] = 0
    if (ANN == 0):
        included[5] = 0
    in_use=[]
    combinations_of_clf=[]
    for i in range(6):
        if(included[i]==1):
            in_use.append(included_clf[i])
    #generate diffrent combinations
    for i in range(len(in_use)+1):
        comb= combinations(in_use,i)
        for j in list(comb):
            element=[]
            for k in range(len(j)):
                element.append(j[k])
            if element!=[]:
                combinations_of_clf.append( element)
    population = []
    # generate random paramters for all diffrent combinations
    for combination in list(combinations_of_clf):
        chromosome = {}
        for clf in list(combination):
            genes=[]
            if(clf=="SVM"):
                genes= SVM_paramsRandom()
                chromosome["SVM"]=genes
            if (clf == "LR"):
                genes = LR_paramsRandom()
                chromosome["LR"]=genes
            if (clf == "KNN"):
                genes = KNN_paramsRandom()
                chromosome["KNN"]=genes
            if (clf == "RF"):
                genes = RF_paramsRandom()
                chromosome["RF"]=genes
            if (clf == "DT"):
                genes = DT_paramsRandom()
                chromosome["DT"]=genes
            if (clf == "ANN"):
                genes = ANN_paramsRandom()
                chromosome["ANN"]=genes
        if population != None:
            population.append(chromosome)
        else:
            population=chromosome
        #combine into one population and return
    return population

# %%
def crossover(parent1, parent2):
    #Generate random indices
    index1 = random.randint(0, len(parent1) - 1)
    index2 = random.randint(0, len(parent2) - 1)
    offspring1={}
    #create offspring from 0 to index1 of parent 1 and index2 till the end of parent 2
    for i in range(0,index1):
        key = list(parent1)[i]
        if (offspring1 != {}):
            count = 0
            keytoadd =key.split('-')[0]
            while keytoadd in offspring1.keys():
                count+=1
                keytoadd = key.split('-')[0] + "-" + str(count)
            offspring1[keytoadd] = parent1[key]
        else:
            offspring1[key] = parent1[key]
    for j in range(index2,len(parent2)):
        key = list(parent2)[j]
        if (offspring1 != {}):
            count = 0
            keytoadd =key.split('-')[0]
            while keytoadd in offspring1.keys():
                count+=1
                keytoadd = key.split('-')[0] + "-" + str(count)
            offspring1[keytoadd] = parent2[key]
        else:
            offspring1[key] = parent2[key]

    #create offspring from 0 to index2 of parent 2 and index1 till the end of parent 1
    offspring2={}
    for i in range(0,index2):
        key = list(parent2)[i]
        if(offspring2!={}):
            count = 0
            keytoadd =key.split('-')[0]
            while keytoadd in offspring2.keys():
                count+=1
                keytoadd=key.split('-')[0]+"-"+str(count)
            offspring2[keytoadd] = parent2[key]
        else:
             offspring2[key]=parent2[key]
    for j in range(index1,len(parent1)):
        key = list(parent1)[j]
        if (offspring2 != {}):
            count = 0
            keytoadd =key.split('-')[0]
            while keytoadd in offspring2.keys():
                count+=1
                keytoadd = key.split('-')[0] + "-" + str(count)
            offspring2[keytoadd] = parent1[key]
        else:
            offspring2[key] = parent1[key]
    print("offspring1",offspring1)
    print("offspring2",offspring2)
    return offspring1, offspring2

# %%
def ANN_model(num=50):
    from keras.models import Sequential
    from keras.layers import Dense
    #create an ANN
    model =Sequential()
    model.add(Dense(num, activation='relu', input_shape=[60]))
    model.add(Dense(int(num/2),activation='relu'))
    model.add(Dense(2, activation='sigmoid'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics= ['accuracy'])
    return model

# %%
def fitness(chromosome,X_train,y_train,X_test,y_test,alpha=1, beta=0,gamma=0, ensemble="vote" ,count=0,gen=0):
    fitness=0
    clfs={}
    for gene in chromosome:
        # Check the gene classifier and creates a model from the paramters
        params = chromosome[gene]
        gene1=gene
        if(len(gene.split('-'))>1):
            genecount=gene.split('-')[1]
            print(genecount)
        else:
            genecount=None
        gene=gene.split('-')[0]
        clf1=gene
        if(genecount==None or genecount!='0'):
            if gene=="SVM":
                clf1=SVC(C=params[0], kernel=params[1], degree=params[2], gamma=params[3],
                        coef0=params[4], shrinking=params[5], probability=True,
                        tol=params[7], cache_size=params[8], class_weight=params[9], verbose=params[10], max_iter=params[11],
                        decision_function_shape=params[12])
            if gene=="KNN":
                clf1=KNeighborsClassifier(n_neighbors=params[0], weights=params[1], algorithm=params[2],
                                         leaf_size=params[3], p=params[4], metric=params[5],
                                         metric_params=params[6], n_jobs=1)
            if gene=="DT":
                clf1=DecisionTreeClassifier(criterion=params[0], splitter=params[1], max_depth=params[2],
                                            min_samples_split=params[3], min_samples_leaf=params[4],
                                            min_weight_fraction_leaf=params[5], max_features=params[6],
                                            random_state=params[7], max_leaf_nodes=params[8], min_impurity_decrease=params[9],
                                            min_impurity_split=params[10], class_weight=params[11])
            if gene == "RF":
                clf1 = RandomForestClassifier(n_estimators=params[0], criterion=params[1], max_depth=params[2],
                                              min_samples_split=params[3], min_samples_leaf=params[4],
                                              min_weight_fraction_leaf=params[5], max_features=params[6],
                                              max_leaf_nodes=params[7], min_impurity_decrease=params[8],
                                              min_impurity_split=params[9],
                                              bootstrap=params[10], oob_score=params[11], n_jobs=1,
                                              random_state=params[13], verbose=params[14], warm_start=params[15],
                                              class_weight=params[16])
            if gene=="LR":
                clf1=LogisticRegression(penalty='l2',dual=False, tol=params[2], C=params[3], fit_intercept=params[4],
                                       intercept_scaling=params[5], class_weight=params[6], random_state=params[7], solver=params[8],
                                       max_iter=params[9], multi_class=params[10], verbose=params[11], warm_start=params[12], n_jobs=1,
                                      )
            if gene=="ANN":
                clf1 =KerasClassifier(build_fn=ANN_model,num=params[0], epochs=500, verbose=False)
                clf1._estimator_type = "classifier"
            clfs[gene1]=clf1
    estimators=[]
    for clf in clfs:
        print(clf)
        estimators.append((clf,clfs[clf]))
    if(len(estimators)>0):
        eclf = VotingClassifier(estimators, voting='hard',flatten_transform=True)
        eclf.fit(X_train,y_train)
        y_pred=eclf.predict(X_test)

        #Get confusion matrix and calculate the ACC, MCC AND F1
        cm=confusion_matrix(y_test, y_pred)
        TN, FP, FN, TP = cm.ravel()
        print( cm)
        accuracy= (TP + TN)/(TP + TN + FP + FN)
        print("accuracy:",accuracy)
        mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
        print("mcc:",mcc)
        precision =(TP/(TP+FP))
        recall= (TP/(TP+FN))
        f1_score= 2 *(precision*recall)/(precision+recall)
        print("f1_score:",f1_score)
        if isnan(accuracy) or isnan(f1_score):
            accuracy=0
        if isnan(mcc):
            mcc=0
        if isnan(f1_score):
            f1_score=0
        fitness=(((alpha*accuracy)+ (beta*mcc)+(gamma*f1_score)))
        print("Fitness:",fitness)
        return fitness, {"mcc":[mcc],"acc":[accuracy],"f1":[f1_score],"cm":[cm]},eclf
    else:
        return 0,{},None

# %%
def rename(old_dict,old_name,new_name):
    new_dict = {}
    for key,value in zip(old_dict.keys(),old_dict.values()):
        new_key = key if key != old_name else new_name
        new_dict[new_key] = old_dict[key]
    return new_dict

# %%
def Mutation(chromosome,X_train,y_train,X_val,y_val):
    #Generate random index and set to 0 or 1 accordingly
    threshold = random.uniform(0, 1)
    index= random.randint(0,len(chromosome)-1)
    if(threshold<=0.5):
        if len(list(chromosome)[index].split('-'))==1:
            print("set to 0")
            chromosome= rename(chromosome,list(chromosome)[index], list(chromosome)[index]+"-0")
        elif(( len(list(chromosome)[index].split('-'))>1 and list(chromosome)[index].split('-')[1]=='0') or (len(list(chromosome)[index].split('-'))>2 and (list(chromosome)[index].split('-'))[2]=='0') ):
            print("set to 1")
            count = 0
            key=list(chromosome)[index].split('-')[0]
            keytoadd = key
            while keytoadd in chromosome.keys():
                count+=1
                keytoadd = key + "-" + str(count)
            chromosome =rename(chromosome,list(chromosome)[index], keytoadd)
        else:
            print("set to 0")
            chromosome = rename(chromosome, list(chromosome)[index], list(chromosome)[index] + "-0")
    else:
        print(index)
        gene = list(chromosome)[index]
        print(gene)
        clf1 = gene
        options = []
        gene1 = list(chromosome)[index]
        gene=list(chromosome)[index].split('-')[0]
        if gene == "SVM" or gene == "KNN" or gene == "DT" or gene == "RF" or gene == "LR" or gene == "ANN":
            if gene == "SVM" or gene == "SVM-0":
                clf1 = SVC()
                c = list(range(1, 1000))
                c.append(0.01)
                c.append(0.1)
                params = {'C': c, 'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
                          "degree": list(range(0, 100)), 'gamma': [1e-3, 1e-4],
                          "coef0": [x * 0.1 for x in range(0, 10)],
                          'class_weight': [{0: 0.01}, {1: 1}, {1: 2}, {1: 10}, {1: 50}, 'balanced']}
            if gene == "KNN" or gene == "KNN-0":
                clf1 = KNeighborsClassifier()
                params = {"n_neighbors": list(range(1, 50)), "weights": ['uniform', "distance"],
                          "leaf_size": list(range(1, 100)), "p": [1, 2],
                          "metric": ['minkowski', 'euclidean', 'manhattan']}
            if gene == "DT" or gene == "DT-0":
                clf1 = DecisionTreeClassifier()
                BN = ['balanced', None]
                RN = [random.randint(0, 100), None]
                max_features = ['auto', 'sqrt']
                max_depth = [int(x) for x in np.linspace(10, 110, num=11)]
                max_depth.append(None)
                min_samples_split = list(range(2, 10))
                min_samples_leaf = list(range(1, 6))
                params = {"criterion": ["gini", "entropy"],
                          'max_features': max_features,
                          'max_depth': max_depth,
                          'min_samples_split': min_samples_split,
                          'min_samples_leaf': min_samples_leaf,
                          }
            if gene == "RF" or gene == "RF-0":
                clf1 = RandomForestClassifier()
                n_estimators = [int(x) for x in np.linspace(start=200, stop=2000, num=10)]
                max_features = ['auto', 'sqrt']
                max_depth = [int(x) for x in np.linspace(10, 110, num=11)]
                max_depth.append(None)
                min_samples_split = list(range(2, 10))
                min_samples_leaf = list(range(1, 4))
                bootstrap = [True, False]
                params = {"criterion": ["gini", "entropy"],
                          'n_estimators': n_estimators,
                          'max_features': max_features,
                          'max_depth': max_depth,
                          'min_samples_split': min_samples_split,
                          'min_samples_leaf': min_samples_leaf,
                          'bootstrap': bootstrap}
            if gene == "LR" or gene == "LR-0":
                clf1 = LogisticRegression()
                c = list(range(1, 1000))
                c.append(0.1)
                c.append(0.001)
                params = {'solver': ['newton-cg', 'lbfgs', 'liblinear'],
                          'penalty': ['l2'],
                          'C': c}
            if gene == "ANN" or gene == "ANN-0":
                params = {"num": list(range(2, 100)), "epochs": list(range(400, 600))}
                clf1 = KerasClassifier(build_fn=ANN_model, epochs=500, verbose=False)
                clf1._estimator_type = "classifier"
            print(clf1)
            randomclf = RandomizedSearchCV(estimator=clf1, param_distributions=params,
                                           n_iter=len(params), cv=5, verbose=2, random_state=42,
                                           n_jobs=1)
            search = randomclf.fit(X_train, y_train)
            param = search.cv_results_
            options = param['params']
        if gene1 == "SVM-0" or gene1 == "KNN-0" or gene1 == "DT-0" or gene1 == "RF-0" or gene1 == "LR-0" or gene1 == "ANN-0":
            options.append(None)
        clfs = {}
        eclfs = {}
        ocount = 0
        fop = {}
        ecount = 0
        # for all other calssifers get the parameters from the chromosomes and generate a new model
        for option in options:
            op = {}
            count = 0
            for gene in chromosome:
                op1 = {}
                params = chromosome[gene]
                clf1 = gene
                if count == index:
                    if option == None:
                        clf1 = None
                    if option != None:
                        if gene == "SVM" or gene == "SVM-0":
                            clf1 = SVC(C=option["C"], kernel=option["kernel"], degree=option["degree"],
                                       gamma=option["gamma"],
                                       coef0=option["coef0"], shrinking=params[5], probability=True,
                                       tol=params[7], cache_size=params[8], class_weight=option["class_weight"],
                                       verbose=params[10],
                                       max_iter=params[11],
                                       decision_function_shape=params[12])
                            # clf1 = SVC(C=option["C"], kernel=option["kernel"], gamma=option["gamma"],
                            # class_weight=option["class_weight"])
                            op1["SVM"] = [option["C"], option["kernel"], option["degree"], option["gamma"],
                                          option["coef0"], params[5], True,
                                          params[7], params[8], option["class_weight"], params[10], params[11],
                                          params[12]]
                        if gene == "KNN" or gene == "KNN-0":
                            clf1 = KNeighborsClassifier(n_neighbors=option["n_neighbors"], weights=option["weights"],
                                                        algorithm=params[2],
                                                        leaf_size=option["leaf_size"], p=option["p"],
                                                        metric=option["metric"],
                                                        metric_params=params[6], n_jobs=1)
                            op1["KNN"] = [option["n_neighbors"], option["weights"], params[2], option["leaf_size"],
                                          option["p"], option["metric"],
                                          params[6], 1]
                            # clf1 = KNeighborsClassifier(n_neighbors=option["n_neighbors"],
                            # leaf_size=option["leaf_size"], p=option["p"])
                            # op1["KNN"]=[option["n_neighbors"],option["leaf_size"],option["p"]]
                        if gene == "DT" or gene == "DT-0":
                            clf1 = DecisionTreeClassifier(criterion=option["criterion"], splitter=params[1],
                                                          max_depth=option["max_depth"],
                                                          min_samples_split=option["min_samples_split"],
                                                          min_samples_leaf=option["min_samples_leaf"],
                                                          min_weight_fraction_leaf=params[5],
                                                          max_features=option["max_features"],
                                                          random_state=params[7], max_leaf_nodes=params[8],
                                                          min_impurity_decrease=params[9],
                                                          min_impurity_split=params[10], class_weight=params[11])
                            op1["DT"] = [option["criterion"], params[1], option["max_depth"],
                                         option["min_samples_split"], option["min_samples_leaf"], params[5],
                                         option["max_features"],
                                         params[7], params[8], params[9], params[10], params[11]]
                            # clf1 = DecisionTreeClassifier(max_depth=option["max_depth"],
                            #                               min_samples_split=option["min_samples_split"], min_samples_leaf=option["min_samples_leaf"],
                            #                               max_features=option["max_features"])
                            # op1["DT"]=[option["max_depth"],option["min_samples_split"], option["min_samples_leaf"],option["max_features"]]
                        if gene == "RF" or gene == " RF-0":
                            clf1 = RandomForestClassifier(n_estimators=option["n_estimators"],
                                                          criterion=option["criterion"], max_depth=option["max_depth"],
                                                          min_samples_split=option["min_samples_split"],
                                                          min_samples_leaf=option["min_samples_leaf"],
                                                          min_weight_fraction_leaf=params[5], max_features=params[6],
                                                          max_leaf_nodes=params[7], min_impurity_decrease=params[8],
                                                          min_impurity_split=params[9],
                                                          bootstrap=option["bootstrap"], oob_score=params[11], n_jobs=1,
                                                          random_state=params[13], verbose=params[14],
                                                          warm_start=params[15],
                                                          class_weight=params[16])
                            op1["RF"] = [option["n_estimators"], option["criterion"], option["max_depth"],
                                         option["min_samples_split"], option["min_samples_leaf"],
                                         params[5], option["max_features"],
                                         params[7], params[8], params[9], option["bootstrap"], params[11], 1,
                                         params[13], params[14],
                                         params[15], params[16]]
                            # clf1 = RandomForestClassifier(n_estimators=option["n_estimators"], max_depth=option["max_depth"],
                            #                               min_samples_split=option["min_samples_split"], min_samples_leaf=option["min_samples_leaf"],
                            #                               max_features=option["max_features"],
                            #                               bootstrap=option["bootstrap"])
                            # op1["RF"]=[option["n_estimators"],option["max_depth"],option["min_samples_split"], option["min_samples_leaf"],
                            #            option["max_features"],option["bootstrap"]]
                        if gene == "LR" or gene == " LR-0":
                            clf1 = LogisticRegression(penalty='l2', dual=False, tol=params[2], C=option["C"],
                                                      fit_intercept=params[4],
                                                      intercept_scaling=params[5], class_weight=params[6],
                                                      random_state=params[7],
                                                      solver=option["solver"],
                                                      max_iter=params[9], multi_class=params[10], verbose=params[11],
                                                      warm_start=params[12], n_jobs=1,
                                                      )
                            op1["LR"] = ["l2", False, params[2], option["C"], params[4], params[5], params[6],
                                         params[7], option["solver"], params[9], params[10], params[11], params[12],
                                         1, ]
                            # clf1 = LogisticRegression(penalty='l2', C=option["C"],solver=option["solver"])
                            # op1["LR"]=["l2",option["C"],option["solver"]]
                        if gene == "ANN" or gene == "ANN -0":
                            clf1 = KerasClassifier(build_fn=ANN_model, num=option["num"],
                                                                                  epochs=500,
                                                                                  verbose=False)
                            clf1._estimator_type = "classifier"
                            op1["ANN"] = [option["num"]]
                else:
                    if gene == "SVM":
                        clf1 = SVC(C=params[0], kernel=params[1], degree=params[2], gamma=params[3],
                                   coef0=params[4], shrinking=params[5], probability=True,
                                   tol=params[7], cache_size=params[8], class_weight=params[9], verbose=params[10],
                                   max_iter=params[11],
                                   decision_function_shape=params[12])
                        op1["SVM"] = [params[0], params[1], params[2], params[3], params[4], params[5], True,
                                      params[7], params[8], params[9], params[10], params[11],
                                      params[12]]
                    if gene == "KNN":
                        clf1 = KNeighborsClassifier(n_neighbors=params[0], weights=params[1], algorithm=params[2],
                                                    leaf_size=params[3], p=params[4], metric=params[5],
                                                    metric_params=params[6], n_jobs=1)
                        op1["KNN"] = [params[0], params[1], params[2], params[3], params[4], params[5],
                                      params[6], 1]
                    if gene == "DT":
                        clf1 = DecisionTreeClassifier(criterion=params[0], splitter=params[1], max_depth=params[2],
                                                      min_samples_split=params[3], min_samples_leaf=params[4],
                                                      min_weight_fraction_leaf=params[5], max_features=params[6],
                                                      random_state=params[7], max_leaf_nodes=params[8],
                                                      min_impurity_decrease=params[9],
                                                      min_impurity_split=params[10], class_weight=params[11])
                        op1["DT"] = [params[0], params[1], params[2], params[3], params[4], params[5], params[6],
                                     params[7], params[8], params[9], params[10], params[11]]
                    if gene == "RF":
                        clf1 = RandomForestClassifier(n_estimators=params[0], criterion=params[1], max_depth=params[2],
                                                      min_samples_split=params[3], min_samples_leaf=params[4],
                                                      min_weight_fraction_leaf=params[5], max_features=params[6],
                                                      max_leaf_nodes=params[7], min_impurity_decrease=params[8],
                                                      min_impurity_split=params[9],
                                                      bootstrap=params[10], oob_score=params[11], n_jobs=1,
                                                      random_state=params[13], verbose=params[14],
                                                      warm_start=params[15],
                                                      class_weight=params[16])
                        op1["RF"] = [params[0], params[1], params[2], params[3], params[4], params[5], params[6],
                                     params[7], params[8], params[9], params[10], params[11], 1, params[13], params[14],
                                     params[15], params[16]]
                    if gene == "LR":
                        clf1 = LogisticRegression(penalty='l2', dual=False, tol=params[2], C=params[3],
                                                  fit_intercept=params[4],
                                                  intercept_scaling=params[5], class_weight=params[6],
                                                  random_state=params[7],
                                                  solver=params[8],
                                                  max_iter=params[9], multi_class=params[10], verbose=params[11],
                                                  warm_start=params[12], n_jobs=1,
                                                  )
                        op1["LR"] = ["l2", False, params[2], params[3], params[4], params[5], params[6],
                                     params[7], params[8], params[9], params[10], params[11], params[12], 1, ]
                    if gene == "ANN":
                        clf1 = KerasClassifier(build_fn=ANN_model, num=params[0],
                                                                              epochs=500,
                                                                              verbose=False)
                        clf1._estimator_type = "classifier"
                        op1["ANN"] = [params[0]]
                op[str(count)] = op1
                count = count + 1
                clfs[gene] = clf1
            fop[str(ocount)] = op
            ocount = ocount + 1
            estimators=[]
            for clf in clfs:
              print(clf)
              estimators.append((clf,clfs[clf]))
            if(len(estimators)>0):
              eclf = VotingClassifier(estimators, voting='hard',flatten_transform=True)
              eclfs[str(ecount)] = eclf
              ecount = ecount + 1
        print(fop)
        print(eclfs)

        # set all the ensembles model in a pipeline to be able to select the best out of them using gridsearch
        pipe = Pipeline([("classifier", VotingClassifier(estimators=KNeighborsClassifier()))])
        search_space = []
        for ens in eclfs:
            search_space.append({"classifier": [eclfs[ens]]})
        print(search_space)
        gridsearch = GridSearchCV(pipe, search_space, cv=5, verbose=5, n_jobs=1)
        best_model = gridsearch.fit(X_val, y_val)
        best = best_model.best_params_
        print(best)
        c = 0
        for ss in eclfs:
            print({'classifier': eclfs[ss]} == best)
            if ({'classifier': eclfs[ss]} == best):
                chromosomes = fop[str(c)]
                if c == len(eclfs):
                    index -= 1
            c = c + 1
        print(chromosomes)

        # return the best ensemble in the right chromosome form
        chromosome1 = chromosomes
        chromosome2 = {}
        for key in chromosome1:
            ch = chromosome1[key]
            for k in ch:
                chromosome2[k] = ch[k]
        chromosome = chromosome2
    print(chromosome)
    return chromosome

# %%
def roulette2(poplulation, n, fit_array):
    fit={}
    fitness = fit_array
    for chromosome, i in zip(poplulation, range(0, len(poplulation))):
        fit[str(chromosome)] = fit_array[i]
    #calculate total fitness
    total_fitness = float(sum(fit[str(chromosome)] for chromosome in poplulation))
    parents=[]
    weights=[]
    #generate probability of Fi/sum of weights
    for  i in range(0, len(fitness)):
        weights.append(fitness[i] / total_fitness)

    #genrate a random number and return when the chromosome at that weight is reached
    while n:
        r = np.random.rand()
        acc = 0
        idx = -1
        while acc < r:
            idx += 1
            acc += weights[idx]
        parents.append(poplulation[idx])
        n-=1
    return parents

# %%
def generateNewPopulation(population,all_fitness, X_train,y_train,X_val,y_val,crossover_prob=0.8, mutation_prob=0.1,elitism_range=0.2):
    new_population=[]
    elitism_fitness= all_fitness.copy()
    elitism_population= population.copy()
    #copy chromosomes in range of elitism rate and check for repetition
    for i in range(0, int(elitism_range*len(population))):
        max_index=elitism_fitness.index(max(elitism_fitness))
        if(elitism_population[max_index] in new_population):
            elitism_fitness.pop(max_index)
            elitism_population.pop(max_index)
        else:
            new_population.append(elitism_population[max_index])
            elitism_fitness.pop(max_index)
            elitism_population.pop(max_index)
    print("new_population",new_population)

    #while the length of the new population still has not reach 63 select mutate and crossover chromomsmes
    while(len(new_population)<len(population)):
        count = 0
        parents = roulette2(population,2,all_fitness)
        if np.random.random() < crossover_prob and len(new_population)<len(population)-1:
            print("crossover",parents[count])
            print("and",parents[count+1] )
            sp1,sp2=crossover(parents[count], parents[count + 1])
            new_population.append(sp1)
            new_population.append(sp2)
        parents = roulette2(population,1,all_fitness)
        if np.random.random() < mutation_prob and len(new_population)<len(population):
            print("Mutation", parents[count])
            try:
              mutated=Mutation(parents[count],X_train,y_train,X_val,y_val)
              new_population.append(mutated)
            except Exception as e:
                print(e)
                print("not mutated")
    return new_population

# %%
from numpy import array, savetxt, loadtxt
from numpy import savetxt
import tensorflow as tf
import pickle
mods=[]

# %%
def GA( crossover_prob=0.85, mutation_prob=0.15, elitism_range=0.15, max_generation=100, convergence_rate=100):
    #generate initial population
    population=generateInitialPopulation()
    print("initial population", population)
    gen=0
    best_fits= {'0': {"{'KNN': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'ANN': [29]}": [0.6936, {'mcc': [0.3868607017236362], 'acc': [0.6936], 'f1': [0.683993399339934], 'cm': [array([[905, 367],
       [399, 829]])]}]}}
    models=[]
    convergence_count=0
    #split dataset
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, random_state=1)
    #while stop conditions not met

    ii=0
    while gen<max_generation  and convergence_count<convergence_rate:
        print("gen", gen)
        print("population", population)
        all_fitness = []
        all_mod = []
        done=[]
        all_info = []
        if gen ==3:
            population= [{'DT': ['entropy', 'best', None, 6, 9, 0.0, None, 53, None, 0.0, None, 'balanced', 0.0], 'RF': [128, 'gini', None, 8, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 11, False, 'balanced', 0.0, None], 'ANN': [95]}, {'KNN': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'ANN': [29]}, {'SVM': [56.651175987316705, 'linear', 93, 0.001, 0.5419741160525751, False, True, 0.001, 200, None, False, -1, 'ovr', False, 39], 'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'RF-1': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'RF-1': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'SVM': [34.05017443007109, 'linear', 24, 0.001, 0.6819152317877569, False, False, 0.001, 200, 'balanced', True, -1, 'ovr', False, None], 'KNN': [3, 'distance', 'auto', 99, 7, 'manhattan', None, None], 'RF': [164, 'gini', None, 10, 3, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 72, False, 'balanced', 0.0, None], 'DT': ['gini', 'best', None, 4, 9, 0.0, None, None, None, 0.0, None, None, 0.0]}, {'DT': ['entropy', 'best', None, 6, 9, 0.0, None, 53, None, 0.0, None, 'balanced', 0.0], 'RF': [128, 'gini', None, 8, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 11, False, 'balanced', 0.0, None], 'ANN': [11]}, {'RF': [151, 'gini', None, 7, 2, 0.0, 'sqrt', None, 0.0, None, False, False, None, None, 29, False, None, 0.0, None], 'LR': ['l2', False, 0.0001, 54.69859774842014, True, 15.905429432727614, 'balanced', 40, 'sag', 198, 'ovr', 16, False, None, None], 'ANN': [15]}, {'DT-0': ['gini', 'best', None, 9, 1, 0.0, None, 37, None, 0.0, None, 'balanced', 0.0], 'RF': [169, 'gini', None, 10, 2, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 57, False, None, 0.0, None]}, {'KNN': [6, 'distance', 'auto', 60, 5, 'manhattan', None, None], 'RF': [128, 'gini', None, 4, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 20, 50, False, 'balanced_subsample', 0.0, None], 'LR': ['elasticnet', True, 0.0001, 7.974803890000159, True, 80.73313721208389, None, 33, 'liblinear', 129, 'ovr', 11, True, None, 0]}, {'ANN': [45]}, {'KNN': [7, 'uniform', 'auto', 68, 7, 'euclidean', None, None], 'LR': ['l2', True, 0.0001, 62.549973805846605, True, 9.211698683897529, 'balanced', 7, 'sag', 184, 'ovr', 16, False, None, 0], 'RF': [158, 'gini', None, 6, 2, 0.0, None, None, 0.0, None, False, False, None, 93, 70, False, None, 0.0, None], 'DT': ['gini', 'best', None, 9, 1, 0.0, None, 37, None, 0.0, None, 'balanced', 0.0], 'RF-1': [169, 'gini', None, 10, 2, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 57, False, None, 0.0, None]}, {'KNN': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF': [128, 'gini', None, 8, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 11, False, 'balanced', 0.0, None], 'LR': ['l2', True, 0.0001, 3.8098921879033187, True, 48.05176624159464, None, None, 'sag', 145, 'ovr', 17, False, None, 0.4379068452283271]}, {'KNN': [6, 'distance', 'auto', 48, 9, 'minkowski', None, None], 'SVM': [21.056444875724022, 'rbf', 63, 0.001, 0.22322055307593025, False, True, 0.001, 200, 'balanced', True, -1, 'ovr', False, None], 'DT': ['gini', 'best', None, 5, 7, 0.0, None, None, None, 0.0, None, None, 0.0], 'RF': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'ANN': [29]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'LR': ['l2', False, 0.0001, 60.81019857941157, True, 35.781403706811055, None, None, 'saga', 139, 'ovr', 3, True, 1]}, {'KNN': [7, 'uniform', 'auto', 35, 6, 'manhattan', None, 1], 'DT': ['entropy', 'best', 30, 8, 1, 0.0, 'auto', None, None, 0.0, None, None], 'RF': [129, 'gini', None, 4, 2, 0.0, 'sqrt', None, 0.0, None, True, False, 1, None, 52, False, None], 'DT-1': ['entropy', 'best', None, 10, 5, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'LR': ['elasticnet', True, 0.0001, 50.91514702179476, True, 84.38877360775552, None, None, 'newton-cg', 67, 'ovr', 19, False, None, 1], 'ANN': [96]}, {'ANN-0': [29]}, {'RF': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'ANN': [29]}, {'KNN': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'SVM': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'LR': ['l2', True, 0.0001, 3.8098921879033187, True, 48.05176624159464, None, None, 'sag', 145, 'ovr', 17, False, None, 0.4379068452283271]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'DT': ['entropy', 'best', None, 10, 5, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'LR': ['elasticnet', True, 0.0001, 50.91514702179476, True, 84.38877360775552, None, None, 'newton-cg', 67, 'ovr', 19, False, None, 1], 'LR-1': ['l2', True, 0.0001, 62.549973805846605, True, 9.211698683897529, 'balanced', 7, 'sag', 184, 'ovr', 16, False, None, 0], 'RF-1': [158, 'gini', None, 6, 2, 0.0, None, None, 0.0, None, False, False, None, 93, 70, False, None, 0.0, None], 'ANN': [45]}, {'KNN': [7, 'uniform', 'auto', 68, 7, 'euclidean', None, None], 'ANN': [96]}, {'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'DT': ['gini', 'best', None, 9, 3, 0.0, None, None, None, 0.0, None, None, 0.0]}, {'KNN': [6, 'distance', 'auto', 48, 9, 'minkowski', None, None], 'SVM': [56.651175987316705, 'linear', 93, 0.001, 0.5419741160525751, False, True, 0.001, 200, None, False, -1, 'ovr', False, 39], 'SVM-1': [60.264686197189036, 'linear', 24, 0.001, 0.4853623809644213, False, False, 0.001, 200, None, False, -1, 'ovr', False, 94], 'DT': ['entropy', 'best', None, 8, 10, 0.0, None, None, None, 0.0, None, None, 0.0], 'RF': [134, 'gini', None, 9, 1, 0.0, None, None, 0.0, None, False, False, None, None, 90, False, 'balanced_subsample', 0.0, None], 'LR': ['elasticnet', False, 0.0001, 59.98191414531681, True, 7.2643157164394845, 'balanced', 34, 'saga', 82, 'ovr', 11, True, None, 0]}, {'SVM': [278, 'linear', 86, 0.0001, 0.30000000000000004, True, True, 0.001, 200, {1: 2}, True, -1, 'ovr'], 'KNN': [9, 'uniform', 'auto', 67, 6, 'minkowski', None, None], 'LR': [None, True, 0.0001, 67.23036339050321, True, 50.45074585210586, None, 90, 'saga', 199, 'ovr', 4, False, None, 0]}, {'SVM': [20.523462924341917, 'linear', 61, 0.001, 0.37201088387311465, True, True, 0.001, 200, None, False, -1, 'ovr', False, 7], 'DT': ['entropy', 'best', None, 10, 7, 0.0, None, 61, None, 0.0, None, None]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'RF-1': [134, 'gini', None, 9, 1, 0.0, None, None, 0.0, None, False, False, None, None, 90, False, 'balanced_subsample', 0.0, None], 'LR': ['elasticnet', False, 0.0001, 59.98191414531681, True, 7.2643157164394845, 'balanced', 34, 'saga', 82, 'ovr', 11, True, None, 0]}, {'KNN': [6, 'distance', 'auto', 48, 9, 'minkowski', None, None], 'DT': ['entropy', 'best', None, 10, 5, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'LR': ['elasticnet', True, 0.0001, 50.91514702179476, True, 84.38877360775552, None, None, 'newton-cg', 67, 'ovr', 19, False, None, 1], 'ANN': [96]}, {'SVM': [34.05017443007109, 'linear', 24, 0.001, 0.6819152317877569, False, False, 0.001, 200, 'balanced', True, -1, 'ovr', False, None], 'KNN': [3, 'distance', 'auto', 99, 7, 'manhattan', None, None], 'SVM-1': [56.651175987316705, 'linear', 93, 0.001, 0.5419741160525751, False, True, 0.001, 200, None, False, -1, 'ovr', False, 39], 'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'DT': ['gini', 'best', None, 9, 3, 0.0, None, None, None, 0.0, None, None, 0.0]}, {'KNN': [6, 'distance', 'auto', 48, 9, 'minkowski', None, None], 'RF': [164, 'gini', None, 10, 3, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 72, False, 'balanced', 0.0, None], 'DT': ['gini', 'best', None, 4, 9, 0.0, None, None, None, 0.0, None, None, 0.0]}, {'SVM': [56.651175987316705, 'linear', 93, 0.001, 0.5419741160525751, False, True, 0.001, 200, None, False, -1, 'ovr', False, 39], 'RF': [129, 'gini', None, 4, 2, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 52, False, None, 0.0, None], 'LR': ['l2', False, 0.0001, 60.81019857941157, True, 35.781403706811055, None, None, 'saga', 139, 'ovr', 3, True, None, 1]}, {'KNN': [9, 'uniform', 'auto', 38, 7, 'minkowski', None, None], 'DT': ['entropy', 'best', None, 6, 9, 0.0, None, 53, None, 0.0, None, 'balanced', 0.0], 'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'KNN-1': [9, 'uniform', 'auto', 67, 6, 'minkowski', None, None], 'DT-1': ['gini', 'best', None, 4, 9, 0.0, None, None, None, 0.0, None, None, 0.0]}, {'DT-0': ['entropy', 'best', None, 9, 10, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'RF': [169, 'gini', None, 7, 2, 0.0, None, None, 0.0, None, True, False, None, None, 92, False, 'balanced', 0.0, None], 'LR': [None, False, 0.0001, 35.36509150434214, True, 58.071491913076834, 'balanced', 91, 'saga', 144, 'ovr', 9, False, None, 0.5105945449044219], 'LR-1': ['l2', True, 0.0001, 3.8098921879033187, True, 48.05176624159464, None, None, 'sag', 145, 'ovr', 17, False, None, 0.4379068452283271]}, {'SVM': [56.651175987316705, 'linear', 93, 0.001, 0.5419741160525751, False, True, 0.001, 200, None, False, -1, 'ovr', False, 39], 'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'SVM-1': [27.006377836840322, 'sigmoid', 25, 0.001, 0.15810347644028822, False, True, 0.001, 200, None, False, -1, 'ovr', False, None], 'LR': [None, True, 0.0001, 14.016710913204722, True, 14.856574211288187, 'balanced', 14, 'newton-cg', 154, 'ovr', 13, False, None, 0.10979771675791761]}, {'LR': ['l2', True, 0.0001, 62.549973805846605, True, 9.211698683897529, 'balanced', 7, 'sag', 184, 'ovr', 16, False, None, 0], 'KNN': [5, 'distance', 'auto', 67, 2, 'minkowski', None, None], 'DT': ['entropy', 'best', None, 6, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'KNN-1': [8, 'uniform', 'auto', 85, 10, 'manhattan', None, None], 'DT-1': ['gini', 'best', None, 9, 3, 0.0, None, None, None, 0.0, None, None, 0.0]}, {'SVM': [60.264686197189036, 'linear', 24, 0.001, 0.4853623809644213, False, False, 0.001, 200, None, False, -1, 'ovr', False, 94], 'DT': ['entropy', 'best', None, 8, 10, 0.0, None, None, None, 0.0, None, None, 0.0], 'RF': [134, 'gini', None, 9, 1, 0.0, None, None, 0.0, None, False, False, None, None, 90, False, 'balanced_subsample', 0.0, None], 'RF-1': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'RF-2': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'LR': ['elasticnet', False, 0.0001, 59.98191414531681, True, 7.2643157164394845, 'balanced', 34, 'saga', 82, 'ovr', 11, True, None, 0]}, {'SVM': [56.651175987316705, 'linear', 93, 0.001, 0.5419741160525751, False, True, 0.001, 200, None, False, -1, 'ovr', False, 39], 'KNN': [6, 'distance', 'auto', 60, 5, 'manhattan', None, None], 'RF': [128, 'gini', None, 4, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 20, 50, False, 'balanced_subsample', 0.0, None], 'LR': ['elasticnet', True, 0.0001, 7.974803890000159, True, 80.73313721208389, None, 33, 'liblinear', 129, 'ovr', 11, True, None, 0]}, {'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'LR': ['l2', True, 0.0001, 62.549973805846605, True, 9.211698683897529, 'balanced', 7, 'sag', 184, 'ovr', 16, False, None, 0], 'KNN': [5, 'distance', 'auto', 67, 2, 'minkowski', None, None], 'DT': ['entropy', 'best', None, 6, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'KNN-1': [8, 'uniform', 'auto', 85, 10, 'manhattan', None, None], 'DT-1': ['gini', 'best', None, 9, 3, 0.0, None, None, None, 0.0, None, None, 0.0]}, {'KNN': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'DT-1': ['entropy', 'best', None, 9, 10, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'RF-1': [169, 'gini', None, 7, 2, 0.0, None, None, 0.0, None, True, False, None, None, 92, False, 'balanced', 0.0, None], 'LR-1': [None, False, 0.0001, 35.36509150434214, True, 58.071491913076834, 'balanced', 91, 'saga', 144, 'ovr', 9, False, None, 0.5105945449044219], 'ANN': [95]}, {'DT': ['entropy', 'best', None, 6, 9, 0.0, None, 53, None, 0.0, None, 'balanced', 0.0], 'RF': [128, 'gini', None, 8, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 11, False, 'balanced', 0.0, None], 'ANN': [11]}, {'KNN': [6, 'distance', 'auto', 48, 9, 'minkowski', None, None], 'RF': [151, 'gini', None, 7, 2, 0.0, 'sqrt', None, 0.0, None, False, False, None, None, 29, False, None, 0.0, None], 'LR': ['l2', False, 0.0001, 54.69859774842014, True, 15.905429432727614, 'balanced', 40, 'sag', 198, 'ovr', 16, False, None, None], 'LR-1': ['elasticnet', True, 0.0001, 27.40003521845059, True, 69.03694996811329, 'balanced', 25, 'liblinear', 100, 'ovr', 3, False, None, 1]}, {'LR-1': ['l2', False, 0.0001, 83.65100124415106, True, 33.009388437161114, 'balanced', 9, 'saga', 69, 'ovr', 4, False, None, 1]}, {'DT': ['entropy', 'best', None, 5, 8, 0.0, None, 86, None, 0.0, None, 'balanced', 0.0], 'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'LR': ['elasticnet', True, 0.0001, 27.40003521845059, True, 69.03694996811329, 'balanced', 25, 'liblinear', 100, 'ovr', 3, False, None, 1]}, {'DT-1': ['entropy', 'best', None, 10, 5, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'ANN': [11]}, {'KNN': [4, 'distance', 'auto', 54, 3, 'manhattan', None, None], 'DT': ['gini', 'best', None, 6, 9, 0.0, None, 97, None, 0.0, None, None], 'LR': ['l2', False, 0.0001, 377, True, 27.254798580910954, None, 27, 'liblinear', 127, 'ovr', 8, False, 1]}, {'SVM': [62.0545082212663, 'poly', 94, 0.001, 0.9462415976951283, False, True, 0.001, 200, None, False, -1, 'ovr', False, None], 'ANN': [49]}, {'DT': ['entropy', 'best', None, 9, 10, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'RF': [169, 'gini', None, 7, 2, 0.0, None, None, 0.0, None, True, False, None, None, 92, False, 'balanced', 0.0, None], 'LR': ['l2', True, 0.0001, 3.8098921879033187, True, 48.05176624159464, None, None, 'sag', 145, 'ovr', 17, False, None, 0.4379068452283271]}, {'DT': ['entropy', 'best', None, 9, 10, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'RF': [169, 'gini', None, 7, 2, 0.0, None, None, 0.0, None, True, False, None, None, 92, False, 'balanced', 0.0, None], 'LR': [None, False, 0.0001, 35.36509150434214, True, 58.071491913076834, 'balanced', 91, 'saga', 144, 'ovr', 9, False, None, 0.5105945449044219], 'LR-1': [None, False, 0.0001, 35.36509150434214, True, 58.071491913076834, 'balanced', 91, 'saga', 144, 'ovr', 9, False, None, 0.5105945449044219], 'LR-2': ['l2', True, 0.0001, 3.8098921879033187, True, 48.05176624159464, None, None, 'sag', 145, 'ovr', 17, False, None, 0.4379068452283271]}, {'SVM': [21.728331255799528, 'linear', 60, 0.001, 0.015683820140798943, True, False, 0.001, 200, None, False, -1, 'ovr', False, None], 'LR': ['elasticnet', True, 0.0001, 85.96012515373184, True, 28.447572405762266, None, 65, 'saga', 85, 'ovr', 17, True, None, 0.7766706104219286], 'SVM-1': [21.056444875724022, 'rbf', 63, 0.001, 0.22322055307593025, False, True, 0.001, 200, 'balanced', True, -1, 'ovr', False, None], 'DT': ['gini', 'best', None, 5, 7, 0.0, None, None, None, 0.0, None, None, 0.0], 'RF': [128, 'gini', None, 8, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 11, False, 'balanced', 0.0, None], 'LR-1': ['l2', True, 0.0001, 3.8098921879033187, True, 48.05176624159464, None, None, 'sag', 145, 'ovr', 17, False, None, 0.4379068452283271]}, {'KNN': [6, 'distance', 'auto', 48, 9, 'minkowski', None, None], 'LR': ['l2', True, 0.0001, 3.8098921879033187, True, 48.05176624159464, None, None, 'sag', 145, 'ovr', 17, False, None, 0.4379068452283271]}, {'SVM': [20.523462924341917, 'linear', 61, 0.001, 0.37201088387311465, True, True, 0.001, 200, None, False, -1, 'ovr'], 'KNN': [29, 'distance', 'auto', 27, 2, 'manhattan', None, 1], 'LR': ['l2', False, 0.0001, 67.23036339050321, True, 50.45074585210586, None, 90, 'saga', 199, 'ovr', 4, False, 1]}, {'KNN': [6, 'distance', 'auto', 48, 9, 'minkowski', None, None], 'SVM': [56.651175987316705, 'linear', 93, 0.001, 0.5419741160525751, False, True, 0.001, 200, None, False, -1, 'ovr', False, 39], 'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'ANN': [87]}, {'KNN-1': [5, 'uniform', 'auto', 59, 6, 'euclidean', None, None], 'LR': ['l2', False, 0.0001, 11.540993663717437, True, 7.273771949163299, None, None, 'sag', 117, 'ovr', 1, True, None, None], 'DT': ['gini', 'best', None, 9, 3, 0.0, None, None, None, 0.0, None, None, 0.0]}, {'LR-0': ['l2', False, 0.0001, 83.65100124415106, True, 33.009388437161114, 'balanced', 9, 'saga', 69, 'ovr', 4, False, None, 1]}, {'RF': [169, 'gini', None, 10, 2, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 57, False, None, 0.0, None]}, {'DT-0': ['gini', 'best', None, 9, 1, 0.0, None, 37, None, 0.0, None, 'balanced', 0.0], 'SVM': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'LR': ['l2', True, 0.0001, 3.8098921879033187, True, 48.05176624159464, None, None, 'sag', 145, 'ovr', 17, False, None, 0.4379068452283271]}, {'KNN-0': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'ANN': [29]}, {'KNN': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'SVM': [56.651175987316705, 'linear', 93, 0.001, 0.5419741160525751, False, True, 0.001, 200, None, False, -1, 'ovr', False, 39], 'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'KNN-1': [9, 'uniform', 'auto', 67, 6, 'minkowski', None, None], 'DT': ['gini', 'best', None, 4, 9, 0.0, None, None, None, 0.0, None, None, 0.0]}, {'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'ANN': [29]}, {'LR': ['elasticnet', True, 0.0001, 27.40003521845059, True, 69.03694996811329, 'balanced', 25, 'liblinear', 100, 'ovr', 3, False, None, 1]}, {'SVM': [278, 'linear', 86, 0.0001, 0.30000000000000004, True, True, 0.001, 200, {1: 2}, True, -1, 'ovr'], 'DT': ['entropy', 'best', 50, 8, 2, 0.0, 'auto', 61, None, 0.0, None, None]}, {'SVM': [20.523462924341917, 'linear', 61, 0.001, 0.37201088387311465, True, True, 0.001, 200, None, False, -1, 'ovr', False, 7], 'RF': [169, 'gini', None, 10, 2, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 57, False, None, 0.0, None]}, {'DT-0': ['gini', 'best', None, 9, 1, 0.0, None, 37, None, 0.0, None, 'balanced', 0.0], 'RF': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'SVM': [440, 'linear', 23, 0.0001, 0.2, True, True, 0.001, 200, {1: 1}, False, -1, 'ovr'], 'KNN': [9, 'uniform', 'auto', 67, 6, 'minkowski', None, 1], 'LR': ['l2', False, 0.0001, 67.23036339050321, True, 50.45074585210586, None, 90, 'saga', 199, 'ovr', 4, False, 1]}]
        if gen<3:
            print(gen)
            print(done)
        else:
            for chromosome in population:
                if chromosome in done:
                    print("chromosome", chromosome)
                    fit = all_fitness[done.index(chromosome)]
                    info = all_info[done.index(chromosome)]
                    model=all_mod[done.index(chromosome)]
                    all_fitness.append(fit)
                    all_info.append(info)
                    all_mod.append(model)
                    done.append(chromosome)
                    print("done out of 63", len(done))
                else:
                    print("chromosome", chromosome)
                    print(ii)
                    fit, info,model = fitness(chromosome,X_train,y_train,X_test,y_test,count=ii,gen=gen)
                    all_fitness.append(fit)
                    all_info.append(info)
                    all_mod.append(model)
                    done.append(chromosome)
                    print("done out of 63", len(done))
                    if gen ==0 or gen ==99:
                                ii+=1
          #check if converged
        if best_fits!={} and gen >0:
            if(str(list(best_fits[str(gen-1)])[0])== str(population[all_fitness.index(max(all_fitness))])):
                print("converged")
                convergence_count = convergence_count + 1
            else:
                convergence_count=0
        #get best fit
        index = all_fitness.index(max(all_fitness))
        print("in gen",gen)
        print("best fitness",max(all_fitness))
        print("chromosome",population[index])
        best_fits[str(gen)]={str(population[index]):[max(all_fitness),all_info[index]]}
        print("best_fits",best_fits)
        print("all fitness",all_fitness)
        print("all_info",all_info)
        try:
            if gen ==0:
                models.append(all_mod[index])
                emod=all_mod[index]
                print(index)
                filename = 'gen0_modelexp1.sav'
                with open(filename, "wb") as file:
                  pickle.dump(emod, file)
            if gen == 99:
                models.append(all_mod[index])
                emod=all_mod[index]
                print(index)
                filename = 'gen99_modelexp1.sav'
                with open(filename, "wb") as file:
                  pickle.dump(emod, file)
        except Exception as e:
            print(e)
            print("not saved")
        if gen ==99   :
            mods.append(all_mod[index])
       
        gen=gen+1
        #check stop conditions and generate new data
        if gen >3 and gen<max_generation and convergence_count<convergence_rate:
            population=generateNewPopulation(population,X_train=X_train,y_train=y_train,X_val=X_val,y_val=y_val,crossover_prob=crossover_prob,mutation_prob=mutation_prob,elitism_range=elitism_range,all_fitness=all_fitness)
        #increase mutation rate
        if (convergence_count >0 and convergence_count% 5==0 ):
            mutation_prob+=0.1
            convergence_count=0
    return best_fits, models

# %%
print(mods)
# Out:
# []

# %%
#x1, y1=balanced_subsample(X,y,5000)
#x1=np.array(x1)
#savetxt('dataexp1x.csv', x1, delimiter=',')
#savetxt('dataexp1y.csv', y1, delimiter=',')
X=loadtxt("dataexp1x.csv", delimiter=",")
y=loadtxt("dataexp1y.csv", delimiter=",")
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, random_state=1)

# %%
best_fits,models=GA()
print(best_fits)
# Out:
# initial population [{'SVM': [28.158689377622682, 'sigmoid', 94, 0.001, 0.6514996951995063, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 38]}, {'KNN': [2, 'uniform', 'auto', 75, 2, 'manhattan', None, None]}, {'DT': ['entropy', 'best', None, 10, 1, 0.0, None, None, None, 0.0, None, 'balanced', 0.0]}, {'RF': [172, 'entropy', None, 7, 6, 0.0, 'auto', None, 0.0, None, False, False, None, 23, 25, False, 'balanced', 0.0, None]}, {'LR': [None, True, 0.0001, 8.838360770622655, True, 47.71808578904544, None, 16, 'newton-cg', 148, 'ovr', 16, True, None, 0]}, {'ANN': [36]}, {'SVM': [89.69660192804706, 'linear', 80, 0.001, 0.893589858873812, False, True, 0.001, 200, 'balanced', False, -1, 'ovr', False, None], 'KNN': [4, 'distance', 'auto', 59, 10, 'manhattan', None, None]}, {'SVM': [36.65463251767797, 'rbf', 32, 0.001, 0.12566016912949518, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 38], 'DT': ['entropy', 'best', None, 5, 7, 0.0, None, None, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [92.5232145440711, 'rbf', 99, 0.001, 0.274727760404633, True, True, 0.001, 200, 'balanced', True, -1, 'ovr', False, 22], 'RF': [157, 'gini', None, 3, 3, 0.0, None, None, 0.0, None, True, False, None, 22, 78, False, None, 0.0, None]}, {'SVM': [71.5409236293127, 'rbf', 47, 0.001, 0.8534948856259764, False, True, 0.001, 200, 'balanced', False, -1, 'ovr', False, None], 'LR': ['l2', True, 0.0001, 34.82054952553728, True, 98.3443193317771, 'balanced', None, 'sag', 65, 'ovr', 20, False, None, 0.36471796247214006]}, {'SVM': [34.63073069162995, 'poly', 83, 0.001, 0.30543960455513275, True, False, 0.001, 200, None, False, -1, 'ovr', False, 37], 'ANN': [72]}, {'KNN': [7, 'distance', 'auto', 32, 7, 'euclidean', None, None], 'DT': ['entropy', 'best', None, 8, 4, 0.0, None, 10, None, 0.0, None, 'balanced', 0.0]}, {'KNN': [2, 'uniform', 'auto', 96, 4, 'minkowski', None, None], 'RF': [117, 'gini', None, 2, 4, 0.0, 'log2', None, 0.0, None, False, False, None, 20, 60, False, None, 0.0, None]}, {'KNN': [3, 'uniform', 'auto', 43, 4, 'minkowski', None, None], 'LR': ['elasticnet', True, 0.0001, 92.75527901929884, True, 42.9148998302924, None, 56, 'lbfgs', 121, 'ovr', 2, True, None, None]}, {'KNN': [1, 'distance', 'auto', 57, 4, 'manhattan', None, None], 'ANN': [60]}, {'DT': ['entropy', 'best', None, 3, 5, 0.0, None, 46, None, 0.0, None, None, 0.0], 'RF': [184, 'entropy', None, 3, 5, 0.0, None, None, 0.0, None, False, False, None, None, 70, False, 'balanced', 0.0, None]}, {'DT': ['gini', 'best', None, 2, 9, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'LR': ['l2', True, 0.0001, 33.77492957697291, True, 52.70046273224176, None, None, 'saga', 142, 'ovr', 2, True, None, 0]}, {'DT': ['gini', 'best', None, 4, 8, 0.0, None, 23, None, 0.0, None, None, 0.0], 'ANN': [45]}, {'RF': [117, 'entropy', None, 10, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 4, 75, False, 'balanced_subsample', 0.0, None], 'LR': ['l2', True, 0.0001, 44.322538403029085, True, 98.80799650331925, 'balanced', 89, 'newton-cg', 175, 'ovr', 10, True, None, None]}, {'RF': [180, 'gini', None, 10, 4, 0.0, None, None, 0.0, None, True, False, None, 49, 91, False, 'balanced', 0.0, None], 'ANN': [34]}, {'LR': ['l2', False, 0.0001, 4.485619754445647, True, 29.563126783057424, None, None, 'lbfgs', 86, 'ovr', 4, False, None, 0], 'ANN': [78]}, {'SVM': [48.30594098005935, 'linear', 75, 0.001, 0.3432614578898733, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 9], 'KNN': [1, 'uniform', 'auto', 51, 10, 'euclidean', None, None], 'DT': ['gini', 'best', None, 9, 6, 0.0, None, None, None, 0.0, None, None, 0.0]}, {'SVM': [63.24467189903523, 'poly', 71, 0.001, 0.7965000889366708, False, True, 0.001, 200, None, True, -1, 'ovr', False, None], 'KNN': [5, 'distance', 'auto', 39, 3, 'minkowski', None, None], 'RF': [198, 'entropy', None, 5, 10, 0.0, None, None, 0.0, None, True, False, None, None, 19, False, 'balanced', 0.0, None]}, {'SVM': [87.44417478251741, 'poly', 26, 0.001, 0.8277 ...
# gen 0
# population [{'SVM': [28.158689377622682, 'sigmoid', 94, 0.001, 0.6514996951995063, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 38]}, {'KNN': [2, 'uniform', 'auto', 75, 2, 'manhattan', None, None]}, {'DT': ['entropy', 'best', None, 10, 1, 0.0, None, None, None, 0.0, None, 'balanced', 0.0]}, {'RF': [172, 'entropy', None, 7, 6, 0.0, 'auto', None, 0.0, None, False, False, None, 23, 25, False, 'balanced', 0.0, None]}, {'LR': [None, True, 0.0001, 8.838360770622655, True, 47.71808578904544, None, 16, 'newton-cg', 148, 'ovr', 16, True, None, 0]}, {'ANN': [36]}, {'SVM': [89.69660192804706, 'linear', 80, 0.001, 0.893589858873812, False, True, 0.001, 200, 'balanced', False, -1, 'ovr', False, None], 'KNN': [4, 'distance', 'auto', 59, 10, 'manhattan', None, None]}, {'SVM': [36.65463251767797, 'rbf', 32, 0.001, 0.12566016912949518, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 38], 'DT': ['entropy', 'best', None, 5, 7, 0.0, None, None, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [92.5232145440711, 'rbf', 99, 0.001, 0.274727760404633, True, True, 0.001, 200, 'balanced', True, -1, 'ovr', False, 22], 'RF': [157, 'gini', None, 3, 3, 0.0, None, None, 0.0, None, True, False, None, 22, 78, False, None, 0.0, None]}, {'SVM': [71.5409236293127, 'rbf', 47, 0.001, 0.8534948856259764, False, True, 0.001, 200, 'balanced', False, -1, 'ovr', False, None], 'LR': ['l2', True, 0.0001, 34.82054952553728, True, 98.3443193317771, 'balanced', None, 'sag', 65, 'ovr', 20, False, None, 0.36471796247214006]}, {'SVM': [34.63073069162995, 'poly', 83, 0.001, 0.30543960455513275, True, False, 0.001, 200, None, False, -1, 'ovr', False, 37], 'ANN': [72]}, {'KNN': [7, 'distance', 'auto', 32, 7, 'euclidean', None, None], 'DT': ['entropy', 'best', None, 8, 4, 0.0, None, 10, None, 0.0, None, 'balanced', 0.0]}, {'KNN': [2, 'uniform', 'auto', 96, 4, 'minkowski', None, None], 'RF': [117, 'gini', None, 2, 4, 0.0, 'log2', None, 0.0, None, False, False, None, 20, 60, False, None, 0.0, None]}, {'KNN': [3, 'uniform', 'auto', 43, 4, 'minkowski', None, None], 'LR': ['elasticnet', True, 0.0001, 92.75527901929884, True, 42.9148998302924, None, 56, 'lbfgs', 121, 'ovr', 2, True, None, None]}, {'KNN': [1, 'distance', 'auto', 57, 4, 'manhattan', None, None], 'ANN': [60]}, {'DT': ['entropy', 'best', None, 3, 5, 0.0, None, 46, None, 0.0, None, None, 0.0], 'RF': [184, 'entropy', None, 3, 5, 0.0, None, None, 0.0, None, False, False, None, None, 70, False, 'balanced', 0.0, None]}, {'DT': ['gini', 'best', None, 2, 9, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'LR': ['l2', True, 0.0001, 33.77492957697291, True, 52.70046273224176, None, None, 'saga', 142, 'ovr', 2, True, None, 0]}, {'DT': ['gini', 'best', None, 4, 8, 0.0, None, 23, None, 0.0, None, None, 0.0], 'ANN': [45]}, {'RF': [117, 'entropy', None, 10, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 4, 75, False, 'balanced_subsample', 0.0, None], 'LR': ['l2', True, 0.0001, 44.322538403029085, True, 98.80799650331925, 'balanced', 89, 'newton-cg', 175, 'ovr', 10, True, None, None]}, {'RF': [180, 'gini', None, 10, 4, 0.0, None, None, 0.0, None, True, False, None, 49, 91, False, 'balanced', 0.0, None], 'ANN': [34]}, {'LR': ['l2', False, 0.0001, 4.485619754445647, True, 29.563126783057424, None, None, 'lbfgs', 86, 'ovr', 4, False, None, 0], 'ANN': [78]}, {'SVM': [48.30594098005935, 'linear', 75, 0.001, 0.3432614578898733, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 9], 'KNN': [1, 'uniform', 'auto', 51, 10, 'euclidean', None, None], 'DT': ['gini', 'best', None, 9, 6, 0.0, None, None, None, 0.0, None, None, 0.0]}, {'SVM': [63.24467189903523, 'poly', 71, 0.001, 0.7965000889366708, False, True, 0.001, 200, None, True, -1, 'ovr', False, None], 'KNN': [5, 'distance', 'auto', 39, 3, 'minkowski', None, None], 'RF': [198, 'entropy', None, 5, 10, 0.0, None, None, 0.0, None, True, False, None, None, 19, False, 'balanced', 0.0, None]}, {'SVM': [87.44417478251741, 'poly', 26, 0.001, 0.827783145212 ...
# in gen 0
# best fitness 0.6936
# chromosome {'KNN': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'ANN': [29]}
# best_fits {'0': {"{'KNN': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'ANN': [29]}": [0.6936, {'mcc': [0.3868607017236362], 'acc': [0.6936], 'f1': [0.683993399339934], 'cm': [array([[905, 367],
#        [399, 829]])]}]}}
# all fitness [0.4912, 0.6464, 0.61, 0.6732, 0.6456, 0.6844, 0.6396, 0.6372, 0.666, 0.6456, 0.644, 0.6176, 0.6716, 0.6596, 0.6136, 0.6444, 0.6476, 0, 0.6776, 0, 0.6744, 0.682, 0.66, 0.6516, 0.6536, 0.6784, 0.6428, 0.6184, 0.6568, 0.6772, 0.6528, 0.6476, 0.6668, 0.634, 0.682, 0.66, 0.6504, 0.65, 0.6784, 0.662, 0.6852, 0.6532, 0.6396, 0.62, 0.6808, 0.6256, 0.6388, 0.6664, 0.6724, 0.6588, 0.6796, 0.6812, 0.6092, 0.6732, 0.682, 0.6816, 0.6804, 0.6788, 0.6608, 0.6796, 0.6732, 0.6936, 0.6616]
# all_info [{'mcc': [0], 'acc': [0.4912], 'f1': [0.6587982832618026], 'cm': [array([[   0, 1272],
#        [   0, 1228]])]}, {'mcc': [0.2936920718871597], 'acc': [0.6464], 'f1': [0.6497622820919177], 'cm': [array([[796, 476],
#        [408, 820]])]}, {'mcc': [0.2196650957004209], 'acc': [0.61], 'f1': [0.601552921945239], 'cm': [array([[789, 483],
#        [492, 736]])]}, {'mcc': [0.34646785595023544], 'acc': [0.6732], 'f1': [0.6704316256555062], 'cm': [array([[852, 420],
#        [397, 831]])]}, {'mcc': [0.2957541618581573], 'acc': [0.6456], 'f1': [0.6636294608959756], 'cm': [array([[740, 532],
#        [354, 874]])]}, {'mcc': [0.3684696799014371], 'acc': [0.6844], 'f1': [0.6759753593429157], 'cm': [array([[888, 384],
#        [405, 823]])]}, {'mcc': [0.2815068255474013], 'acc': [0.6396], 'f1': [0.595056179775281], 'cm': [array([[937, 335],
#        [566, 662]])]}, {'mcc': [0.2786541033547449], 'acc': [0.6372], 'f1': [0.5822201750345463], 'cm': [array([[961, 311],
#        [596, 632]])]}, {'mcc': [0.333561546398658], 'acc': [0.666], 'f1': [0.6332894158981116], 'cm': [array([[944, 328],
#        [507, 721]])]}, {'mcc': [0.2958429475381238], 'acc': [0.6456], 'f1': [0.6638846737481032], 'cm': [array([[739, 533],
#        [353, 875]])]}, {'mcc': [0.29006150825396493], 'acc': [0.644], 'f1': [0.6023235031277926], 'cm': [array([[936, 336],
#        [554, 674]])]}, {'mcc': [0.2502905145934123], 'acc': [0.6176], 'f1': [0.5127420998980632], 'cm': [array([[1041,  231],
#        [ 725,  503]])]}, {'mcc': [0.34686955681844955], 'acc': [0.6716], 'f1': [0.6310112359550563], 'cm': [array([[977, 295],
#        [526, 702]])]}, {'mcc': [0.321604765837958], 'acc': [0.6596], 'f1': [0.6209354120267261], 'cm': [array([[952, 320],
#        [531, 697]])]}, {'mcc': [0.24750343101372904], 'acc': [0.6136], 'f1': [0.4905063291139241], 'cm': [array([[1069,  203],
#        [ 763,  465]])]}, {'mcc': [0.29764232827862236], 'acc': [0.6444], 'f1': [0.5760610395803528], 'cm': [array([[1007,  265],
#        [ 624,  604]])]}, {'mcc': [0.3028316601801736], 'acc': [0.6476], 'f1': [0.5846298915605846], 'cm': [array([[999, 273],
#        [608, 620]])]}, {'mcc': [0], 'acc': [0], 'f1': [0], 'cm': [array([[1272,    0],
#        [1228,    0]])]}, {'mcc': [0.35889711233007376], 'acc': [0.6776], 'f1': [0.6385650224215247], 'cm': [array([[982, 290],
#        [516, 712]])]}, {'mcc': [0], 'acc': [0], 'f1': [0], 'cm': [array([[1272,    0],
#        [1228,    0]])]}, {'mcc': [0.34956623550403637], 'acc': [0.6744], 'f1': [0.6482281763180641], 'cm': [array([[936, 336],
#        [478, 750]])]}, {'mcc': [0.36868475682875207], 'acc': [0.682], 'f1': [0.6971428571428572], 'cm': [array([[790, 482],
#        [313, 915]])]}, {'mcc': [0.3257733718360666], 'acc': [0.66], 'f1': [0.6797287113790504], 'cm': [array([[748, 524],
#        [326, 902]])]}, {'mcc': [0.3107918133821213], 'acc': [0.6516], 'f1': [0.6763285024154589], 'cm': [array([[719, 553],
#        [318, 910]])]}, {'mcc': [0.3089117815624329], 'acc': [0.6536], 'f1': [0.6168141592920354], 'cm': [array([[937, 335],
#        [531, 697]])]}, {'mcc': [0.3597213173279607], 'acc': [0.6784], 'f1': [0.6890951276102087], 'cm': [array([[805, 467],
#        [337, 891]])]}, {'mcc': [0.2928174195195563], 'acc': [0.6428], 'f1': [0.6679062848642617], 'cm': [array([[709, 563],
#        [330, 898]])]}, {'mcc': [0.24018837977812318], 'acc': [0.6184], 'f1': [0.5587419056429233], 'cm': [array([[942, 330],
#        [624, 604]])]}, {'mcc': [0.3207084645956629], 'acc': [0.6568], 'f1': [0.6798507462686568], 'cm': [array([[731, 541],
#        [317, 911]])]}, {'mcc': [0.3566717308539513], 'acc': [0.6772], 'f1': [0.6437086092715233], 'cm': [array([[964, 308],
#        [499, 729]])]}, {'mcc': [0.31237939627535255], 'acc': [0.6528], 'f1': [0.6756352765321375], 'cm': [array([[728, 544],
#        [324, 904]])]}, {'mcc': [0.29520433484660397], 'acc': [0.6476], 'f1': [0.6440404040404041], 'cm': [array([[822, 450],
#        [431, 797]])]}, {'mcc': [0.3350202757736869], 'acc': [0.6668], 'f1': [0.6724341329138812], 'cm': [array([[812, 460],
#        [373, 855]])]}, {'mcc': [0.275681543632846], 'acc': [0.634], 'f1': [0.564078132444021], 'cm': [array([[993, 279],
#        [636, 592]])]}, {'mcc': [0.36444197754923996], 'acc': [0.682], 'f1': [0.6821271491403439], 'cm': [array([[852, 420],
#        [375, 853]])]}, {'mcc': [0.3222446805083023], 'acc': [0.66], 'f1': [0.6222222222222223], 'cm': [array([[950, 322],
#        [528, 700]])]}, {'mcc': [0.3099042168690396], 'acc': [0.6504], 'f1': [0.5842055185537584], 'cm': [array([[1012,  260],
#        [ 614,  614]])]}, {'mcc': [0.3004212245753161], 'acc': [0.65], 'f1': [0.6501399440223911], 'cm': [array([[812, 460],
#        [415, 813]])]}, {'mcc': [0.3564489341616833], 'acc': [0.6784], 'f1': [0.6694078947368421], 'cm': [array([[882, 390],
#        [414, 814]])]}, {'mcc': [0.3248944908223983], 'acc': [0.662], 'f1': [0.6650812524772096], 'cm': [array([[816, 456],
#        [389, 839]])]}, {'mcc': [0.3723141732528181], 'acc': [0.6852], 'f1': [0.6922174423152131], 'cm': [array([[828, 444],
#        [343, 885]])]}, {'mcc': [0.3060640552677656], 'acc': [0.6532], 'f1': [0.6343315056938001], 'cm': [array([[881, 391],
#        [476, 752]])]}, {'mcc': [0.27921543836271995], 'acc': [0.6396], 'f1': [0.6121394748170469], 'cm': [array([[888, 384],
#        [517, 711]])]}, {'mcc': [0.24957111805959722], 'acc': [0.62], 'f1': [0.534769833496572], 'cm': [array([[1004,  268],
#        [ 682,  546]])]}, {'mcc': [0.36134046935901964], 'acc': [0.6808], 'f1': [0.6655490360435876], 'cm': [array([[908, 364],
#        [434, 794]])]}, {'mcc': [0.2709471582426173], 'acc': [0.6256], 'f1': [0.5150259067357513], 'cm': [array([[1067,  205],
#        [ 731,  497]])]}, {'mcc': [0.2838084431994492], 'acc': [0.6388], 'f1': [0.5766526019690577], 'cm': [array([[982, 290],
#        [613, 615]])]}, {'mcc': [0.33241283437995217], 'acc': [0.6664], 'f1': [0.6519198664440734], 'cm': [array([[885, 387],
#        [447, 781]])]}, {'mcc': [0.34445372939907726], 'acc': [0.6724], 'f1': [0.6577517760133723], 'cm': [array([[894, 378],
#        [441, 787]])]}, {'mcc': [0.3189417178025654], 'acc': [0.6588], 'f1': [0.6643053915781189], 'cm': [array([[803, 469],
#        [384, 844]])]}, {'mcc': [0.36293340121217926], 'acc': [0.6796], 'f1': [0.6409681757059614], 'cm': [array([[984, 288],
#        [513, 715]])]}, {'mcc': [0.36274846698434166], 'acc': [0.6812], 'f1': [0.659256092347157], 'cm': [array([[932, 340],
#        [457, 771]])]}, {'mcc': [0.23804793673867622], 'acc': [0.6092], 'f1': [0.4833421470121629], 'cm': [array([[1066,  206],
#        [ 771,  457]])]}, {'mcc': [0.34690753857521966], 'acc': [0.6732], 'f1': [0.6486021505376345], 'cm': [array([[929, 343],
#        [474, 754]])]}, {'mcc': [0.36443523908313463], 'acc': [0.682], 'f1': [0.6595289079229121], 'cm': [array([[935, 337],
#        [458, 770]])]}, {'mcc': [0.36368955615989673], 'acc': [0.6816], 'f1': [0.6586620926243568], 'cm': [array([[936, 336],
#        [460, 768]])]}, {'mcc': [0.36124093990054373], 'acc': [0.6804], 'f1': [0.6805277888844461], 'cm': [array([[850, 422],
#        [377, 851]])]}, {'mcc': [0.3572656166554148], 'acc': [0.6788], 'f1': [0.6649979140592407], 'cm': [array([[900, 372],
#        [431, 797]])]}, {'mcc': [0.3219701897996362], 'acc': [0.6608], 'f1': [0.6347975882859603], 'cm': [array([[915, 357],
#        [491, 737]])]}, {'mcc': [0.3628346499790332], 'acc': [0.6796], 'f1': [0.6922781406069919], 'cm': [array([[798, 474],
#        [327, 901]])]}, {'mcc': [0.3460402890037907], 'acc': [0.6732], 'f1': [0.6591572799332498], 'cm': [array([[893, 379],
#        [438, 790]])]}, {'mcc': [0.3868607017236362], 'acc': [0.6936], 'f1': [0.683993399339934], 'cm': [array([[905, 367],
#        [399, 829]])]}, {'mcc': [0.3278239419119164], 'acc': [0.6616], 'f1': [0.6144029170464904], 'cm': [array([[980, 292],
#        [554, 674]])]}]
# list index out of range
# not saved
# gen 1
# population [{'SVM': [13.159320452636692, 'poly', 16, 0.001, 0.3094347827289865, False, True, 0.001, 200, None, True, -1, 'ovr', False, None]}, {'KNN': [8, 'distance', 'auto', 87, 9, 'euclidean', None, None]}, {'DT': ['gini', 'best', None, 4, 5, 0.0, None, 23, None, 0.0, None, None, 0.0]}, {'RF': [105, 'entropy', None, 3, 5, 0.0, 'sqrt', None, 0.0, None, False, False, None, None, 87, False, 'balanced_subsample', 0.0, None]}, {'LR': ['elasticnet', True, 0.0001, 27.40003521845059, True, 69.03694996811329, 'balanced', 25, 'liblinear', 100, 'ovr', 3, False, None, 1]}, {'ANN': [11]}, {'SVM': [56.83482787308529, 'rbf', 56, 0.001, 0.1471499725774863, True, True, 0.001, 200, 'balanced', True, -1, 'ovr', False, None], 'KNN': [3, 'uniform', 'auto', 48, 2, 'manhattan', None, None]}, {'SVM': [95.6629149764185, 'linear', 79, 0.001, 0.00830740648726247, True, True, 0.001, 200, None, True, -1, 'ovr', False, 84], 'DT': ['entropy', 'best', None, 10, 7, 0.0, None, 61, None, 0.0, None, None, 0.0]}, {'SVM': [71.96244306499204, 'sigmoid', 5, 0.001, 0.5492971306487061, False, False, 0.001, 200, 'balanced', True, -1, 'ovr', False, None], 'RF': [198, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, True, False, None, 81, 93, False, 'balanced_subsample', 0.0, None]}, {'SVM': [72.2877803985163, 'poly', 58, 0.001, 0.32776436448881874, True, False, 0.001, 200, 'balanced', True, -1, 'ovr', False, None], 'LR': ['l2', False, 0.0001, 33.41075518012888, True, 26.949763828687612, None, None, 'saga', 56, 'ovr', 20, False, None, 0]}, {'SVM': [62.63417243030604, 'rbf', 12, 0.001, 0.5775521256446646, True, True, 0.001, 200, 'balanced', False, -1, 'ovr', False, 15], 'ANN': [38]}, {'KNN': [8, 'uniform', 'auto', 85, 10, 'manhattan', None, None], 'DT': ['gini', 'best', None, 9, 3, 0.0, None, None, None, 0.0, None, None, 0.0]}, {'KNN': [7, 'uniform', 'auto', 68, 7, 'euclidean', None, None], 'RF': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'KNN': [9, 'uniform', 'auto', 39, 4, 'euclidean', None, None], 'LR': ['l2', True, 0.0001, 26.16823306908008, True, 27.593643224456134, 'balanced', 90, 'liblinear', 136, 'ovr', 9, False, None, 0]}, {'KNN': [2, 'uniform', 'auto', 79, 9, 'minkowski', None, None], 'ANN': [54]}, {'DT': ['gini', 'best', None, 9, 1, 0.0, None, 37, None, 0.0, None, 'balanced', 0.0], 'RF': [169, 'gini', None, 10, 2, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 57, False, None, 0.0, None]}, {'DT': ['gini', 'best', None, 6, 9, 0.0, None, 97, None, 0.0, None, None, 0.0], 'LR': ['l2', False, 0.0001, 94.63262765732827, True, 27.254798580910954, None, 27, 'lbfgs', 127, 'ovr', 8, False, None, 0]}, {'DT': ['entropy', 'best', None, 7, 1, 0.0, None, 43, None, 0.0, None, 'balanced', 0.0], 'ANN': [45]}, {'RF': [147, 'entropy', None, 7, 6, 0.0, 'sqrt', None, 0.0, None, False, False, None, None, 54, False, 'balanced', 0.0, None], 'LR': ['l1', True, 0.0001, 73.66626472747214, True, 25.658603878007202, None, 98, 'newton-cg', 153, 'ovr', 14, True, None, 0]}, {'RF': [115, 'entropy', None, 8, 5, 0.0, 'sqrt', None, 0.0, None, False, False, None, 34, 26, False, 'balanced_subsample', 0.0, None], 'ANN': [84]}, {'LR': [None, True, 0.0001, 73.3785646444317, True, 70.87886982015137, None, None, 'lbfgs', 177, 'ovr', 18, False, None, None], 'ANN': [33]}, {'SVM': [20.523462924341917, 'linear', 61, 0.001, 0.37201088387311465, True, True, 0.001, 200, None, False, -1, 'ovr', False, 7], 'KNN': [9, 'uniform', 'auto', 67, 6, 'minkowski', None, None], 'DT': ['gini', 'best', None, 4, 9, 0.0, None, None, None, 0.0, None, None, 0.0]}, {'SVM': [27.006377836840322, 'sigmoid', 25, 0.001, 0.15810347644028822, False, True, 0.001, 200, None, False, -1, 'ovr', False, None], 'KNN': [7, 'distance', 'auto', 82, 7, 'minkowski', None, None], 'RF': [147, 'gini', None, 4, 1, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 78, False, None, 0.0, None]}, {'SVM': [68.60856180899256, 'linear', 40, 0.001, 0.8538864166950686, True, T ...
# chromosome {'KNN': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'ANN': [29]}
# 0
# KNN
# DT
# RF
# LR
# ANN
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s remaining:    0.0s
# building tree 1 of 149
# building tree 2 of 149
# building tree 3 of 149
# building tree 4 of 149
# building tree 5 of 149
# building tree 6 of 149
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    0.4s remaining:    0.0s
# building tree 7 of 149
# building tree 8 of 149
# building tree 9 of 149
# building tree 10 of 149
# building tree 11 of 149
# building tree 12 of 149
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    0.6s remaining:    0.0s
# building tree 13 of 149
# building tree 14 of 149
# building tree 15 of 149
# building tree 16 of 149
# building tree 17 of 149
# building tree 18 of 149
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    0.7s remaining:    0.0s
# building tree 19 of 149
# building tree 20 of 149
# building tree 21 of 149
# building tree 22 of 149
# building tree 23 of 149
# building tree 24 of 149
# building tree 25 of 149
# building tree 26 of 149
# building tree 27 of 149
# building tree 28 of 149
# building tree 29 of 149
# building tree 30 of 149
# building tree 31 of 149
# building tree 32 of 149
# building tree 33 of 149
# building tree 34 of 149
# building tree 35 of 149
# building tree 36 of 149
# building tree 37 of 149
# building tree 38 of 149
# building tree 39 of 149
# building tree 40 of 149
# building tree 41 of 149
# building tree 42 of 149
# building tree 43 of 149
# building tree 44 of 149
# building tree 45 of 149
# building tree 46 of 149
# building tree 47 of 149
# building tree 48 of 149
# building tree 49 of 149
# building tree 50 of 149
# building tree 51 of 149
# building tree 52 of 149
# building tree 53 of 149
# building tree 54 of 149
# building tree 55 of 149
# building tree 56 of 149
# building tree 57 of 149
# building tree 58 of 149
# building tree 59 of 149
# building tree 60 of 149
# building tree 61 of 149
# building tree 62 of 149
# building tree 63 of 149
# building tree 64 of 149
# building tree 65 of 149
# building tree 66 of 149
# building tree 67 of 149
# building tree 68 of 149
# building tree 69 of 149
# building tree 70 of 149
# building tree 71 of 149
# building tree 72 of 149
# building tree 73 of 149
# building tree 74 of 149
# building tree 75 of 149
# building tree 76 of 149
# building tree 77 of 149
# building tree 78 of 149
# building tree 79 of 149
# building tree 80 of 149
# building tree 81 of 149
# building tree 82 of 149
# building tree 83 of 149
# building tree 84 of 149
# building tree 85 of 149
# building tree 86 of 149
# building tree 87 of 149
# building tree 88 of 149
# building tree 89 of 149
# building tree 90 of 149
# building tree 91 of 149
# building tree 92 of 149
# building tree 93 of 149
# building tree 94 of 149
# building tree 95 of 149
# building tree 96 of 149
# building tree 97 of 149
# building tree 98 of 149
# building tree 99 of 149
# building tree 100 of 149
# building tree 101 of 149
# building tree 102 of 149
# building tree 103 of 149
# building tree 104 of 149
# building tree 105 of 149
# building tree 106 of 149
# building tree 107 of 149
# building tree 108 of 149
# building tree 109 of 149
# building tree 110 of 149
# building tree 111 of 149
# building tree 112 of 149
# building tree 113 of 149
# building tree 114 of 149
# building tree 115 of 149
# building tree 116 of 149
# building tree 117 of 149
# building tree 118 of 149
# building tree 119 of 149
# building tree 120 of 149
# building tree 121 of 149
# building tree 122 of 149
# building tree 123 of 149
# building tree 124 of 149
# building tree 125 of 149
# building tree 126 of 149
# building tree 127 of 149
# building tree 128 of 149
# building tree 129 of 149
# building tree 130 of 149
# building tree 131 of 149
# building tree 132 of 149
# building tree 133 of 149
# building tree 134 of 149
# building tree 135 of 149
# building tree 136 of 149
# building tree 137 of 149
# building tree 138 of 149
# building tree 139 of 149
# building tree 140 of 149
# building tree 141 of 149
# building tree 142 of 149
# building tree 143 of 149
# building tree 144 of 149
# building tree 145 of 149
# building tree 146 of 149
# building tree 147 of 149
# building tree 148 of 149
# building tree 149 of 149
# [Parallel(n_jobs=1)]: Done 149 out of 149 | elapsed:    5.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# convergence after 136 epochs took 1 seconds
# WARNING:tensorflow:From /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s finished
# WARNING:tensorflow:From /srv/conda/envs/notebook/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 149 out of 149 | elapsed:    0.1s finished
# [[895 377]
#  [401 827]]
# accuracy: 0.6888
# mcc: 0.37726625701546396
# f1_score: 0.6800986842105263
# Fitness: 0.6888
# done out of 63 1
# chromosome {'RF': [119, 'gini', None, 7, 5, 0.0, None, None, 0.0, None, True, False, None, None, 33, False, 'balanced', 0.0, None], 'LR': ['elasticnet', False, 0.0001, 42.33501859534018, True, 67.38757846654921, None, 60, 'lbfgs', 62, 'ovr', 2, False, None, 0], 'ANN': [54]}
# 0
# RF
# LR
# ANN
# building tree 1 of 119
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# building tree 2 of 119
# building tree 3 of 119
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.7s remaining:    0.0s
# building tree 4 of 119
# building tree 5 of 119
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    1.1s remaining:    0.0s
# building tree 6 of 119
# building tree 7 of 119
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    1.5s remaining:    0.0s
# building tree 8 of 119
# building tree 9 of 119
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    1.8s remaining:    0.0s
# building tree 10 of 119
# building tree 11 of 119
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    2.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    2.2s remaining:    0.0s
# building tree 12 of 119
# building tree 13 of 119
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    2.6s remaining:    0.0s
# building tree 14 of 119
# building tree 15 of 119
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    3.0s remaining:    0.0s
# building tree 16 of 119
# building tree 17 of 119
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    3.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    3.3s remaining:    0.0s
# building tree 18 of 119
# building tree 19 of 119
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    3.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    3.7s remaining:    0.0s
# building tree 20 of 119
# building tree 21 of 119
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    3.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    4.1s remaining:    0.0s
# building tree 22 of 119
# building tree 23 of 119
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    4.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    4.5s remaining:    0.0s
# building tree 24 of 119
# building tree 25 of 119
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    4.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    4.8s remaining:    0.0s
# building tree 26 of 119
# building tree 27 of 119
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    5.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    5.2s remaining:    0.0s
# building tree 28 of 119
# building tree 29 of 119
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    5.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    5.6s remaining:    0.0s
# building tree 30 of 119
# building tree 31 of 119
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:    5.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:    5.9s remaining:    0.0s
# building tree 32 of 119
# building tree 33 of 119
# building tree 34 of 119
# building tree 35 of 119
# building tree 36 of 119
# building tree 37 of 119
# building tree 38 of 119
# building tree 39 of 119
# building tree 40 of 119
# building tree 41 of 119
# building tree 42 of 119
# building tree 43 of 119
# building tree 44 of 119
# building tree 45 of 119
# building tree 46 of 119
# building tree 47 of 119
# building tree 48 of 119
# building tree 49 of 119
# building tree 50 of 119
# building tree 51 of 119
# building tree 52 of 119
# building tree 53 of 119
# building tree 54 of 119
# building tree 55 of 119
# building tree 56 of 119
# building tree 57 of 119
# building tree 58 of 119
# building tree 59 of 119
# building tree 60 of 119
# building tree 61 of 119
# building tree 62 of 119
# building tree 63 of 119
# building tree 64 of 119
# building tree 65 of 119
# building tree 66 of 119
# building tree 67 of 119
# building tree 68 of 119
# building tree 69 of 119
# building tree 70 of 119
# building tree 71 of 119
# building tree 72 of 119
# building tree 73 of 119
# building tree 74 of 119
# building tree 75 of 119
# building tree 76 of 119
# building tree 77 of 119
# building tree 78 of 119
# building tree 79 of 119
# building tree 80 of 119
# building tree 81 of 119
# building tree 82 of 119
# building tree 83 of 119
# building tree 84 of 119
# building tree 85 of 119
# building tree 86 of 119
# building tree 87 of 119
# building tree 88 of 119
# building tree 89 of 119
# building tree 90 of 119
# building tree 91 of 119
# building tree 92 of 119
# building tree 93 of 119
# building tree 94 of 119
# building tree 95 of 119
# building tree 96 of 119
# building tree 97 of 119
# building tree 98 of 119
# building tree 99 of 119
# building tree 100 of 119
# building tree 101 of 119
# building tree 102 of 119
# building tree 103 of 119
# building tree 104 of 119
# building tree 105 of 119
# building tree 106 of 119
# building tree 107 of 119
# building tree 108 of 119
# building tree 109 of 119
# building tree 110 of 119
# building tree 111 of 119
# building tree 112 of 119
# building tree 113 of 119
# building tree 114 of 119
# building tree 115 of 119
# building tree 116 of 119
# building tree 117 of 119
# building tree 118 of 119
# building tree 119 of 119
# [Parallel(n_jobs=1)]: Done 119 out of 119 | elapsed:   22.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 119 out of 119 | elapsed:    0.1s finished
# [[957 315]
#  [511 717]]
# accuracy: 0.6696
# mcc: 0.34141485198718025
# f1_score: 0.6345132743362832
# Fitness: 0.6696
# done out of 63 2
# chromosome {'ANN': [11]}
# 0
# ANN
# [[863 409]
#  [411 817]]
# accuracy: 0.672
# mcc: 0.34377868988063687
# f1_score: 0.6658516707416463
# Fitness: 0.672
# done out of 63 3
# chromosome {'SVM': [20.523462924341917, 'linear', 61, 0.001, 0.37201088387311465, True, True, 0.001, 200, None, False, -1, 'ovr', False, 7], 'KNN': [9, 'uniform', 'auto', 67, 6, 'minkowski', None, None], 'DT': ['gini', 'best', None, 4, 9, 0.0, None, None, None, 0.0, None, None, 0.0]}
# 0
# SVM
# KNN
# DT
# [[799 473]
#  [316 912]]
# accuracy: 0.6844
# mcc: 0.3729395906870161
# f1_score: 0.6980482204362802
# Fitness: 0.6844
# done out of 63 4
# chromosome {'KNN': [3, 'distance', 'auto', 99, 7, 'manhattan', None, None], 'RF': [164, 'gini', None, 10, 3, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 72, False, 'balanced', 0.0, None], 'LR': [None, True, 0.0001, 67.23036339050321, True, 50.45074585210586, None, 90, 'saga', 199, 'ovr', 4, False, None, 0]}
# 0
# KNN
# RF
# LR
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# building tree 1 of 164
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# building tree 2 of 164
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# building tree 3 of 164
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# building tree 4 of 164
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# building tree 5 of 164
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s remaining:    0.0s
# building tree 6 of 164
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.2s remaining:    0.0s
# building tree 7 of 164
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.2s remaining:    0.0s
# building tree 8 of 164
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.2s remaining:    0.0s
# building tree 9 of 164
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.2s remaining:    0.0s
# building tree 10 of 164
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.3s remaining:    0.0s
# building tree 11 of 164
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    0.3s remaining:    0.0s
# building tree 12 of 164
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.3s remaining:    0.0s
# building tree 13 of 164
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    0.3s remaining:    0.0s
# building tree 14 of 164
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.4s remaining:    0.0s
# building tree 15 of 164
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.4s remaining:    0.0s
# building tree 16 of 164
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    0.4s remaining:    0.0s
# building tree 17 of 164
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    0.4s remaining:    0.0s
# building tree 18 of 164
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    0.5s remaining:    0.0s
# building tree 19 of 164
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.5s remaining:    0.0s
# building tree 20 of 164
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    0.5s remaining:    0.0s
# building tree 21 of 164
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    0.5s remaining:    0.0s
# building tree 22 of 164
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.6s remaining:    0.0s
# building tree 23 of 164
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    0.6s remaining:    0.0s
# building tree 24 of 164
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    0.6s remaining:    0.0s
# building tree 25 of 164
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    0.6s remaining:    0.0s
# building tree 26 of 164
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    0.7s remaining:    0.0s
# building tree 27 of 164
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    0.7s remaining:    0.0s
# building tree 28 of 164
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    0.7s remaining:    0.0s
# building tree 29 of 164
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    0.7s remaining:    0.0s
# building tree 30 of 164
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    0.8s remaining:    0.0s
# building tree 31 of 164
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:    0.8s remaining:    0.0s
# building tree 32 of 164
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:    0.8s remaining:    0.0s
# building tree 33 of 164
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed:    0.8s remaining:    0.0s
# building tree 34 of 164
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed:    0.9s remaining:    0.0s
# building tree 35 of 164
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed:    0.9s remaining:    0.0s
# building tree 36 of 164
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:    0.9s remaining:    0.0s
# building tree 37 of 164
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed:    0.9s remaining:    0.0s
# building tree 38 of 164
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed:    1.0s remaining:    0.0s
# building tree 39 of 164
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed:    1.0s remaining:    0.0s
# building tree 40 of 164
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    1.0s remaining:    0.0s
# building tree 41 of 164
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed:    1.0s remaining:    0.0s
# building tree 42 of 164
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:    1.1s remaining:    0.0s
# building tree 43 of 164
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed:    1.1s remaining:    0.0s
# building tree 44 of 164
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed:    1.1s remaining:    0.0s
# building tree 45 of 164
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:    1.1s remaining:    0.0s
# building tree 46 of 164
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed:    1.1s remaining:    0.0s
# building tree 47 of 164
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed:    1.2s remaining:    0.0s
# building tree 48 of 164
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed:    1.2s remaining:    0.0s
# building tree 49 of 164
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed:    1.2s remaining:    0.0s
# building tree 50 of 164
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    1.3s remaining:    0.0s
# building tree 51 of 164
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed:    1.3s remaining:    0.0s
# building tree 52 of 164
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed:    1.3s remaining:    0.0s
# building tree 53 of 164
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed:    1.3s remaining:    0.0s
# building tree 54 of 164
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed:    1.3s remaining:    0.0s
# building tree 55 of 164
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed:    1.4s remaining:    0.0s
# building tree 56 of 164
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed:    1.4s remaining:    0.0s
# building tree 57 of 164
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed:    1.4s remaining:    0.0s
# building tree 58 of 164
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed:    1.4s remaining:    0.0s
# building tree 59 of 164
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed:    1.5s remaining:    0.0s
# building tree 60 of 164
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:    1.5s remaining:    0.0s
# building tree 61 of 164
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed:    1.5s remaining:    0.0s
# building tree 62 of 164
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed:    1.5s remaining:    0.0s
# building tree 63 of 164
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    1.6s remaining:    0.0s
# building tree 64 of 164
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    1.6s remaining:    0.0s
# building tree 65 of 164
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed:    1.6s remaining:    0.0s
# building tree 66 of 164
# [Parallel(n_jobs=1)]: Done  66 out of  66 | elapsed:    1.7s remaining:    0.0s
# building tree 67 of 164
# [Parallel(n_jobs=1)]: Done  67 out of  67 | elapsed:    1.7s remaining:    0.0s
# building tree 68 of 164
# [Parallel(n_jobs=1)]: Done  68 out of  68 | elapsed:    1.7s remaining:    0.0s
# building tree 69 of 164
# [Parallel(n_jobs=1)]: Done  69 out of  69 | elapsed:    1.7s remaining:    0.0s
# building tree 70 of 164
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed:    1.8s remaining:    0.0s
# building tree 71 of 164
# [Parallel(n_jobs=1)]: Done  71 out of  71 | elapsed:    1.8s remaining:    0.0s
# building tree 72 of 164
# building tree 73 of 164
# building tree 74 of 164
# building tree 75 of 164
# building tree 76 of 164
# building tree 77 of 164
# building tree 78 of 164
# building tree 79 of 164
# building tree 80 of 164
# building tree 81 of 164
# building tree 82 of 164
# building tree 83 of 164
# building tree 84 of 164
# building tree 85 of 164
# building tree 86 of 164
# building tree 87 of 164
# building tree 88 of 164
# building tree 89 of 164
# building tree 90 of 164
# building tree 91 of 164
# building tree 92 of 164
# building tree 93 of 164
# building tree 94 of 164
# building tree 95 of 164
# building tree 96 of 164
# building tree 97 of 164
# ...
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  66 out of  66 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  67 out of  67 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  68 out of  68 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  69 out of  69 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  71 out of  71 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 164 out of 164 | elapsed:    0.1s finished
# [[941 331]
#  [445 783]]
# accuracy: 0.6896
# mcc: 0.37959698428526767
# f1_score: 0.66865926558497
# Fitness: 0.6896
# done out of 63 5
# chromosome {'DT': ['entropy', 'best', None, 6, 9, 0.0, None, 53, None, 0.0, None, 'balanced', 0.0], 'RF': [128, 'gini', None, 8, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 11, False, 'balanced', 0.0, None], 'ANN': [11]}
# 0
# DT
# RF
# ANN
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.2s remaining:    0.0s
# building tree 1 of 128
# building tree 2 of 128
# building tree 3 of 128
# building tree 4 of 128
# building tree 5 of 128
# building tree 6 of 128
# building tree 7 of 128
# building tree 8 of 128
# building tree 9 of 128
# building tree 10 of 128
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.2s remaining:    0.0s
# building tree 11 of 128
# building tree 12 of 128
# building tree 13 of 128
# building tree 14 of 128
# building tree 15 of 128
# building tree 16 of 128
# building tree 17 of 128
# building tree 18 of 128
# building tree 19 of 128
# building tree 20 of 128
# building tree 21 of 128
# building tree 22 of 128
# building tree 23 of 128
# building tree 24 of 128
# building tree 25 of 128
# building tree 26 of 128
# building tree 27 of 128
# building tree 28 of 128
# building tree 29 of 128
# building tree 30 of 128
# building tree 31 of 128
# building tree 32 of 128
# building tree 33 of 128
# building tree 34 of 128
# building tree 35 of 128
# building tree 36 of 128
# building tree 37 of 128
# building tree 38 of 128
# building tree 39 of 128
# building tree 40 of 128
# building tree 41 of 128
# building tree 42 of 128
# building tree 43 of 128
# building tree 44 of 128
# building tree 45 of 128
# building tree 46 of 128
# building tree 47 of 128
# building tree 48 of 128
# building tree 49 of 128
# building tree 50 of 128
# building tree 51 of 128
# building tree 52 of 128
# building tree 53 of 128
# building tree 54 of 128
# building tree 55 of 128
# building tree 56 of 128
# building tree 57 of 128
# building tree 58 of 128
# building tree 59 of 128
# building tree 60 of 128
# building tree 61 of 128
# building tree 62 of 128
# building tree 63 of 128
# building tree 64 of 128
# building tree 65 of 128
# building tree 66 of 128
# building tree 67 of 128
# building tree 68 of 128
# building tree 69 of 128
# building tree 70 of 128
# building tree 71 of 128
# building tree 72 of 128
# building tree 73 of 128
# building tree 74 of 128
# building tree 75 of 128
# building tree 76 of 128
# building tree 77 of 128
# building tree 78 of 128
# building tree 79 of 128
# building tree 80 of 128
# building tree 81 of 128
# building tree 82 of 128
# building tree 83 of 128
# building tree 84 of 128
# building tree 85 of 128
# building tree 86 of 128
# building tree 87 of 128
# building tree 88 of 128
# building tree 89 of 128
# building tree 90 of 128
# building tree 91 of 128
# building tree 92 of 128
# building tree 93 of 128
# building tree 94 of 128
# building tree 95 of 128
# building tree 96 of 128
# building tree 97 of 128
# building tree 98 of 128
# building tree 99 of 128
# building tree 100 of 128
# building tree 101 of 128
# building tree 102 of 128
# building tree 103 of 128
# building tree 104 of 128
# building tree 105 of 128
# building tree 106 of 128
# building tree 107 of 128
# building tree 108 of 128
# building tree 109 of 128
# building tree 110 of 128
# building tree 111 of 128
# building tree 112 of 128
# building tree 113 of 128
# building tree 114 of 128
# building tree 115 of 128
# building tree 116 of 128
# building tree 117 of 128
# building tree 118 of 128
# building tree 119 of 128
# building tree 120 of 128
# building tree 121 of 128
# building tree 122 of 128
# building tree 123 of 128
# building tree 124 of 128
# building tree 125 of 128
# building tree 126 of 128
# building tree 127 of 128
# building tree 128 of 128
# [Parallel(n_jobs=1)]: Done 128 out of 128 | elapsed:    2.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 128 out of 128 | elapsed:    0.1s finished
# [[858 414]
#  [393 835]]
# accuracy: 0.6772
# mcc: 0.3544409334671144
# f1_score: 0.6742026645135244
# Fitness: 0.6772
# done out of 63 6
# chromosome {'RF': [151, 'gini', None, 7, 2, 0.0, 'sqrt', None, 0.0, None, False, False, None, None, 29, False, None, 0.0, None], 'LR': ['l2', False, 0.0001, 54.69859774842014, True, 15.905429432727614, 'balanced', 40, 'sag', 198, 'ovr', 16, False, None, None], 'ANN': [15]}
# 0
# RF
# LR
# ANN
# building tree 1 of 151
# building tree 2 of 151
# building tree 3 of 151
# building tree 4 of 151
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# building tree 5 of 151
# building tree 6 of 151
# building tree 7 of 151
# building tree 8 of 151
# building tree 9 of 151
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.4s remaining:    0.0s
# building tree 10 of 151
# building tree 11 of 151
# building tree 12 of 151
# building tree 13 of 151
# building tree 14 of 151
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.6s remaining:    0.0s
# building tree 15 of 151
# building tree 16 of 151
# building tree 17 of 151
# building tree 18 of 151
# building tree 19 of 151
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.8s remaining:    0.0s
# building tree 20 of 151
# building tree 21 of 151
# building tree 22 of 151
# building tree 23 of 151
# building tree 24 of 151
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    1.0s remaining:    0.0s
# building tree 25 of 151
# building tree 26 of 151
# building tree 27 of 151
# building tree 28 of 151
# building tree 29 of 151
# building tree 30 of 151
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    1.1s remaining:    0.0s
# building tree 31 of 151
# building tree 32 of 151
# building tree 33 of 151
# building tree 34 of 151
# building tree 35 of 151
# building tree 36 of 151
# building tree 37 of 151
# building tree 38 of 151
# building tree 39 of 151
# building tree 40 of 151
# building tree 41 of 151
# building tree 42 of 151
# building tree 43 of 151
# building tree 44 of 151
# building tree 45 of 151
# building tree 46 of 151
# building tree 47 of 151
# building tree 48 of 151
# building tree 49 of 151
# building tree 50 of 151
# building tree 51 of 151
# building tree 52 of 151
# building tree 53 of 151
# building tree 54 of 151
# building tree 55 of 151
# building tree 56 of 151
# building tree 57 of 151
# building tree 58 of 151
# building tree 59 of 151
# building tree 60 of 151
# building tree 61 of 151
# building tree 62 of 151
# building tree 63 of 151
# building tree 64 of 151
# building tree 65 of 151
# building tree 66 of 151
# building tree 67 of 151
# building tree 68 of 151
# building tree 69 of 151
# building tree 70 of 151
# building tree 71 of 151
# building tree 72 of 151
# building tree 73 of 151
# building tree 74 of 151
# building tree 75 of 151
# building tree 76 of 151
# building tree 77 of 151
# building tree 78 of 151
# building tree 79 of 151
# building tree 80 of 151
# building tree 81 of 151
# building tree 82 of 151
# building tree 83 of 151
# building tree 84 of 151
# building tree 85 of 151
# building tree 86 of 151
# building tree 87 of 151
# building tree 88 of 151
# building tree 89 of 151
# building tree 90 of 151
# building tree 91 of 151
# building tree 92 of 151
# building tree 93 of 151
# building tree 94 of 151
# building tree 95 of 151
# building tree 96 of 151
# building tree 97 of 151
# building tree 98 of 151
# building tree 99 of 151
# building tree 100 of 151
# building tree 101 of 151
# building tree 102 of 151
# building tree 103 of 151
# building tree 104 of 151
# building tree 105 of 151
# building tree 106 of 151
# building tree 107 of 151
# building tree 108 of 151
# building tree 109 of 151
# building tree 110 of 151
# building tree 111 of 151
# building tree 112 of 151
# building tree 113 of 151
# building tree 114 of 151
# building tree 115 of 151
# building tree 116 of 151
# building tree 117 of 151
# building tree 118 of 151
# building tree 119 of 151
# building tree 120 of 151
# building tree 121 of 151
# building tree 122 of 151
# building tree 123 of 151
# building tree 124 of 151
# building tree 125 of 151
# building tree 126 of 151
# building tree 127 of 151
# building tree 128 of 151
# building tree 129 of 151
# building tree 130 of 151
# building tree 131 of 151
# building tree 132 of 151
# building tree 133 of 151
# building tree 134 of 151
# building tree 135 of 151
# building tree 136 of 151
# building tree 137 of 151
# building tree 138 of 151
# building tree 139 of 151
# building tree 140 of 151
# building tree 141 of 151
# building tree 142 of 151
# building tree 143 of 151
# building tree 144 of 151
# building tree 145 of 151
# building tree 146 of 151
# building tree 147 of 151
# building tree 148 of 151
# building tree 149 of 151
# building tree 150 of 151
# building tree 151 of 151
# [Parallel(n_jobs=1)]: Done 151 out of 151 | elapsed:    6.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# convergence after 125 epochs took 1 seconds
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s finished

# %%
chromosome0=best_fits['0']
chromosome99=best_fits['99']

# %% [markdown]
# #validate on unseen data

# %%
print("equinox")
data = arff.loadarff('Equinox-3.4-OSA.arff')
data_value = pd.DataFrame(data[0])
PROMISE_data = data_value[:, 0:60]
PROMISE_target = data_value[:,60]
PROMISE_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(PROMISE_data)
X=PROMISE_data_minmax_scalled
y=PROMISE_target

# %%
y_pred0=model0.predict(X)
cm=confusion_matrix(y, y_pred0)
TN, FP, FN, TP = cm.ravel()
print( cm)
accuracy= (TP + TN)/(TP + TN + FP + FN)
print("accuracy:",accuracy)
mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
print("mcc:",mcc)
precision =(TP/(TP+FP))
recall= (TP/(TP+FN))
f1_score= 2 *(precision*recall)/(precision+recall)
print("f1_score:",f1_score)

# %%
y_pred99=model99.predict(X)
cm=confusion_matrix(y, y_pred99)
TN, FP, FN, TP = cm.ravel()
print( cm)
accuracy= (TP + TN)/(TP + TN + FP + FN)
print("accuracy:",accuracy)
mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
print("mcc:",mcc)
precision =(TP/(TP+FP))
recall= (TP/(TP+FN))
f1_score= 2 *(precision*recall)/(precision+recall)
print("f1_score:",f1_score)

# %%
print("Mylyn")
data = arff.loadarff('Mylyn-3.1-OSA.arff')
data_value = pd.DataFrame(data[0])
PROMISE_data = data_value[:, 0:60]
PROMISE_target = data_value[:,60]
PROMISE_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(PROMISE_data)
X=PROMISE_data_minmax_scalled
y=PROMISE_target
y_pred0=model0.predict(X)
cm=confusion_matrix(y, y_pred0)
TN, FP, FN, TP = cm.ravel()
print( cm)
accuracy= (TP + TN)/(TP + TN + FP + FN)
print("accuracy:",accuracy)
mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
print("mcc:",mcc)
precision =(TP/(TP+FP))
recall= (TP/(TP+FN))
f1_score= 2 *(precision*recall)/(precision+recall)
print("f1_score:",f1_score)

# %%
y_pred99=model99.predict(X)
cm=confusion_matrix(y, y_pred99)
TN, FP, FN, TP = cm.ravel()
print( cm)
accuracy= (TP + TN)/(TP + TN + FP + FN)
print("accuracy:",accuracy)
mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
print("mcc:",mcc)
precision =(TP/(TP+FP))
recall= (TP/(TP+FN))
f1_score= 2 *(precision*recall)/(precision+recall)
print("f1_score:",f1_score)

# %%
print("Eclipse_JDT_Core")

data = arff.loadarff('Eclipse_JDT_Core-3.4-OSA.arff')
data_value = pd.DataFrame(data[0])
PROMISE_data = data_value[:, 0:60]
PROMISE_target = data_value[:,60]
PROMISE_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(PROMISE_data)
X=PROMISE_data_minmax_scalled
y=PROMISE_target
y_pred0=model0.predict(X)
cm=confusion_matrix(y, y_pred0)
TN, FP, FN, TP = cm.ravel()
print( cm)
accuracy= (TP + TN)/(TP + TN + FP + FN)
print("accuracy:",accuracy)
mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
print("mcc:",mcc)
precision =(TP/(TP+FP))
recall= (TP/(TP+FN))
f1_score= 2 *(precision*recall)/(precision+recall)
print("f1_score:",f1_score)

# %%
y_pred99=model99.predict(X)
cm=confusion_matrix(y, y_pred99)
TN, FP, FN, TP = cm.ravel()
print( cm)
accuracy= (TP + TN)/(TP + TN + FP + FN)
print("accuracy:",accuracy)
mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
print("mcc:",mcc)
precision =(TP/(TP+FP))
recall= (TP/(TP+FN))
f1_score= 2 *(precision*recall)/(precision+recall)
print("f1_score:",f1_score)

# %%
print("all")
BugPrediction_target,BugPrediction_data_normalized,BugPrediction_data_minmax_scalled,BugPrediction_data_standardized=BugPredictionDatasetPreprocess()

# %%
X=BugPrediction_data_minmax_scalled
y=BugPrediction_target
y_pred0=model0.predict(X)
cm=confusion_matrix(y, y_pred0)
TN, FP, FN, TP = cm.ravel()
print( cm)
accuracy= (TP + TN)/(TP + TN + FP + FN)
print("accuracy:",accuracy)
mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
print("mcc:",mcc)
precision =(TP/(TP+FP))
recall= (TP/(TP+FN))
f1_score= 2 *(precision*recall)/(precision+recall)
print("f1_score:",f1_score)

# %%
y_pred99=model99.predict(X)
cm=confusion_matrix(y, y_pred99)
TN, FP, FN, TP = cm.ravel()
print( cm)
accuracy= (TP + TN)/(TP + TN + FP + FN)
print("accuracy:",accuracy)
mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
print("mcc:",mcc)
precision =(TP/(TP+FP))
recall= (TP/(TP+FN))
f1_score= 2 *(precision*recall)/(precision+recall)
print("f1_score:",f1_score)
