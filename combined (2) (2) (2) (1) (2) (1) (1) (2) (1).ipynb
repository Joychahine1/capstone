# %% [markdown]
# enerate random parameters

# %%
#Install a conda package in the current Jupyter kernel

import sys
# !conda install --yes --prefix {sys.prefix} pandas
# !conda install --yes --prefix {sys.prefix} keras
# !conda install --yes --prefix {sys.prefix} scikit-learn 

from keras.wrappers.scikit_learn import KerasClassifier
from itertools import combinations
from math import sqrt, isnan
from scipy.io import arff	
from sklearn.metrics import f1_score as f1
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, matthews_corrcoef
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn import preprocessing
import numpy as np
import random
import pandas as pd
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - keras
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     absl-py-0.11.0             |   py37h89c1867_0         168 KB  conda-forge
#     astor-0.8.1                |     pyh9f0ad1d_0          25 KB  conda-forge
#     binutils_impl_linux-64-2.31.1|       h6176602_1         3.9 MB  defaults
#     binutils_linux-64-2.31.1   |       h6176602_9          26 KB  defaults
#     c-ares-1.17.1              |       h36c2ea0_0         111 KB  conda-forge
#     cached-property-1.5.1      |             py_0          10 KB  conda-forge
#     gast-0.4.0                 |     pyh9f0ad1d_0          12 KB  conda-forge
#     gcc_impl_linux-64-7.3.0    |       habb00fd_1        41.9 MB  defaults
#     gcc_linux-64-7.3.0         |       h553295d_9          27 KB  defaults
#     google-pasta-0.2.0         |     pyh8c360ce_0          42 KB  conda-forge
#     grpcio-1.34.1              |   py37hb27c1af_0         2.0 MB  conda-forge
#     gxx_impl_linux-64-7.3.0    |       hdf63c60_1        15.0 MB  defaults
#     gxx_linux-64-7.3.0         |       h553295d_9          26 KB  defaults
#     h5py-3.1.0                 |nompi_py37h1e651dc_100         1.2 MB  conda-forge
#     hdf5-1.10.6                |nompi_h6a2412b_1114         3.1 MB  conda-forge
#     keras-2.3.1                |           py37_0         591 KB  conda-forge
#     keras-applications-1.0.8   |             py_1          30 KB  conda-forge
#     keras-preprocessing-1.1.2  |     pyhd8ed1ab_0          34 KB  conda-forge
#     libgpuarray-0.7.6          |    h14c3975_1003         263 KB  conda-forge
#     libpng-1.6.37              |       h21135ba_2         306 KB  conda-forge
#     libprotobuf-3.14.0         |       h780b84a_0         2.5 MB  conda-forge
#     markdown-3.3.3             |     pyh9f0ad1d_0          66 KB  conda-forge
#     protobuf-3.14.0            |   py37hcd2ae1e_1         342 KB  conda-forge
#     pygpu-0.7.6                |py37h902c9e0_1002         663 KB  conda-forge
#     pyyaml-5.3.1               |   py37h5e8e339_2         199 KB  conda-forge
#     tensorboard-1.14.0         |           py37_0         3.2 MB  conda-forge
#     tensorflow-1.14.0          |       h4531e10_0          23 KB  conda-forge
#     tensorflow-base-1.14.0     |   py37h4531e10_0        87.6 MB  conda-forge
#     tensorflow-estimator-1.14.0|   py37h5ca1d4c_0         645 KB  conda-forge
#     termcolor-1.1.0            |             py_2           6 KB  conda-forge
#     theano-1.0.5               |   py37h745909e_1         3.7 MB  conda-forge
#     werkzeug-1.0.1             |     pyh9f0ad1d_0         239 KB  conda-forge
#     wrapt-1.12.1               |   py37h5e8e339_3          47 KB  conda-forge
#     yaml-0.2.5                 |       h516909a_0          82 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       168.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   absl-py            conda-forge/linux-64::absl-py-0.11.0-py37h89c1867_0
#   astor              conda-forge/noarch::astor-0.8.1-pyh9f0ad1d_0
#   binutils_impl_lin~ pkgs/main/linux-64::binutils_impl_linux-64-2.31.1-h6176602_1
#   binutils_linux-64  pkgs/main/linux-64::binutils_linux-64-2.31.1-h6176602_9
#   c-ares             conda-forge/linux-64::c-ares-1.17.1-h36c2ea0_0
#   cached-property    conda-forge/noarch::cached-property-1.5.1-py_0
#   gast               conda-forge/noarch::gast-0.4.0-pyh9f0ad1d_0
#   gcc_impl_linux-64  pkgs/main/linux-64::gcc_impl_linux-64-7.3.0-habb00fd_1
#   gcc_linux-64       pkgs/main/linux-64::gcc_linux-64-7.3.0-h553295d_9
#   google-pasta       conda-forge/noarch::google-pasta-0.2.0-pyh8c360ce_0
#   grpcio             conda-forge/linux-64::grpcio-1.34.1-py37hb27c1af_0
#   gxx_impl_linux-64  pkgs/main/linux-64::gxx_impl_linux-64-7.3.0-hdf63c60_1
#   gxx_linux-64       pkgs/main/linux-64::gxx_linux-64-7.3.0-h553295d_9
#   h5py               conda-forge/linux-64::h5py-3.1.0-nompi_py37h1e651dc_100
#   hdf5               conda-forge/linux-64::hdf5-1.10.6-nompi_h6a2412b_1114
#   keras              conda-forge/linux-64::keras-2.3.1-py37_0
#   keras-applications conda-forge/noarch::keras-applications-1.0.8-py_1
#   keras-preprocessi~ conda-forge/noarch::keras-preprocessing-1.1.2-pyhd8ed1ab_0
#   libgpuarray        conda-forge/linux-64::libgpuarray-0.7.6-h14c3975_1003
#   libpng             conda-forge/linux-64::libpng-1.6.37-h21135ba_2
#   libprotobuf        conda-forge/linux-64::libprotobuf-3.14.0-h780b84a_0
#   markdown           conda-forge/noarch::markdown-3.3.3-pyh9f0ad1d_0
#   protobuf           conda-forge/linux-64::protobuf-3.14.0-py37hcd2ae1e_1
#   pygpu              conda-forge/linux-64::pygpu-0.7.6-py37h902c9e0_1002
#   pyyaml             conda-forge/linux-64::pyyaml-5.3.1-py37h5e8e339_2
#   tensorboard        conda-forge/linux-64::tensorboard-1.14.0-py37_0
#   tensorflow         conda-forge/linux-64::tensorflow-1.14.0-h4531e10_0
#   tensorflow-base    conda-forge/linux-64::tensorflow-base-1.14.0-py37h4531e10_0
#   tensorflow-estima~ conda-forge/linux-64::tensorflow-estimator-1.14.0-py37h5ca1d4c_0
#   termcolor          conda-forge/noarch::termcolor-1.1.0-py_2
#   theano             conda-forge/linux-64::theano-1.0.5-py37h745909e_1
#   werkzeug           conda-forge/noarch::werkzeug-1.0.1-pyh9f0ad1d_0
#   wrapt              conda-forge/linux-64::wrapt-1.12.1-py37h5e8e339_3
#   yaml               conda-forge/linux-64::yaml-0.2.5-h516909a_0
#
#
#
# Downloading and Extracting Packages
# markdown-3.3.3       | 66 KB     | ##################################### | 100%
# pyyaml-5.3.1         | 199 KB    | ##################################### | 100%
# libgpuarray-0.7.6    | 263 KB    | ##################################### | 100%
# hdf5-1.10.6          | 3.1 MB    | ##################################### | 100%
# keras-2.3.1          | 591 KB    | ##################################### | 100%
# absl-py-0.11.0       | 168 KB    | ##################################### | 100%
# tensorflow-1.14.0    | 23 KB     | ##################################### | 100%
# protobuf-3.14.0      | 342 KB    | ##################################### | 100%
# yaml-0.2.5           | 82 KB     | ##################################### | 100%
# h5py-3.1.0           | 1.2 MB    | ##################################### | 100%
# keras-applications-1 | 30 KB     | ##################################### | 100%
# tensorflow-base-1.14 | 87.6 MB   | ##################################### | 100%
# grpcio-1.34.1        | 2.0 MB    | ##################################### | 100%
# tensorboard-1.14.0   | 3.2 MB    | ##################################### | 100%
# c-ares-1.17.1        | 111 KB    | ##################################### | 100%
# gxx_impl_linux-64-7. | 15.0 MB   | ##################################### | 100%
# binutils_impl_linux- | 3.9 MB    | ##################################### | 100%
# termcolor-1.1.0      | 6 KB      | ##################################### | 100%
# gcc_impl_linux-64-7. | 41.9 MB   | ##################################### | 100%
# binutils_linux-64-2. | 26 KB     | ##################################### | 100%
# gxx_linux-64-7.3.0   | 26 KB     | ##################################### | 100%
# astor-0.8.1          | 25 KB     | ##################################### | 100%
# cached-property-1.5. | 10 KB     | ##################################### | 100%
# google-pasta-0.2.0   | 42 KB     | ##################################### | 100%
# wrapt-1.12.1         | 47 KB     | ##################################### | 100%
# pygpu-0.7.6          | 663 KB    | ##################################### | 100%
# theano-1.0.5         | 3.7 MB    | ##################################### | 100%
# keras-preprocessing- | 34 KB     | ##################################### | 100%
# libprotobuf-3.14.0   | 2.5 MB    | ##################################### | 100%
# gcc_linux-64-7.3.0   | 27 KB     | ##################################### | 100%
# libpng-1.6.37        | 306 KB    | ##################################### | 100%
# gast-0.4.0           | 12 KB     | ##################################### | 100%
# werkzeug-1.0.1       | 239 KB    | ##################################### | 100%
# tensorflow-estimator | 645 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
# Using TensorFlow backend.
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def SVM_params():
    list_of_parameters= ["C", "kernel", "degree", "gamma","coef0","shrinking","probability","tol","cache_size","class_weight", "verbose","max_iter", "decision_function_shape",
                         "break_ties"]
    default_values=[1.0, "rbf", 3,"scale", 0.0, True, False, 0.001, 200, None, False, -1, 'ovr', False, None]
    return default_values

# %%
def SVM_paramsRandom():
    kernel = ['linear', 'poly', 'rbf', 'sigmoid']
    kernel_index = random.randint(0, len(kernel)-1)
    TF=[True, False]
    BN=["balanced", None]
    RN=[random.randint(0, 100), None]
    list_of_parameters= ["C", "kernel", "degree", "gamma","coef0","shrinking","probability","tol","cache_size","class_weight", "verbose","max_iter",
                         "decision_function_shape", "break_ties"]
    random_values=[random.uniform(0,100), kernel[kernel_index], random.randint(0,100), 0.001, random.uniform(0, 1),
                    TF[random.randint(0,len(TF)-1)], TF[random.randint(0,len(TF)-1)], 0.001, 200,
                    BN[random.randint(0,len(BN)-1)], TF[random.randint(0,len(TF)-1)], -1, 'ovr',
                   False,  RN[random.randint(0,len(RN)-1)]]
    return random_values
def KNN_params():
    list_of_parameters= ["n_neighbors", "weights", "algorithm", "leaf_size", "p", "metric", "metric_params", "n_jobs" ]
    default_values=[5, 'uniform', 'auto', 30, 2, 'minkowski', None, None]
    return default_values
def KNN_paramsRandom():
    weights=['uniform', "distance"]
    metric=['minkowski', 'euclidean', 'manhattan']
    list_of_parameters= ["n_neighbors", "weights", "algorithm", "leaf_size", "p", "metric", "metric_params", "n_jobs" ]
    random_values=[random.randint(1,10),weights[random.randint(0, len(weights)-1)], 'auto',
                   random.randint(30,100), random.randint(2,10), metric[random.randint(0, len(metric)-1)], None, None]
    return random_values
def LR_params():
    list_of_parameters= ["penalty","dual", "tol", "C", "fit_intercept","intercept_scaling", "class_weight", "random_state", "solver","max_iter",
                         "multi_class", "verbose", "warm_start", "n_jobs", "l1_ratio"]
    default_values=[ 'l2',False, 0.0001,1.0, True, 1, None, None, 'lbfgs', 100, 'auto', 0, False, None, None]
    return default_values
def LR_paramsRandom():
    penalty=['l1', 'l2', 'elasticnet', None]
    TF=[True, False]
    BN=["balanced", None]
    RN=[random.randint(0, 100), None]
    l1_ratio=[0,1, random.uniform(0,1),None]
    solver=['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
    s= solver[random.randint(0,len(solver)-1)]
    if(s=="lbgs" or s=='sag'):
        p='l2'
    else:
        p=penalty[random.randint(0,len(penalty)-1)]
    list_of_parameters= ["penalty","dual", "tol", "C", "fit_intercept","intercept_scaling", "class_weight",
                         "random_state", "solver","max_iter", "multi_class", "verbose", "warm_start", "n_jobs",
                         "l1_ratio"]
    random_values=[ p,TF[random.randint(0,len(TF)-1)], 0.0001,
                     random.uniform(0,100), True, random.uniform(0,100), BN[random.randint(0,len(BN)-1)],
                     RN[random.randint(0,len(RN)-1)], s, random.randint(50,200),
                     'ovr', random.randint(0,20), TF[random.randint(0,len(TF)-1)],
                     None, l1_ratio[random.randint(0,len(l1_ratio)-1)]]
    return random_values
def RF_params():
    list_of_parameters= ["n_estimators", "criterion", "max_depth", "min_samples_split", "min_samples_leaf", "min_weight_fraction_leaf", "max_features","max_leaf_nodes", "min_impurity_decrease",
                                          "min_impurity_split","bootstrap", "oob_score", "n_jobs", "random_state", "verbose", "warm_start","class_weight", "ccp_alpha", "max_samples"]
    default_values=[100,"gini",None, 2, 1, 0.0,"auto",None,0.0, None, True, False,None,None, 0, False,None,0.0,None ]
    return default_values
def RF_paramsRandom():
    criterion =["gini", "entropy"]
    max_features=['auto', 'sqrt', 'log2',None]
    BN= ['balanced', 'balanced_subsample', None]
    RN=[random.randint(0,100), None]
    TF=[True,False]
    list_of_parameters= ["n_estimators", "criterion", "max_depth", "min_samples_split", "min_samples_leaf",
                         "min_weight_fraction_leaf", "max_features","max_leaf_nodes", "min_impurity_decrease",
                         "min_impurity_split","bootstrap", "oob_score", "n_jobs", "random_state", "verbose",
                         "warm_start","class_weight", "ccp_alpha", "max_samples"]
    random_values=[random.randint(100,200),criterion[random.randint(0,len(criterion)-1)],None,
                   random.randint(2,10),random.randint(1,10),
                   0.0,max_features[random.randint(0,len(max_features)-1)],
                   None,0.0, None, TF[random.randint(0,len(TF)-1)], False,None,
                   RN[random.randint(0,len(RN)-1)],random.randint(0,100), False,
                   BN[random.randint(0,len(BN)-1)],0.0,None ]
    return random_values
def DT_params():
    list_of_parameters= ["criterion","splitter","max_depth","min_samples_split","min_samples_leaf","min_weight_fraction_leaf","max_features",
                         "random_state","max_leaf_nodes","min_impurity_decrease","class_weight","ccp_alpha" ]
    default_values=["gini","best",None, 2, 1, 0.0,None, None,None,0.0,None,None,0.0]
    return default_values
def DT_paramsRandom():
    criterion =["gini", "entropy"]
    BN= ['balanced', None]
    RN=[random.randint(0,100), None]
    list_of_parameters= ["criterion","splitter","max_depth","min_samples_split","min_samples_leaf","min_weight_fraction_leaf","max_features",
                         "random_state","max_leaf_nodes","min_impurity_decrease","class_weight","ccp_alpha" ]
    random_values=[criterion[random.randint(0,len(criterion)-1)],"best",None,
                   random.randint(2, 10), random.randint(1, 10),0.0,None, RN[random.randint(0,len(RN)-1)],None,0.0,None,
                   BN[random.randint(0,len(BN)-1)],0.0]
    return random_values
def ANN_params():
    return ""
def ANN_paramsRandom():
    return [random.randint(10,100)]
#these functions split the datasets into target and data and return the preprocessed form
def BugCatcherDatasetPreprocess():
    data = arff.loadarff('Bugcatchers-unified-file.arff')
    BugCatchers= pd.DataFrame(data[0])
    BugCatchers_data=BugCatchers.iloc[:, 0:6]
    BugCatchers_target = BugCatchers.iloc[:, 16]

    label_encoder = preprocessing.LabelEncoder()
    label_encoder.fit(BugCatchers_target)
    BugCatchers_target=label_encoder.transform(BugCatchers_target)
    BugCatchers_data_normalized = preprocessing.normalize(BugCatchers_data)
    BugCatchers_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(BugCatchers_data)
    BugCatchers_data_standardized= preprocessing.StandardScaler().fit_transform(BugCatchers_data)
    print( "Bug Catchers dataset is preprocessed \n")
    return BugCatchers_target,BugCatchers_data_normalized,BugCatchers_data_minmax_scalled,BugCatchers_data_standardized
def PromiseDatasetPreprocess():
    data = arff.loadarff('PROMISE-unified-class.arff')
    PROMISE = pd.DataFrame(data[0])
    PROMISE_data = PROMISE.iloc[:, 0:60]
    PROMISE_target = PROMISE.iloc[:, 80]

    label_encoder = preprocessing.LabelEncoder()
    label_encoder.fit(PROMISE_target)
    PROMISE_target=label_encoder.transform(PROMISE_target)
    PROMISE_data_normalized = preprocessing.normalize(PROMISE_data)
    PROMISE_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(PROMISE_data)
    PROMISE_data_standardized= preprocessing.StandardScaler().fit_transform(PROMISE_data)
    print("PROMISE dataset is preprocessed \n")
    return PROMISE_target,PROMISE_data_normalized,PROMISE_data_minmax_scalled,PROMISE_data_standardized
def EclipseDatasetPreprocess():
    data = arff.loadarff('Zimmerman-unified-file.arff')
    Eclipse= pd.DataFrame(data[0])
    Eclipse_data=Eclipse.iloc[:, 0:6]
    Eclipse_target = Eclipse.iloc[:, 204]

    label_encoder = preprocessing.LabelEncoder()
    label_encoder.fit(Eclipse_target)
    Eclipse_target=label_encoder.transform(Eclipse_target)
    Eclipse_data_normalized = preprocessing.normalize(Eclipse_data)
    Eclipse_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(Eclipse_data)
    Eclipse_data_standardized= preprocessing.StandardScaler().fit_transform(Eclipse_data)
    print("Eclipse dataset is preprocessed \n")
    return Eclipse_target, Eclipse_data_normalized,Eclipse_data_minmax_scalled,Eclipse_data_standardized
def BugPredictionDatasetPreprocess():
    data = arff.loadarff('BugPrediction-unified-class.arff')
    BugPrediction= pd.DataFrame(data[0])
    BugPrediction_data=BugPrediction.iloc[:, 0:60]
    BugPrediction_target = BugPrediction.iloc[:, 97]

    label_encoder = preprocessing.LabelEncoder()
    label_encoder.fit(BugPrediction_target)
    BugPrediction_target=label_encoder.transform(BugPrediction_target)
    BugPrediction_data_normalized = preprocessing.normalize(BugPrediction_data)
    BugPrediction_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(BugPrediction_data)
    BugPrediction_data_standardized= preprocessing.StandardScaler().fit_transform(BugPrediction_data)
    print( "Bug Prediction dataset is preprocessed \n")
    return BugPrediction_target,BugPrediction_data_normalized,BugPrediction_data_minmax_scalled,BugPrediction_data_standardized
def GitHubFileDatasetPreprocess():
    data = arff.loadarff('GitHub-unified-file.arff')
    GitHub_File= pd.DataFrame(data[0])
    GitHub_File_data=GitHub_File.iloc[:, 0:6]
    GitHub_File_target = GitHub_File.iloc[:, 10]

    label_encoder = preprocessing.LabelEncoder()
    label_encoder.fit(GitHub_File_target)
    GitHub_File_target=label_encoder.transform(GitHub_File_target)
    GitHub_File_data_normalized = preprocessing.normalize(GitHub_File_data)
    GitHub_File_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(GitHub_File_data)
    GitHub_File_data_standardized= preprocessing.StandardScaler().fit_transform(GitHub_File_data)
    print( "GitHub File dataset is preprocessed \n")
    return GitHub_File_target,GitHub_File_data_normalized,GitHub_File_data_minmax_scalled,GitHub_File_data_standardized
def GitHubClassDatasetPreprocess():
    data = arff.loadarff('GitHub-unified-class.arff')
    GitHub_class= np.array(dataset['data'])
    GitHub_class_data=GitHub_class.iloc[:, 0:60]
    GitHub_class_target = GitHub_class.iloc[:, 60]
    GitHub_class_data=data

    label_encoder = preprocessing.LabelEncoder()
    label_encoder.fit(GitHub_class_target)
    GitHub_class_target=label_encoder.transform(GitHub_class_target)
    GitHub_class_data_normalized = preprocessing.normalize(GitHub_class_data)
    GitHub_class_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(GitHub_class_data)
    GitHub_class_data_standardized= preprocessing.StandardScaler().fit_transform(GitHub_class_data)
    print( "GitHub Class dataset is preprocessed \n")
    return GitHub_class_target,GitHub_class_data_normalized,GitHub_class_data_minmax_scalled,GitHub_class_data_standardized

# %%
BugPrediction_target,BugPrediction_data_normalized,BugPrediction_data_minmax_scalled,BugPrediction_data_standardized=BugPredictionDatasetPreprocess()
PROMISE_target,PROMISE_data_normalized,PROMISE_data_minmax_scalled,PROMISE_data_standardized=PromiseDatasetPreprocess()
# Out:
# Bug Prediction dataset is preprocessed
#
# PROMISE dataset is preprocessed

# %%
X=PROMISE_data_normalized
y=PROMISE_target
def balanced_subsample(X,y,  min_elems = 5000):
    #return a balnced subsample of min_elems of each class
    x=[]
    y_s=[]
    for yi in np.unique(y):
        elems = X[(y == yi)]
        np.random.shuffle(elems)
        for e in elems[0:min_elems,:]:
            xx=[]
            for c in e:
                xx.append(c)
            x.append(xx)
        for e in range(0,min_elems):
            y_s.append(0 if yi == 0 else 1)
    return x,y_s

# %%
def generateInitialPopulation(SVM=1, KNN=1, DT=1, RF=1, LR=1, ANN=1):
    included_clf=["SVM", "KNN", "DT", "RF", "LR", "ANN"]
    included=[1,1,1,1,1,1]
    if(SVM==0):
        included[0]=0
    if (KNN == 0):
        included[1] = 0
    if (DT == 0):
        included[2] = 0
    if (RF == 0):
        included[3] = 0
    if (LR == 0):
        included[4] = 0
    if (ANN == 0):
        included[5] = 0
    in_use=[]
    combinations_of_clf=[]
    for i in range(6):
        if(included[i]==1):
            in_use.append(included_clf[i])
    #generate diffrent combinations
    for i in range(len(in_use)+1):
        comb= combinations(in_use,i)
        for j in list(comb):
            element=[]
            for k in range(len(j)):
                element.append(j[k])
            if element!=[]:
                combinations_of_clf.append( element)
    population = []
    # generate random paramters for all diffrent combinations
    for combination in list(combinations_of_clf):
        chromosome = {}
        for clf in list(combination):
            genes=[]
            if(clf=="SVM"):
                genes= SVM_paramsRandom()
                chromosome["SVM"]=genes
            if (clf == "LR"):
                genes = LR_paramsRandom()
                chromosome["LR"]=genes
            if (clf == "KNN"):
                genes = KNN_paramsRandom()
                chromosome["KNN"]=genes
            if (clf == "RF"):
                genes = RF_paramsRandom()
                chromosome["RF"]=genes
            if (clf == "DT"):
                genes = DT_paramsRandom()
                chromosome["DT"]=genes
            if (clf == "ANN"):
                genes = ANN_paramsRandom()
                chromosome["ANN"]=genes
        if population != None:
            population.append(chromosome)
        else:
            population=chromosome
        #combine into one population and return
    return population

# %%
def crossover(parent1, parent2):
    #Generate random indices
    index1 = random.randint(0, len(parent1) - 1)
    index2 = random.randint(0, len(parent2) - 1)
    offspring1={}
    #create offspring from 0 to index1 of parent 1 and index2 till the end of parent 2
    for i in range(0,index1):
        key = list(parent1)[i]
        if (offspring1 != {}):
            count = 0
            keytoadd =key.split('-')[0]
            while keytoadd in offspring1.keys():
                count+=1
                keytoadd = key.split('-')[0] + "-" + str(count)
            offspring1[keytoadd] = parent1[key]
        else:
            offspring1[key] = parent1[key]
    for j in range(index2,len(parent2)):
        key = list(parent2)[j]
        if (offspring1 != {}):
            count = 0
            keytoadd =key.split('-')[0]
            while keytoadd in offspring1.keys():
                count+=1
                keytoadd = key.split('-')[0] + "-" + str(count)
            offspring1[keytoadd] = parent2[key]
        else:
            offspring1[key] = parent2[key]

    #create offspring from 0 to index2 of parent 2 and index1 till the end of parent 1
    offspring2={}
    for i in range(0,index2):
        key = list(parent2)[i]
        if(offspring2!={}):
            count = 0
            keytoadd =key.split('-')[0]
            while keytoadd in offspring2.keys():
                count+=1
                keytoadd=key.split('-')[0]+"-"+str(count)
            offspring2[keytoadd] = parent2[key]
        else:
             offspring2[key]=parent2[key]
    for j in range(index1,len(parent1)):
        key = list(parent1)[j]
        if (offspring2 != {}):
            count = 0
            keytoadd =key.split('-')[0]
            while keytoadd in offspring2.keys():
                count+=1
                keytoadd = key.split('-')[0] + "-" + str(count)
            offspring2[keytoadd] = parent1[key]
        else:
            offspring2[key] = parent1[key]
    print("offspring1",offspring1)
    print("offspring2",offspring2)
    return offspring1, offspring2

# %%
def ANN_model(num=50):
    from keras.models import Sequential
    from keras.layers import Dense
    #create an ANN
    model =Sequential()
    model.add(Dense(num, activation='relu', input_shape=[60]))
    model.add(Dense(int(num/2),activation='relu'))
    model.add(Dense(2, activation='sigmoid'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics= ['accuracy'])
    return model

# %%
def fitness(chromosome,X_train,y_train,X_test,y_test,alpha=1, beta=0,gamma=0, ensemble="vote" ,count=0,gen=0):
    fitness=0
    clfs={}
    for gene in chromosome:
        # Check the gene classifier and creates a model from the paramters
        params = chromosome[gene]
        gene1=gene
        if(len(gene.split('-'))>1):
            genecount=gene.split('-')[1]
            print(genecount)
        else:
            genecount=None
        gene=gene.split('-')[0]
        clf1=gene
        if(genecount==None or genecount!='0'):
            if gene=="SVM":
                clf1=SVC(C=params[0], kernel=params[1], degree=params[2], gamma=params[3],
                        coef0=params[4], shrinking=params[5], probability=True,
                        tol=params[7], cache_size=params[8], class_weight=params[9], verbose=params[10], max_iter=params[11],
                        decision_function_shape=params[12])
            if gene=="KNN":
                clf1=KNeighborsClassifier(n_neighbors=params[0], weights=params[1], algorithm=params[2],
                                         leaf_size=params[3], p=params[4], metric=params[5],
                                         metric_params=params[6], n_jobs=1)
            if gene=="DT":
                clf1=DecisionTreeClassifier(criterion=params[0], splitter=params[1], max_depth=params[2],
                                            min_samples_split=params[3], min_samples_leaf=params[4],
                                            min_weight_fraction_leaf=params[5], max_features=params[6],
                                            random_state=params[7], max_leaf_nodes=params[8], min_impurity_decrease=params[9],
                                            min_impurity_split=params[10], class_weight=params[11])
            if gene == "RF":
                clf1 = RandomForestClassifier(n_estimators=params[0], criterion=params[1], max_depth=params[2],
                                              min_samples_split=params[3], min_samples_leaf=params[4],
                                              min_weight_fraction_leaf=params[5], max_features=params[6],
                                              max_leaf_nodes=params[7], min_impurity_decrease=params[8],
                                              min_impurity_split=params[9],
                                              bootstrap=params[10], oob_score=params[11], n_jobs=1,
                                              random_state=params[13], verbose=params[14], warm_start=params[15],
                                              class_weight=params[16])
            if gene=="LR":
                clf1=LogisticRegression(penalty='l2',dual=False, tol=params[2], C=params[3], fit_intercept=params[4],
                                       intercept_scaling=params[5], class_weight=params[6], random_state=params[7], solver=params[8],
                                       max_iter=params[9], multi_class=params[10], verbose=params[11], warm_start=params[12], n_jobs=1,
                                      )
            if gene=="ANN":
                clf1 =KerasClassifier(build_fn=ANN_model,num=params[0], epochs=500, verbose=False)
                clf1._estimator_type = "classifier"
            clfs[gene1]=clf1
    estimators=[]
    for clf in clfs:
        print(clf)
        estimators.append((clf,clfs[clf]))
    if(len(estimators)>0):
        eclf = VotingClassifier(estimators, voting='hard',flatten_transform=True)
        eclf.fit(X_train,y_train)
        y_pred=eclf.predict(X_test)

        #Get confusion matrix and calculate the ACC, MCC AND F1
        cm=confusion_matrix(y_test, y_pred)
        TN, FP, FN, TP = cm.ravel()
        print( cm)
        accuracy= (TP + TN)/(TP + TN + FP + FN)
        print("accuracy:",accuracy)
        mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
        print("mcc:",mcc)
        precision =(TP/(TP+FP))
        recall= (TP/(TP+FN))
        f1_score= 2 *(precision*recall)/(precision+recall)
        print("f1_score:",f1_score)
        if isnan(accuracy) or isnan(f1_score):
            accuracy=0
        if isnan(mcc):
            mcc=0
        if isnan(f1_score):
            f1_score=0
        fitness=(((alpha*accuracy)+ (beta*mcc)+(gamma*f1_score)))
        print("Fitness:",fitness)
        return fitness, {"mcc":[mcc],"acc":[accuracy],"f1":[f1_score],"cm":[cm]},eclf
    else:
        return 0,{},None

# %%
def rename(old_dict,old_name,new_name):
    new_dict = {}
    for key,value in zip(old_dict.keys(),old_dict.values()):
        new_key = key if key != old_name else new_name
        new_dict[new_key] = old_dict[key]
    return new_dict

# %%
def Mutation(chromosome,X_train,y_train,X_val,y_val):
    #Generate random index and set to 0 or 1 accordingly
    threshold = random.uniform(0, 1)
    index= random.randint(0,len(chromosome)-1)
    if(threshold<=0.5):
        if len(list(chromosome)[index].split('-'))==1:
            print("set to 0")
            chromosome= rename(chromosome,list(chromosome)[index], list(chromosome)[index]+"-0")
        elif(( len(list(chromosome)[index].split('-'))>1 and list(chromosome)[index].split('-')[1]=='0') or (len(list(chromosome)[index].split('-'))>2 and (list(chromosome)[index].split('-'))[2]=='0') ):
            print("set to 1")
            count = 0
            key=list(chromosome)[index].split('-')[0]
            keytoadd = key
            while keytoadd in chromosome.keys():
                count+=1
                keytoadd = key + "-" + str(count)
            chromosome =rename(chromosome,list(chromosome)[index], keytoadd)
        else:
            print("set to 0")
            chromosome = rename(chromosome, list(chromosome)[index], list(chromosome)[index] + "-0")
    else:
        print(index)
        gene = list(chromosome)[index]
        print(gene)
        clf1 = gene
        options = []
        gene1 = list(chromosome)[index]
        gene=list(chromosome)[index].split('-')[0]
        if gene == "SVM" or gene == "KNN" or gene == "DT" or gene == "RF" or gene == "LR" or gene == "ANN":
            if gene == "SVM" or gene == "SVM-0":
                clf1 = SVC()
                c = list(range(1, 1000))
                c.append(0.01)
                c.append(0.1)
                params = {'C': c, 'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
                          "degree": list(range(0, 100)), 'gamma': [1e-3, 1e-4],
                          "coef0": [x * 0.1 for x in range(0, 10)],
                          'class_weight': [{0: 0.01}, {1: 1}, {1: 2}, {1: 10}, {1: 50}, 'balanced']}
            if gene == "KNN" or gene == "KNN-0":
                clf1 = KNeighborsClassifier()
                params = {"n_neighbors": list(range(1, 50)), "weights": ['uniform', "distance"],
                          "leaf_size": list(range(1, 100)), "p": [1, 2],
                          "metric": ['minkowski', 'euclidean', 'manhattan']}
            if gene == "DT" or gene == "DT-0":
                clf1 = DecisionTreeClassifier()
                BN = ['balanced', None]
                RN = [random.randint(0, 100), None]
                max_features = ['auto', 'sqrt']
                max_depth = [int(x) for x in np.linspace(10, 110, num=11)]
                max_depth.append(None)
                min_samples_split = list(range(2, 10))
                min_samples_leaf = list(range(1, 6))
                params = {"criterion": ["gini", "entropy"],
                          'max_features': max_features,
                          'max_depth': max_depth,
                          'min_samples_split': min_samples_split,
                          'min_samples_leaf': min_samples_leaf,
                          }
            if gene == "RF" or gene == "RF-0":
                clf1 = RandomForestClassifier()
                n_estimators = [int(x) for x in np.linspace(start=200, stop=2000, num=10)]
                max_features = ['auto', 'sqrt']
                max_depth = [int(x) for x in np.linspace(10, 110, num=11)]
                max_depth.append(None)
                min_samples_split = list(range(2, 10))
                min_samples_leaf = list(range(1, 4))
                bootstrap = [True, False]
                params = {"criterion": ["gini", "entropy"],
                          'n_estimators': n_estimators,
                          'max_features': max_features,
                          'max_depth': max_depth,
                          'min_samples_split': min_samples_split,
                          'min_samples_leaf': min_samples_leaf,
                          'bootstrap': bootstrap}
            if gene == "LR" or gene == "LR-0":
                clf1 = LogisticRegression()
                c = list(range(1, 1000))
                c.append(0.1)
                c.append(0.001)
                params = {'solver': ['newton-cg', 'lbfgs', 'liblinear'],
                          'penalty': ['l2'],
                          'C': c}
            if gene == "ANN" or gene == "ANN-0":
                params = {"num": list(range(2, 100)), "epochs": list(range(400, 600))}
                clf1 = KerasClassifier(build_fn=ANN_model, epochs=500, verbose=False)
                clf1._estimator_type = "classifier"
            print(clf1)
            randomclf = RandomizedSearchCV(estimator=clf1, param_distributions=params,
                                           n_iter=len(params), cv=5, verbose=2, random_state=42,
                                           n_jobs=1)
            search = randomclf.fit(X_train, y_train)
            param = search.cv_results_
            options = param['params']
        if gene1 == "SVM-0" or gene1 == "KNN-0" or gene1 == "DT-0" or gene1 == "RF-0" or gene1 == "LR-0" or gene1 == "ANN-0":
            options.append(None)
        clfs = {}
        eclfs = {}
        ocount = 0
        fop = {}
        ecount = 0
        # for all other calssifers get the parameters from the chromosomes and generate a new model
        for option in options:
            op = {}
            count = 0
            for gene in chromosome:
                op1 = {}
                params = chromosome[gene]
                clf1 = gene
                if count == index:
                    if option == None:
                        clf1 = None
                    if option != None:
                        gene1=gene
                        gene=gene.split('-')[0]
                        print(gene)
                        if gene == "SVM" or gene == "SVM-0":
                            clf1 = SVC(C=option["C"], kernel=option["kernel"], degree=option["degree"],
                                       gamma=option["gamma"],
                                       coef0=option["coef0"], shrinking=params[5], probability=True,
                                       tol=params[7], cache_size=params[8], class_weight=option["class_weight"],
                                       verbose=params[10],
                                       max_iter=params[11],
                                       decision_function_shape=params[12])
                            # clf1 = SVC(C=option["C"], kernel=option["kernel"], gamma=option["gamma"],
                            # class_weight=option["class_weight"])
                            op1[gene1] = [option["C"], option["kernel"], option["degree"], option["gamma"],
                                          option["coef0"], params[5], True,
                                          params[7], params[8], option["class_weight"], params[10], params[11],
                                          params[12]]
                        if gene == "KNN" or gene == "KNN-0":
                            clf1 = KNeighborsClassifier(n_neighbors=option["n_neighbors"], weights=option["weights"],
                                                        algorithm=params[2],
                                                        leaf_size=option["leaf_size"], p=option["p"],
                                                        metric=option["metric"],
                                                        metric_params=params[6], n_jobs=1)
                            op1[gene1] = [option["n_neighbors"], option["weights"], params[2], option["leaf_size"],
                                          option["p"], option["metric"],
                                          params[6], 1]
                            # clf1 = KNeighborsClassifier(n_neighbors=option["n_neighbors"],
                            # leaf_size=option["leaf_size"], p=option["p"])
                            # op1["KNN"]=[option["n_neighbors"],option["leaf_size"],option["p"]]
                        if gene == "DT" or gene == "DT-0":
                            clf1 = DecisionTreeClassifier(criterion=option["criterion"], splitter=params[1],
                                                          max_depth=option["max_depth"],
                                                          min_samples_split=option["min_samples_split"],
                                                          min_samples_leaf=option["min_samples_leaf"],
                                                          min_weight_fraction_leaf=params[5],
                                                          max_features=option["max_features"],
                                                          random_state=params[7], max_leaf_nodes=params[8],
                                                          min_impurity_decrease=params[9],
                                                          min_impurity_split=params[10], class_weight=params[11])
                            op1[gene1] = [option["criterion"], params[1], option["max_depth"],
                                         option["min_samples_split"], option["min_samples_leaf"], params[5],
                                         option["max_features"],
                                         params[7], params[8], params[9], params[10], params[11]]
                            # clf1 = DecisionTreeClassifier(max_depth=option["max_depth"],
                            #                               min_samples_split=option["min_samples_split"], min_samples_leaf=option["min_samples_leaf"],
                            #                               max_features=option["max_features"])
                            # op1["DT"]=[option["max_depth"],option["min_samples_split"], option["min_samples_leaf"],option["max_features"]]
                        if gene == "RF" or gene == " RF-0":
                            clf1 = RandomForestClassifier(n_estimators=option["n_estimators"],
                                                          criterion=option["criterion"], max_depth=option["max_depth"],
                                                          min_samples_split=option["min_samples_split"],
                                                          min_samples_leaf=option["min_samples_leaf"],
                                                          min_weight_fraction_leaf=params[5], max_features=params[6],
                                                          max_leaf_nodes=params[7], min_impurity_decrease=params[8],
                                                          min_impurity_split=params[9],
                                                          bootstrap=option["bootstrap"], oob_score=params[11], n_jobs=1,
                                                          random_state=params[13], verbose=params[14],
                                                          warm_start=params[15],
                                                          class_weight=params[16])
                            op1[gene1] = [option["n_estimators"], option["criterion"], option["max_depth"],
                                         option["min_samples_split"], option["min_samples_leaf"],
                                         params[5], option["max_features"],
                                         params[7], params[8], params[9], option["bootstrap"], params[11], 1,
                                         params[13], params[14],
                                         params[15], params[16]]
                            # clf1 = RandomForestClassifier(n_estimators=option["n_estimators"], max_depth=option["max_depth"],
                            #                               min_samples_split=option["min_samples_split"], min_samples_leaf=option["min_samples_leaf"],
                            #                               max_features=option["max_features"],
                            #                               bootstrap=option["bootstrap"])
                            # op1["RF"]=[option["n_estimators"],option["max_depth"],option["min_samples_split"], option["min_samples_leaf"],
                            #            option["max_features"],option["bootstrap"]]
                        if gene == "LR" or gene == " LR-0":
                            clf1 = LogisticRegression(penalty='l2', dual=False, tol=params[2], C=option["C"],
                                                      fit_intercept=params[4],
                                                      intercept_scaling=params[5], class_weight=params[6],
                                                      random_state=params[7],
                                                      solver=option["solver"],
                                                      max_iter=params[9], multi_class=params[10], verbose=params[11],
                                                      warm_start=params[12], n_jobs=1,
                                                      )
                            op1[gene1] = ["l2", False, params[2], option["C"], params[4], params[5], params[6],
                                         params[7], option["solver"], params[9], params[10], params[11], params[12],
                                         1, ]
                            # clf1 = LogisticRegression(penalty='l2', C=option["C"],solver=option["solver"])
                            # op1["LR"]=["l2",option["C"],option["solver"]]
                        if gene == "ANN" or gene == "ANN -0":
                            clf1 = KerasClassifier(build_fn=ANN_model, num=option["num"],
                                                                                  epochs=500,
                                                                                  verbose=False)
                            clf1._estimator_type = "classifier"
                            op1[gene1] = [option["num"]]
                else:
                    gene1=gene
                    gene=gene.split('-')[0]
                    if gene == "SVM":
                        clf1 = SVC(C=params[0], kernel=params[1], degree=params[2], gamma=params[3],
                                   coef0=params[4], shrinking=params[5], probability=True,
                                   tol=params[7], cache_size=params[8], class_weight=params[9], verbose=params[10],
                                   max_iter=params[11],
                                   decision_function_shape=params[12])
                        op1[gene1] = [params[0], params[1], params[2], params[3], params[4], params[5], True,
                                      params[7], params[8], params[9], params[10], params[11],
                                      params[12]]
                    if gene == "KNN":
                        clf1 = KNeighborsClassifier(n_neighbors=params[0], weights=params[1], algorithm=params[2],
                                                    leaf_size=params[3], p=params[4], metric=params[5],
                                                    metric_params=params[6], n_jobs=1)
                        op1[gene1] = [params[0], params[1], params[2], params[3], params[4], params[5],
                                      params[6], 1]
                    if gene == "DT":
                        clf1 = DecisionTreeClassifier(criterion=params[0], splitter=params[1], max_depth=params[2],
                                                      min_samples_split=params[3], min_samples_leaf=params[4],
                                                      min_weight_fraction_leaf=params[5], max_features=params[6],
                                                      random_state=params[7], max_leaf_nodes=params[8],
                                                      min_impurity_decrease=params[9],
                                                      min_impurity_split=params[10], class_weight=params[11])
                        op1[gene1] = [params[0], params[1], params[2], params[3], params[4], params[5], params[6],
                                     params[7], params[8], params[9], params[10], params[11]]
                    if gene == "RF":
                        clf1 = RandomForestClassifier(n_estimators=params[0], criterion=params[1], max_depth=params[2],
                                                      min_samples_split=params[3], min_samples_leaf=params[4],
                                                      min_weight_fraction_leaf=params[5], max_features=params[6],
                                                      max_leaf_nodes=params[7], min_impurity_decrease=params[8],
                                                      min_impurity_split=params[9],
                                                      bootstrap=params[10], oob_score=params[11], n_jobs=1,
                                                      random_state=params[13], verbose=params[14],
                                                      warm_start=params[15],
                                                      class_weight=params[16])
                        op1[gene1] = [params[0], params[1], params[2], params[3], params[4], params[5], params[6],
                                     params[7], params[8], params[9], params[10], params[11], 1, params[13], params[14],
                                     params[15], params[16]]
                    if gene == "LR":
                        clf1 = LogisticRegression(penalty='l2', dual=False, tol=params[2], C=params[3],
                                                  fit_intercept=params[4],
                                                  intercept_scaling=params[5], class_weight=params[6],
                                                  random_state=params[7],
                                                  solver=params[8],
                                                  max_iter=params[9], multi_class=params[10], verbose=params[11],
                                                  warm_start=params[12], n_jobs=1,
                                                  )
                        op1[gene1] = ["l2", False, params[2], params[3], params[4], params[5], params[6],
                                     params[7], params[8], params[9], params[10], params[11], params[12], 1, ]
                    if gene == "ANN":
                        clf1 = KerasClassifier(build_fn=ANN_model, num=params[0],
                                                                              epochs=500,
                                                                              verbose=False)
                        clf1._estimator_type = "classifier"
                        op1[gene1] = [params[0]]
                op[str(count)] = op1
                count = count + 1
                clfs[gene1] = clf1
            fop[str(ocount)] = op
            ocount = ocount + 1
            estimators=[]
            for clf in clfs:
              print(clf)
              estimators.append((clf,clfs[clf]))
            if(len(estimators)>0):
              eclf = VotingClassifier(estimators, voting='hard',flatten_transform=True)
              eclfs[str(ecount)] = eclf
              ecount = ecount + 1
        print(fop)
        print(eclfs)

        # set all the ensembles model in a pipeline to be able to select the best out of them using gridsearch
        pipe = Pipeline([("classifier", VotingClassifier(estimators=KNeighborsClassifier()))])
        search_space = []
        for ens in eclfs:
            search_space.append({"classifier": [eclfs[ens]]})
        print(search_space)
        gridsearch = GridSearchCV(pipe, search_space, cv=5, verbose=5, n_jobs=1)
        best_model = gridsearch.fit(X_val, y_val)
        best = best_model.best_params_
        print(best)
        c = 0
        for ss in eclfs:
            print({'classifier': eclfs[ss]} == best)
            if ({'classifier': eclfs[ss]} == best):
                chromosomes = fop[str(c)]
                if c == len(eclfs):
                    index -= 1
            c = c + 1
        print(chromosomes)

        # return the best ensemble in the right chromosome form
        chromosome1 = chromosomes
        chromosome2 = {}
        for key in chromosome1:
            ch = chromosome1[key]
            for k in ch:
                chromosome2[k] = ch[k]
        chromosome = chromosome2
    print(chromosome)
    return chromosome

# %%
def roulette2(poplulation, n, fit_array):
    fit={}
    fitness = fit_array
    for chromosome, i in zip(poplulation, range(0, len(poplulation))):
        fit[str(chromosome)] = fit_array[i]
    #calculate total fitness
    total_fitness = float(sum(fit[str(chromosome)] for chromosome in poplulation))
    parents=[]
    weights=[]
    #generate probability of Fi/sum of weights
    for  i in range(0, len(fitness)):
        weights.append(fitness[i] / total_fitness)

    #genrate a random number and return when the chromosome at that weight is reached
    while n:
        r = np.random.rand()
        acc = 0
        idx = -1
        while acc < r:
            idx += 1
            acc += weights[idx]
        parents.append(poplulation[idx])
        n-=1
    return parents

# %%
def generateNewPopulation(population,all_fitness, X_train,y_train,X_val,y_val,crossover_prob=0.8, mutation_prob=0.1,elitism_range=0.2):
    new_population=[]
    elitism_fitness= all_fitness.copy()
    elitism_population= population.copy()
    #copy chromosomes in range of elitism rate and check for repetition
    for i in range(0, int(elitism_range*len(population))):
        max_index=elitism_fitness.index(max(elitism_fitness))
        if(elitism_population[max_index] in new_population):
            elitism_fitness.pop(max_index)
            elitism_population.pop(max_index)
        else:
            new_population.append(elitism_population[max_index])
            elitism_fitness.pop(max_index)
            elitism_population.pop(max_index)
    print("new_population",new_population)

    #while the length of the new population still has not reach 63 select mutate and crossover chromomsmes
    while(len(new_population)<len(population)):
        count = 0
        parents = roulette2(population,2,all_fitness)
        if np.random.random() < crossover_prob and len(new_population)<len(population)-1:
            print("crossover",parents[count])
            print("and",parents[count+1] )
            sp1,sp2=crossover(parents[count], parents[count + 1])
            new_population.append(sp1)
            new_population.append(sp2)
        parents = roulette2(population,1,all_fitness)
        if np.random.random() < mutation_prob and len(new_population)<len(population):
            print("Mutation", parents[count])
            try:
              mutated=Mutation(parents[count],X_train,y_train,X_val,y_val)
              new_population.append(mutated)
            except Exception as e:
                print(e)
                print("not mutated")
    return new_population

# %%
from numpy import array, savetxt, loadtxt
from numpy import savetxt
import tensorflow as tf
import pickle
mods=[]

# %%
def GA( crossover_prob=0.85, mutation_prob=0.15, elitism_range=0.15, max_generation=100, convergence_rate=100):
    #generate initial population
    population=generateInitialPopulation()
    print("initial population", population)
    gen=0
    convergence_count=0
    best_fits= {'0': {"{'KNN': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'ANN': [29]}": [0.6936, {'mcc': [0.3868607017236362], 'acc': [0.6936], 'f1': [0.683993399339934], 'cm': [array([[905, 367],
       [399, 829]])]}]}, '1': {"{'SVM': [56.651175987316705, 'linear', 93, 0.001, 0.5419741160525751, False, True, 0.001, 200, None, False, -1, 'ovr', False, 39], 'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'RF-1': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}": [0.6892, {'mcc': [0.37873304414332953], 'acc': [0.6892], 'f1': [0.6885771543086171], 'cm': [array([[864, 408],
       [369, 859]])]}]}, '2': {"{'DT': ['entropy', 'best', None, 6, 9, 0.0, None, 53, None, 0.0, None, 'balanced', 0.0], 'RF': [128, 'gini', None, 8, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 11, False, 'balanced', 0.0, None], 'ANN': [95]}": [0.692, {'mcc': [0.3843162871199211], 'acc': [0.692], 'f1': [0.6912590216519647], 'cm': [array([[868, 404],
       [366, 862]])]}]}, '3': {"{'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'ANN': [29]}": [0.6936, {'mcc': [0.38877714769982136], 'acc': [0.6936], 'f1': [0.6666666666666667], 'cm': [array([[968, 304],
       [462, 766]])]}]}, '4': {"{'SVM': [34.05017443007109, 'linear', 24, 0.001, 0.6819152317877569, False, False, 0.001, 200, 'balanced', True, -1, 'ovr', False, None], 'KNN': [3, 'distance', 'auto', 99, 7, 'manhattan', None, None], 'RF': [164, 'gini', None, 10, 3, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 72, False, 'balanced', 0.0, None], 'DT': ['gini', 'best', None, 4, 9, 0.0, None, None, None, 0.0, None, None, 0.0]}": [0.692, {'mcc': [0.38450722234769114], 'acc': [0.692], 'f1': [0.6706586826347305], 'cm': [array([[946, 326],
       [444, 784]])]}]}, '5': {"{'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'ANN': [29]}": [0.6952, {'mcc': [0.39086561376102064], 'acc': [0.6952], 'f1': [0.6746370623398804], 'cm': [array([[948, 324],
       [438, 790]])]}]}, '6': {"{'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'SVM': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'ANN': [11]}": [0.6976, {'mcc': [0.39488837584444486], 'acc': [0.6976], 'f1': [0.6863070539419087], 'cm': [array([[917, 355],
       [401, 827]])]}]}, '7': {"{'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'SVM': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'ANN': [11]}": [0.6944, {'mcc': [0.3884778918890737], 'acc': [0.6944], 'f1': [0.6829875518672198], 'cm': [array([[913, 359],
       [405, 823]])]}]}, '8': {"{'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'SVM': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'ANN': [11]}": [0.6948, {'mcc': [0.39044156980468053], 'acc': [0.6948], 'f1': [0.6718279569892474], 'cm': [array([[956, 316],
       [447, 781]])]}]}, '9': {"{'RF-1': [128, 'gini', None, 8, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 11, False, 'balanced', 0.0, None], 'DT': ['gini', 'best', None, 9, 1, 0.0, None, 37, None, 0.0, None, 'balanced', 0.0], 'RF': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}": [0.6944, {'mcc': [0.3886106160244197], 'acc': [0.6944], 'f1': [0.6889250814332247], 'cm': [array([[890, 382],
       [382, 846]])]}]}, '10': {"{'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'SVM': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'ANN': [11]}": [0.6972, {'mcc': [0.39475222745104804], 'acc': [0.6972], 'f1': [0.6777352064708387], 'cm': [array([[947, 325],
       [432, 796]])]}]}, '11': {"{'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'SVM': [34.05017443007109, 'linear', 24, 0.001, 0.6819152317877569, False, False, 0.001, 200, 'balanced', True, -1, 'ovr', False, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'ANN': [15]}": [0.6988, {'mcc': [0.39728542086093516], 'acc': [0.6988], 'f1': [0.690505548705302], 'cm': [array([[907, 365],
       [388, 840]])]}]}, '12': {"{'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'SVM': [34.05017443007109, 'linear', 24, 0.001, 0.6819152317877569, False, False, 0.001, 200, 'balanced', True, -1, 'ovr', False, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'ANN': [15]}": [0.6972, {'mcc': [0.3943055767931843], 'acc': [0.6972], 'f1': [0.6817990752416981], 'cm': [array([[932, 340],
       [417, 811]])]}]}}
    for i in range(0,len( best_fits)-1):
        if best_fits[str(i)]==best_fits[str(i+1)]:
            convergence_count+=1
        if (convergence_count >0 and convergence_count% 5==0 ):
            if mutation <0.85:
                    mutation_prob+=0.1
                    convergence_count=0
    
    models=[]
    #split dataset
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, random_state=1)
    #while stop conditions not met

    ii=0
    while gen<max_generation  and convergence_count<convergence_rate:
        print("gen", gen)
        print("population", population)
        all_fitness = []
        all_mod = []
        done=[]
        all_info = []
        if gen ==13:
             population= [{'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'SVM': [34.05017443007109, 'linear', 24, 0.001, 0.6819152317877569, False, False, 0.001, 200, 'balanced', True, -1, 'ovr', False, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'ANN': [15]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF-1': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'DT-1-0': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'ANN': [15]}, {'RF-1': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'ANN': [15]}, {'RF-1': [128, 'gini', None, 8, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 11, False, 'balanced', 0.0, None], 'RF': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'KNN': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'RF': [169, 'gini', None, 7, 2, 0.0, None, None, 0.0, None, True, False, None, None, 92, False, 'balanced', 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'SVM': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'DT-1': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF-1': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'SVM-1': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'ANN': [11]}, {'RF-1': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'SVM': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'RF': [128, 'gini', None, 8, 8, 0.0, 'sqrt', None, 0.0, None, True, False, 1, None, 11, False, 'balanced'], 'DT': ['entropy', 'best', 50, 8, 2, 0.0, 'auto', 61, None, 0.0, None, None]}, {'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'SVM': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'ANN': [11]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF-1-0': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'DT-1-0': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'ANN': [15]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF-1': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l2', False, 0.0001, 60.81019857941157, True, 35.781403706811055, None, None, 'saga', 139, 'ovr', 3, True, 1]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF-1': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'DT-1': ['gini', 'best', None, 9, 1, 0.0, None, 37, None, 0.0, None, 'balanced', 0.0], 'RF-2': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'ANN': [11]}, {'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'ANN': [15]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'DT': ['gini', 'best', None, 9, 3, 0.0, None, None, None, 0.0, None, None, 0.0]}, {'ANN': [11]}, {'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None], 'RF': [200, 'gini', 20, 8, 2, 0.0, 'sqrt', None, 0.0, None, True, False, 1, 2, 19, False, None], 'DT-1': ['gini', 'best', None, 5, 7, 0.0, None, None, None, 0.0, None, None], 'LR': ['l2', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, 1], 'DT-2': ['gini', 'best', None, 5, 7, 0.0, None, None, None, 0.0, None, None], 'LR-1': ['l2', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, 1], 'RF-1': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, 1, 23, 83, False, None]}, {'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None], 'RF': [200, 'gini', 20, 8, 2, 0.0, 'sqrt', None, 0.0, None, True, False, 1, 2, 19, False, None], 'KNN': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'ANN': [11]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF-1': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'RF-2': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, 1, 23, 83, False, None]}, {'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'ANN': [15]}, {'RF': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'KNN-0': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'RF': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'RF': [128, 'gini', None, 8, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 11, False, 'balanced', 0.0, None], 'ANN': [11]}, {'KNN-0': [6, 'distance', 'auto', 48, 9, 'minkowski', None, None], 'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'ANN': [11]}, {'DT': ['entropy', 'best', None, 10, 7, 0.0, None, 61, None, 0.0, None, None]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'RF-1': [169, 'gini', None, 7, 2, 0.0, None, None, 0.0, None, True, False, None, None, 92, False, 'balanced', 0.0, None], 'RF-2': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF-1': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'DT-1': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'ANN': [15]}, {'RF-1': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'SVM': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'RF': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'ANN': [15]}, {'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'ANN': [11]}, {'RF-1': [128, 'gini', None, 8, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 11, False, 'balanced', 0.0, None], 'RF': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'RF-0': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'RF': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'KNN-0': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'LR': ['l2', False, 0.0001, 60.81019857941157, True, 35.781403706811055, None, None, 'saga', 139, 'ovr', 3, True, 1]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF-1': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'DT-1': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF-2': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'RF-3': [1000, 'gini', 10, 6, 3, 0.0, 'sqrt', None, 0.0, None, False, False, 1, 25, 31, False, None], 'LR': ['l2', False, 0.0001, 60.81019857941157, True, 35.781403706811055, None, None, 'saga', 139, 'ovr', 3, True, 1]}, {'KNN': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'RF': [169, 'gini', None, 7, 2, 0.0, None, None, 0.0, None, True, False, None, None, 92, False, 'balanced', 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'SVM': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'DT-1': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF-1': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'RF-1': [169, 'gini', None, 7, 2, 0.0, None, None, 0.0, None, True, False, None, None, 92, False, 'balanced', 0.0, None], 'RF-2': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'SVM': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'ANN': [11]}, {'RF-1': [169, 'gini', None, 7, 2, 0.0, None, None, 0.0, None, True, False, None, None, 92, False, 'balanced', 0.0, None], 'SVM': [56.651175987316705, 'linear', 93, 0.001, 0.5419741160525751, False, True, 0.001, 200, None, False, -1, 'ovr', False, 39], 'RF': [1000, 'gini', 10, 6, 3, 0.0, 'sqrt', None, 0.0, None, False, False, 1, 25, 31, False, None], 'LR': ['l2', False, 0.0001, 432, True, 35.781403706811055, None, None, 'lbfgs', 139, 'ovr', 3, True, 1]}, {'ANN': [29]}, {'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'DT-1': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'ANN': [15]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF-1': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'DT-1': ['entropy', 'best', None, 10, 7, 0.0, None, 61, None, 0.0, None, None]}, {'KNN': [6, 'distance', 'auto', 48, 9, 'minkowski', None, None], 'RF': [128, 'gini', None, 8, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 11, False, 'balanced', 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF-1': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'ANN': [11]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'RF-1': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'DT-1': ['gini', 'best', None, 9, 3, 0.0, None, None, None, 0.0, None, None, 0.0]}, {'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'DT-1': ['gini', 'best', None, 9, 3, 0.0, None, None, None, 0.0, None, None, 0.0]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'DT': ['gini', 'best', 110, 6, 3, 0.0, 'sqrt', None, None, 0.0, None, None]}, {'DT': ['gini', 'best', None, 9, 1, 0.0, None, 37, None, 0.0, None, 'balanced', 0.0], 'RF': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'DT': ['gini', 'best', None, 9, 1, 0.0, None, 37, None, 0.0, None, 'balanced', 0.0], 'RF': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'ANN': [11]}, {'DT': ['gini', 'best', None, 9, 1, 0.0, None, 37, None, 0.0, None, 'balanced', 0.0], 'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'SVM': [56.651175987316705, 'linear', 93, 0.001, 0.5419741160525751, False, True, 0.001, 200, None, False, -1, 'ovr', False, 39], 'RF-1': [1000, 'gini', 10, 6, 3, 0.0, 'sqrt', None, 0.0, None, False, False, 1, 25, 31, False, None], 'LR': ['l2', False, 0.0001, 432, True, 35.781403706811055, None, None, 'lbfgs', 139, 'ovr', 3, True, 1]}, {'ANN': [11]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'RF-1': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'RF-2': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, None, 23, 83, False, None, 0.0, None]}, {'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'ANN': [15]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF-1': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'KNN': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'SVM': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'ANN': [11]}, {'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None], 'RF': [169, 'gini', None, 7, 2, 0.0, None, None, 0.0, None, True, False, None, None, 92, False, 'balanced', 0.0, None], 'ANN': [29]}, {'RF-1': [128, 'gini', None, 8, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 11, False, 'balanced', 0.0, None], 'RF': [200, 'gini', 20, 8, 2, 0.0, 'sqrt', None, 0.0, None, True, False, 1, 2, 19, False, None], 'DT': ['gini', 'best', None, 5, 7, 0.0, None, None, None, 0.0, None, None], 'LR': ['l2', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, 1], 'RF-2': [142, 'gini', None, 9, 7, 0.0, 'sqrt', None, 0.0, None, True, False, 1, 23, 83, False, None]}, {'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'SVM': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'ANN': [11]}, {'RF-1': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'ANN': [15]}, {'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'ANN': [11]}, {'RF': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'SVM': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'ANN': [11]}, {'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'RF-1': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'DT-1': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'SVM': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'ANN': [11]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'DT': ['entropy', 'best', None, 10, 7, 0.0, None, 61, None, 0.0, None, None]}, {'RF-2': [168, 'gini', None, 6, 6, 0.0, 'log2', None, 0.0, None, False, False, None, 35, 56, False, 'balanced_subsample', 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'SVM': [86.1077970069117, 'linear', 47, 0.001, 0.024398332864562833, False, True, 0.001, 200, None, True, -1, 'ovr', False, 71], 'ANN': [11]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF-1': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'LR': ['l1', False, 0.0001, 29.11751571756812, True, 4.314227682695792, None, 19, 'saga', 143, 'ovr', 7, False, None, 0.050970430431922065], 'RF-2': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'DT-1': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'DT-2': ['gini', 'best', None, 9, 3, 0.0, None, None, None, 0.0, None, None, 0.0]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'KNN': [2, 'uniform', 'auto', 100, 9, 'minkowski', None, None], 'SVM': [34.05017443007109, 'linear', 24, 0.001, 0.6819152317877569, False, False, 0.001, 200, 'balanced', True, -1, 'ovr', False, None], 'KNN-1': [3, 'distance', 'auto', 99, 7, 'manhattan', None, None], 'RF-1': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, 1, 2, 19, False, None], 'KNN-2': [3, 'distance', 'auto', 99, 7, 'manhattan', None, None], 'SVM-1': [56.651175987316705, 'linear', 93, 0.001, 0.5419741160525751, False, True, 0.001, 200, None, False, -1, 'ovr', False, 39], 'LR': ['l2', False, 0.0001, 60.81019857941157, True, 35.781403706811055, None, None, 'saga', 139, 'ovr', 3, True, 1]}, {'RF': [182, 'entropy', None, 2, 7, 0.0, 'log2', None, 0.0, None, False, False, None, 25, 31, False, None, 0.0, None], 'DT': ['gini', 'best', None, 5, 9, 0.0, None, 29, None, 0.0, None, None, 0.0], 'RF-1': [149, 'gini', None, 5, 7, 0.0, 'sqrt', None, 0.0, None, False, False, None, 2, 19, False, None, 0.0, None], 'DT-1': ['gini', 'best', None, 9, 3, 0.0, None, None, None, 0.0, None, None, 0.0]}]

        elif gen<13:
            print(gen)
            print(done)
        else:
            for chromosome in population:
                if chromosome in done:
                    print("chromosome", chromosome)
                    fit = all_fitness[done.index(chromosome)]
                    info = all_info[done.index(chromosome)]
                    model=all_mod[done.index(chromosome)]
                    all_fitness.append(fit)
                    all_info.append(info)
                    all_mod.append(model)
                    done.append(chromosome)
                    print("done out of 63", len(done))
                else:
                    print("chromosome", chromosome)
                    print(ii)
                    fit, info,model = fitness(chromosome,X_train,y_train,X_test,y_test,count=ii,gen=gen)
                    all_fitness.append(fit)
                    all_info.append(info)
                    all_mod.append(model)
                    done.append(chromosome)
                    print("done out of 63", len(done))
                    if gen ==0 or gen ==99:
                                ii+=1
        if gen >12:
          #check if converged
            if best_fits!={} and gen >0:
                if(str(list(best_fits[str(gen-1)])[0])== str(population[all_fitness.index(max(all_fitness))])):
                    print("converged")
                    convergence_count = convergence_count + 1
                else:
                    convergence_count=0
            #get best fit
            index = all_fitness.index(max(all_fitness))
            print("in gen",gen)
            print("best fitness",max(all_fitness))
            print("chromosome",population[index])
            best_fits[str(gen)]={str(population[index]):[max(all_fitness),all_info[index]]}
            print("best_fits",best_fits)
            print("all fitness",all_fitness)
            print("all_info",all_info)
            try:
                if gen ==0:
                    models.append(all_mod[index])
                    emod=all_mod[index]
                    print(index)
                    filename = 'gen0_modelexp1.sav'
                    with open(filename, "wb") as file:
                      pickle.dump(emod, file)
                if gen == 99:
                    models.append(all_mod[index])
                    emod=all_mod[index]
                    print(index)
                    filename = 'gen99_modelexp1.sav'
                    with open(filename, "wb") as file:
                      pickle.dump(emod, file)
            except Exception as e:
                print(e)
                print("not saved")
            if gen ==99   :
                mods.append(all_mod[index])
       
        gen=gen+1
        #check stop conditions and generate new data
        if gen >13 and gen<max_generation and convergence_count<convergence_rate:
            population=generateNewPopulation(population,X_train=X_train,y_train=y_train,X_val=X_val,y_val=y_val,crossover_prob=crossover_prob,mutation_prob=mutation_prob,elitism_range=elitism_range,all_fitness=all_fitness)
        #increase mutation rate
        if (convergence_count >0 and convergence_count% 5==0 ):
            if mutation <0.85:
                mutation_prob+=0.1
                convergence_count=0
    return best_fits, models

# %%
print(mods)
# Out:
# []

# %%
#x1, y1=balanced_subsample(X,y,5000)
#x1=np.array(x1)
#savetxt('dataexp1x.csv', x1, delimiter=',')
#savetxt('dataexp1y.csv', y1, delimiter=',')
X=loadtxt("dataexp1x.csv", delimiter=",")
y=loadtxt("dataexp1y.csv", delimiter=",")
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, random_state=1)

# %%
best_fits,models=GA()
print(best_fits)
# Out:
# initial population [{'SVM': [75.20723072692363, 'rbf', 97, 0.001, 0.8924063484233576, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, None]}, {'KNN': [3, 'distance', 'auto', 43, 8, 'euclidean', None, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0]}, {'RF': [125, 'gini', None, 3, 3, 0.0, 'log2', None, 0.0, None, False, False, None, None, 54, False, 'balanced_subsample', 0.0, None]}, {'LR': [None, True, 0.0001, 62.95029295560095, True, 40.736858002108114, 'balanced', None, 'liblinear', 95, 'ovr', 3, False, None, 0.6004743126677025]}, {'ANN': [26]}, {'SVM': [1.6205244872553926, 'linear', 97, 0.001, 0.47224133253518186, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 86], 'KNN': [3, 'distance', 'auto', 53, 10, 'euclidean', None, None]}, {'SVM': [90.6772806327919, 'poly', 18, 0.001, 0.40367195686644597, True, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'DT': ['gini', 'best', None, 5, 5, 0.0, None, 96, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [29.320468307472748, 'rbf', 38, 0.001, 0.1960139761399078, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'RF': [137, 'entropy', None, 7, 8, 0.0, 'log2', None, 0.0, None, False, False, None, None, 68, False, None, 0.0, None]}, {'SVM': [24.445399323751506, 'linear', 70, 0.001, 0.7042850659482285, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'LR': ['l2', False, 0.0001, 56.50901591746285, True, 78.70295913262008, None, None, 'lbfgs', 77, 'ovr', 9, False, None, 0.24717973942429228]}, {'SVM': [38.615943839552926, 'poly', 54, 0.001, 0.33422522231596474, False, True, 0.001, 200, 'balanced', False, -1, 'ovr', False, 51], 'ANN': [90]}, {'KNN': [4, 'distance', 'auto', 56, 3, 'manhattan', None, None], 'DT': ['gini', 'best', None, 8, 4, 0.0, None, 34, None, 0.0, None, None, 0.0]}, {'KNN': [7, 'distance', 'auto', 65, 8, 'manhattan', None, None], 'RF': [161, 'gini', None, 6, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 95, False, 'balanced_subsample', 0.0, None]}, {'KNN': [2, 'uniform', 'auto', 38, 3, 'euclidean', None, None], 'LR': ['elasticnet', False, 0.0001, 0.531087951749798, True, 34.98982066433245, None, 19, 'liblinear', 112, 'ovr', 1, False, None, 0.41510791777699363]}, {'KNN': [9, 'uniform', 'auto', 62, 3, 'minkowski', None, None], 'ANN': [74]}, {'DT': ['gini', 'best', None, 5, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'RF': [178, 'entropy', None, 6, 2, 0.0, 'sqrt', None, 0.0, None, True, False, None, 45, 51, False, 'balanced', 0.0, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'LR': ['l1', True, 0.0001, 50.408784108164376, True, 75.49096784227251, 'balanced', None, 'saga', 96, 'ovr', 5, False, None, 0.9401969233820928]}, {'DT': ['entropy', 'best', None, 7, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'ANN': [41]}, {'RF': [109, 'gini', None, 3, 2, 0.0, 'auto', None, 0.0, None, True, False, None, 50, 9, False, 'balanced', 0.0, None], 'LR': ['l2', False, 0.0001, 11.642172089074975, True, 74.1340978383606, 'balanced', 49, 'sag', 175, 'ovr', 3, False, None, 1]}, {'RF': [128, 'entropy', None, 4, 2, 0.0, 'log2', None, 0.0, None, True, False, None, None, 35, False, None, 0.0, None], 'ANN': [95]}, {'LR': [None, True, 0.0001, 97.36593344266976, True, 40.677297188514046, 'balanced', 81, 'newton-cg', 195, 'ovr', 7, True, None, 1], 'ANN': [51]}, {'SVM': [45.00064934835307, 'rbf', 87, 0.001, 0.8483581652266433, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 50], 'KNN': [4, 'distance', 'auto', 58, 4, 'minkowski', None, None], 'DT': ['gini', 'best', None, 4, 8, 0.0, None, 8, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [14.349834674001327, 'linear', 100, 0.001, 0.6998560105273739, False, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'KNN': [1, 'uniform', 'auto', 99, 7, 'minkowski', None, None], 'RF': [168, 'gini', None, 4, 2, 0.0, None, None, 0.0, None, True, False, None, None,  ...
# gen 0
# population [{'SVM': [75.20723072692363, 'rbf', 97, 0.001, 0.8924063484233576, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, None]}, {'KNN': [3, 'distance', 'auto', 43, 8, 'euclidean', None, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0]}, {'RF': [125, 'gini', None, 3, 3, 0.0, 'log2', None, 0.0, None, False, False, None, None, 54, False, 'balanced_subsample', 0.0, None]}, {'LR': [None, True, 0.0001, 62.95029295560095, True, 40.736858002108114, 'balanced', None, 'liblinear', 95, 'ovr', 3, False, None, 0.6004743126677025]}, {'ANN': [26]}, {'SVM': [1.6205244872553926, 'linear', 97, 0.001, 0.47224133253518186, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 86], 'KNN': [3, 'distance', 'auto', 53, 10, 'euclidean', None, None]}, {'SVM': [90.6772806327919, 'poly', 18, 0.001, 0.40367195686644597, True, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'DT': ['gini', 'best', None, 5, 5, 0.0, None, 96, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [29.320468307472748, 'rbf', 38, 0.001, 0.1960139761399078, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'RF': [137, 'entropy', None, 7, 8, 0.0, 'log2', None, 0.0, None, False, False, None, None, 68, False, None, 0.0, None]}, {'SVM': [24.445399323751506, 'linear', 70, 0.001, 0.7042850659482285, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'LR': ['l2', False, 0.0001, 56.50901591746285, True, 78.70295913262008, None, None, 'lbfgs', 77, 'ovr', 9, False, None, 0.24717973942429228]}, {'SVM': [38.615943839552926, 'poly', 54, 0.001, 0.33422522231596474, False, True, 0.001, 200, 'balanced', False, -1, 'ovr', False, 51], 'ANN': [90]}, {'KNN': [4, 'distance', 'auto', 56, 3, 'manhattan', None, None], 'DT': ['gini', 'best', None, 8, 4, 0.0, None, 34, None, 0.0, None, None, 0.0]}, {'KNN': [7, 'distance', 'auto', 65, 8, 'manhattan', None, None], 'RF': [161, 'gini', None, 6, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 95, False, 'balanced_subsample', 0.0, None]}, {'KNN': [2, 'uniform', 'auto', 38, 3, 'euclidean', None, None], 'LR': ['elasticnet', False, 0.0001, 0.531087951749798, True, 34.98982066433245, None, 19, 'liblinear', 112, 'ovr', 1, False, None, 0.41510791777699363]}, {'KNN': [9, 'uniform', 'auto', 62, 3, 'minkowski', None, None], 'ANN': [74]}, {'DT': ['gini', 'best', None, 5, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'RF': [178, 'entropy', None, 6, 2, 0.0, 'sqrt', None, 0.0, None, True, False, None, 45, 51, False, 'balanced', 0.0, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'LR': ['l1', True, 0.0001, 50.408784108164376, True, 75.49096784227251, 'balanced', None, 'saga', 96, 'ovr', 5, False, None, 0.9401969233820928]}, {'DT': ['entropy', 'best', None, 7, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'ANN': [41]}, {'RF': [109, 'gini', None, 3, 2, 0.0, 'auto', None, 0.0, None, True, False, None, 50, 9, False, 'balanced', 0.0, None], 'LR': ['l2', False, 0.0001, 11.642172089074975, True, 74.1340978383606, 'balanced', 49, 'sag', 175, 'ovr', 3, False, None, 1]}, {'RF': [128, 'entropy', None, 4, 2, 0.0, 'log2', None, 0.0, None, True, False, None, None, 35, False, None, 0.0, None], 'ANN': [95]}, {'LR': [None, True, 0.0001, 97.36593344266976, True, 40.677297188514046, 'balanced', 81, 'newton-cg', 195, 'ovr', 7, True, None, 1], 'ANN': [51]}, {'SVM': [45.00064934835307, 'rbf', 87, 0.001, 0.8483581652266433, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 50], 'KNN': [4, 'distance', 'auto', 58, 4, 'minkowski', None, None], 'DT': ['gini', 'best', None, 4, 8, 0.0, None, 8, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [14.349834674001327, 'linear', 100, 0.001, 0.6998560105273739, False, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'KNN': [1, 'uniform', 'auto', 99, 7, 'minkowski', None, None], 'RF': [168, 'gini', None, 4, 2, 0.0, None, None, 0.0, None, True, False, None, None, 77, Fals ...
# 0
# []
# gen 1
# population [{'SVM': [75.20723072692363, 'rbf', 97, 0.001, 0.8924063484233576, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, None]}, {'KNN': [3, 'distance', 'auto', 43, 8, 'euclidean', None, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0]}, {'RF': [125, 'gini', None, 3, 3, 0.0, 'log2', None, 0.0, None, False, False, None, None, 54, False, 'balanced_subsample', 0.0, None]}, {'LR': [None, True, 0.0001, 62.95029295560095, True, 40.736858002108114, 'balanced', None, 'liblinear', 95, 'ovr', 3, False, None, 0.6004743126677025]}, {'ANN': [26]}, {'SVM': [1.6205244872553926, 'linear', 97, 0.001, 0.47224133253518186, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 86], 'KNN': [3, 'distance', 'auto', 53, 10, 'euclidean', None, None]}, {'SVM': [90.6772806327919, 'poly', 18, 0.001, 0.40367195686644597, True, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'DT': ['gini', 'best', None, 5, 5, 0.0, None, 96, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [29.320468307472748, 'rbf', 38, 0.001, 0.1960139761399078, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'RF': [137, 'entropy', None, 7, 8, 0.0, 'log2', None, 0.0, None, False, False, None, None, 68, False, None, 0.0, None]}, {'SVM': [24.445399323751506, 'linear', 70, 0.001, 0.7042850659482285, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'LR': ['l2', False, 0.0001, 56.50901591746285, True, 78.70295913262008, None, None, 'lbfgs', 77, 'ovr', 9, False, None, 0.24717973942429228]}, {'SVM': [38.615943839552926, 'poly', 54, 0.001, 0.33422522231596474, False, True, 0.001, 200, 'balanced', False, -1, 'ovr', False, 51], 'ANN': [90]}, {'KNN': [4, 'distance', 'auto', 56, 3, 'manhattan', None, None], 'DT': ['gini', 'best', None, 8, 4, 0.0, None, 34, None, 0.0, None, None, 0.0]}, {'KNN': [7, 'distance', 'auto', 65, 8, 'manhattan', None, None], 'RF': [161, 'gini', None, 6, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 95, False, 'balanced_subsample', 0.0, None]}, {'KNN': [2, 'uniform', 'auto', 38, 3, 'euclidean', None, None], 'LR': ['elasticnet', False, 0.0001, 0.531087951749798, True, 34.98982066433245, None, 19, 'liblinear', 112, 'ovr', 1, False, None, 0.41510791777699363]}, {'KNN': [9, 'uniform', 'auto', 62, 3, 'minkowski', None, None], 'ANN': [74]}, {'DT': ['gini', 'best', None, 5, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'RF': [178, 'entropy', None, 6, 2, 0.0, 'sqrt', None, 0.0, None, True, False, None, 45, 51, False, 'balanced', 0.0, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'LR': ['l1', True, 0.0001, 50.408784108164376, True, 75.49096784227251, 'balanced', None, 'saga', 96, 'ovr', 5, False, None, 0.9401969233820928]}, {'DT': ['entropy', 'best', None, 7, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'ANN': [41]}, {'RF': [109, 'gini', None, 3, 2, 0.0, 'auto', None, 0.0, None, True, False, None, 50, 9, False, 'balanced', 0.0, None], 'LR': ['l2', False, 0.0001, 11.642172089074975, True, 74.1340978383606, 'balanced', 49, 'sag', 175, 'ovr', 3, False, None, 1]}, {'RF': [128, 'entropy', None, 4, 2, 0.0, 'log2', None, 0.0, None, True, False, None, None, 35, False, None, 0.0, None], 'ANN': [95]}, {'LR': [None, True, 0.0001, 97.36593344266976, True, 40.677297188514046, 'balanced', 81, 'newton-cg', 195, 'ovr', 7, True, None, 1], 'ANN': [51]}, {'SVM': [45.00064934835307, 'rbf', 87, 0.001, 0.8483581652266433, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 50], 'KNN': [4, 'distance', 'auto', 58, 4, 'minkowski', None, None], 'DT': ['gini', 'best', None, 4, 8, 0.0, None, 8, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [14.349834674001327, 'linear', 100, 0.001, 0.6998560105273739, False, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'KNN': [1, 'uniform', 'auto', 99, 7, 'minkowski', None, None], 'RF': [168, 'gini', None, 4, 2, 0.0, None, None, 0.0, None, True, False, None, None, 77, Fals ...
# 1
# []
# gen 2
# population [{'SVM': [75.20723072692363, 'rbf', 97, 0.001, 0.8924063484233576, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, None]}, {'KNN': [3, 'distance', 'auto', 43, 8, 'euclidean', None, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0]}, {'RF': [125, 'gini', None, 3, 3, 0.0, 'log2', None, 0.0, None, False, False, None, None, 54, False, 'balanced_subsample', 0.0, None]}, {'LR': [None, True, 0.0001, 62.95029295560095, True, 40.736858002108114, 'balanced', None, 'liblinear', 95, 'ovr', 3, False, None, 0.6004743126677025]}, {'ANN': [26]}, {'SVM': [1.6205244872553926, 'linear', 97, 0.001, 0.47224133253518186, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 86], 'KNN': [3, 'distance', 'auto', 53, 10, 'euclidean', None, None]}, {'SVM': [90.6772806327919, 'poly', 18, 0.001, 0.40367195686644597, True, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'DT': ['gini', 'best', None, 5, 5, 0.0, None, 96, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [29.320468307472748, 'rbf', 38, 0.001, 0.1960139761399078, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'RF': [137, 'entropy', None, 7, 8, 0.0, 'log2', None, 0.0, None, False, False, None, None, 68, False, None, 0.0, None]}, {'SVM': [24.445399323751506, 'linear', 70, 0.001, 0.7042850659482285, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'LR': ['l2', False, 0.0001, 56.50901591746285, True, 78.70295913262008, None, None, 'lbfgs', 77, 'ovr', 9, False, None, 0.24717973942429228]}, {'SVM': [38.615943839552926, 'poly', 54, 0.001, 0.33422522231596474, False, True, 0.001, 200, 'balanced', False, -1, 'ovr', False, 51], 'ANN': [90]}, {'KNN': [4, 'distance', 'auto', 56, 3, 'manhattan', None, None], 'DT': ['gini', 'best', None, 8, 4, 0.0, None, 34, None, 0.0, None, None, 0.0]}, {'KNN': [7, 'distance', 'auto', 65, 8, 'manhattan', None, None], 'RF': [161, 'gini', None, 6, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 95, False, 'balanced_subsample', 0.0, None]}, {'KNN': [2, 'uniform', 'auto', 38, 3, 'euclidean', None, None], 'LR': ['elasticnet', False, 0.0001, 0.531087951749798, True, 34.98982066433245, None, 19, 'liblinear', 112, 'ovr', 1, False, None, 0.41510791777699363]}, {'KNN': [9, 'uniform', 'auto', 62, 3, 'minkowski', None, None], 'ANN': [74]}, {'DT': ['gini', 'best', None, 5, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'RF': [178, 'entropy', None, 6, 2, 0.0, 'sqrt', None, 0.0, None, True, False, None, 45, 51, False, 'balanced', 0.0, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'LR': ['l1', True, 0.0001, 50.408784108164376, True, 75.49096784227251, 'balanced', None, 'saga', 96, 'ovr', 5, False, None, 0.9401969233820928]}, {'DT': ['entropy', 'best', None, 7, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'ANN': [41]}, {'RF': [109, 'gini', None, 3, 2, 0.0, 'auto', None, 0.0, None, True, False, None, 50, 9, False, 'balanced', 0.0, None], 'LR': ['l2', False, 0.0001, 11.642172089074975, True, 74.1340978383606, 'balanced', 49, 'sag', 175, 'ovr', 3, False, None, 1]}, {'RF': [128, 'entropy', None, 4, 2, 0.0, 'log2', None, 0.0, None, True, False, None, None, 35, False, None, 0.0, None], 'ANN': [95]}, {'LR': [None, True, 0.0001, 97.36593344266976, True, 40.677297188514046, 'balanced', 81, 'newton-cg', 195, 'ovr', 7, True, None, 1], 'ANN': [51]}, {'SVM': [45.00064934835307, 'rbf', 87, 0.001, 0.8483581652266433, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 50], 'KNN': [4, 'distance', 'auto', 58, 4, 'minkowski', None, None], 'DT': ['gini', 'best', None, 4, 8, 0.0, None, 8, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [14.349834674001327, 'linear', 100, 0.001, 0.6998560105273739, False, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'KNN': [1, 'uniform', 'auto', 99, 7, 'minkowski', None, None], 'RF': [168, 'gini', None, 4, 2, 0.0, None, None, 0.0, None, True, False, None, None, 77, Fals ...
# 2
# []
# gen 3
# population [{'SVM': [75.20723072692363, 'rbf', 97, 0.001, 0.8924063484233576, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, None]}, {'KNN': [3, 'distance', 'auto', 43, 8, 'euclidean', None, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0]}, {'RF': [125, 'gini', None, 3, 3, 0.0, 'log2', None, 0.0, None, False, False, None, None, 54, False, 'balanced_subsample', 0.0, None]}, {'LR': [None, True, 0.0001, 62.95029295560095, True, 40.736858002108114, 'balanced', None, 'liblinear', 95, 'ovr', 3, False, None, 0.6004743126677025]}, {'ANN': [26]}, {'SVM': [1.6205244872553926, 'linear', 97, 0.001, 0.47224133253518186, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 86], 'KNN': [3, 'distance', 'auto', 53, 10, 'euclidean', None, None]}, {'SVM': [90.6772806327919, 'poly', 18, 0.001, 0.40367195686644597, True, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'DT': ['gini', 'best', None, 5, 5, 0.0, None, 96, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [29.320468307472748, 'rbf', 38, 0.001, 0.1960139761399078, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'RF': [137, 'entropy', None, 7, 8, 0.0, 'log2', None, 0.0, None, False, False, None, None, 68, False, None, 0.0, None]}, {'SVM': [24.445399323751506, 'linear', 70, 0.001, 0.7042850659482285, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'LR': ['l2', False, 0.0001, 56.50901591746285, True, 78.70295913262008, None, None, 'lbfgs', 77, 'ovr', 9, False, None, 0.24717973942429228]}, {'SVM': [38.615943839552926, 'poly', 54, 0.001, 0.33422522231596474, False, True, 0.001, 200, 'balanced', False, -1, 'ovr', False, 51], 'ANN': [90]}, {'KNN': [4, 'distance', 'auto', 56, 3, 'manhattan', None, None], 'DT': ['gini', 'best', None, 8, 4, 0.0, None, 34, None, 0.0, None, None, 0.0]}, {'KNN': [7, 'distance', 'auto', 65, 8, 'manhattan', None, None], 'RF': [161, 'gini', None, 6, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 95, False, 'balanced_subsample', 0.0, None]}, {'KNN': [2, 'uniform', 'auto', 38, 3, 'euclidean', None, None], 'LR': ['elasticnet', False, 0.0001, 0.531087951749798, True, 34.98982066433245, None, 19, 'liblinear', 112, 'ovr', 1, False, None, 0.41510791777699363]}, {'KNN': [9, 'uniform', 'auto', 62, 3, 'minkowski', None, None], 'ANN': [74]}, {'DT': ['gini', 'best', None, 5, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'RF': [178, 'entropy', None, 6, 2, 0.0, 'sqrt', None, 0.0, None, True, False, None, 45, 51, False, 'balanced', 0.0, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'LR': ['l1', True, 0.0001, 50.408784108164376, True, 75.49096784227251, 'balanced', None, 'saga', 96, 'ovr', 5, False, None, 0.9401969233820928]}, {'DT': ['entropy', 'best', None, 7, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'ANN': [41]}, {'RF': [109, 'gini', None, 3, 2, 0.0, 'auto', None, 0.0, None, True, False, None, 50, 9, False, 'balanced', 0.0, None], 'LR': ['l2', False, 0.0001, 11.642172089074975, True, 74.1340978383606, 'balanced', 49, 'sag', 175, 'ovr', 3, False, None, 1]}, {'RF': [128, 'entropy', None, 4, 2, 0.0, 'log2', None, 0.0, None, True, False, None, None, 35, False, None, 0.0, None], 'ANN': [95]}, {'LR': [None, True, 0.0001, 97.36593344266976, True, 40.677297188514046, 'balanced', 81, 'newton-cg', 195, 'ovr', 7, True, None, 1], 'ANN': [51]}, {'SVM': [45.00064934835307, 'rbf', 87, 0.001, 0.8483581652266433, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 50], 'KNN': [4, 'distance', 'auto', 58, 4, 'minkowski', None, None], 'DT': ['gini', 'best', None, 4, 8, 0.0, None, 8, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [14.349834674001327, 'linear', 100, 0.001, 0.6998560105273739, False, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'KNN': [1, 'uniform', 'auto', 99, 7, 'minkowski', None, None], 'RF': [168, 'gini', None, 4, 2, 0.0, None, None, 0.0, None, True, False, None, None, 77, Fals ...
# 3
# []
# gen 4
# population [{'SVM': [75.20723072692363, 'rbf', 97, 0.001, 0.8924063484233576, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, None]}, {'KNN': [3, 'distance', 'auto', 43, 8, 'euclidean', None, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0]}, {'RF': [125, 'gini', None, 3, 3, 0.0, 'log2', None, 0.0, None, False, False, None, None, 54, False, 'balanced_subsample', 0.0, None]}, {'LR': [None, True, 0.0001, 62.95029295560095, True, 40.736858002108114, 'balanced', None, 'liblinear', 95, 'ovr', 3, False, None, 0.6004743126677025]}, {'ANN': [26]}, {'SVM': [1.6205244872553926, 'linear', 97, 0.001, 0.47224133253518186, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 86], 'KNN': [3, 'distance', 'auto', 53, 10, 'euclidean', None, None]}, {'SVM': [90.6772806327919, 'poly', 18, 0.001, 0.40367195686644597, True, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'DT': ['gini', 'best', None, 5, 5, 0.0, None, 96, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [29.320468307472748, 'rbf', 38, 0.001, 0.1960139761399078, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'RF': [137, 'entropy', None, 7, 8, 0.0, 'log2', None, 0.0, None, False, False, None, None, 68, False, None, 0.0, None]}, {'SVM': [24.445399323751506, 'linear', 70, 0.001, 0.7042850659482285, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'LR': ['l2', False, 0.0001, 56.50901591746285, True, 78.70295913262008, None, None, 'lbfgs', 77, 'ovr', 9, False, None, 0.24717973942429228]}, {'SVM': [38.615943839552926, 'poly', 54, 0.001, 0.33422522231596474, False, True, 0.001, 200, 'balanced', False, -1, 'ovr', False, 51], 'ANN': [90]}, {'KNN': [4, 'distance', 'auto', 56, 3, 'manhattan', None, None], 'DT': ['gini', 'best', None, 8, 4, 0.0, None, 34, None, 0.0, None, None, 0.0]}, {'KNN': [7, 'distance', 'auto', 65, 8, 'manhattan', None, None], 'RF': [161, 'gini', None, 6, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 95, False, 'balanced_subsample', 0.0, None]}, {'KNN': [2, 'uniform', 'auto', 38, 3, 'euclidean', None, None], 'LR': ['elasticnet', False, 0.0001, 0.531087951749798, True, 34.98982066433245, None, 19, 'liblinear', 112, 'ovr', 1, False, None, 0.41510791777699363]}, {'KNN': [9, 'uniform', 'auto', 62, 3, 'minkowski', None, None], 'ANN': [74]}, {'DT': ['gini', 'best', None, 5, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'RF': [178, 'entropy', None, 6, 2, 0.0, 'sqrt', None, 0.0, None, True, False, None, 45, 51, False, 'balanced', 0.0, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'LR': ['l1', True, 0.0001, 50.408784108164376, True, 75.49096784227251, 'balanced', None, 'saga', 96, 'ovr', 5, False, None, 0.9401969233820928]}, {'DT': ['entropy', 'best', None, 7, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'ANN': [41]}, {'RF': [109, 'gini', None, 3, 2, 0.0, 'auto', None, 0.0, None, True, False, None, 50, 9, False, 'balanced', 0.0, None], 'LR': ['l2', False, 0.0001, 11.642172089074975, True, 74.1340978383606, 'balanced', 49, 'sag', 175, 'ovr', 3, False, None, 1]}, {'RF': [128, 'entropy', None, 4, 2, 0.0, 'log2', None, 0.0, None, True, False, None, None, 35, False, None, 0.0, None], 'ANN': [95]}, {'LR': [None, True, 0.0001, 97.36593344266976, True, 40.677297188514046, 'balanced', 81, 'newton-cg', 195, 'ovr', 7, True, None, 1], 'ANN': [51]}, {'SVM': [45.00064934835307, 'rbf', 87, 0.001, 0.8483581652266433, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 50], 'KNN': [4, 'distance', 'auto', 58, 4, 'minkowski', None, None], 'DT': ['gini', 'best', None, 4, 8, 0.0, None, 8, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [14.349834674001327, 'linear', 100, 0.001, 0.6998560105273739, False, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'KNN': [1, 'uniform', 'auto', 99, 7, 'minkowski', None, None], 'RF': [168, 'gini', None, 4, 2, 0.0, None, None, 0.0, None, True, False, None, None, 77, Fals ...
# 4
# []
# gen 5
# population [{'SVM': [75.20723072692363, 'rbf', 97, 0.001, 0.8924063484233576, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, None]}, {'KNN': [3, 'distance', 'auto', 43, 8, 'euclidean', None, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0]}, {'RF': [125, 'gini', None, 3, 3, 0.0, 'log2', None, 0.0, None, False, False, None, None, 54, False, 'balanced_subsample', 0.0, None]}, {'LR': [None, True, 0.0001, 62.95029295560095, True, 40.736858002108114, 'balanced', None, 'liblinear', 95, 'ovr', 3, False, None, 0.6004743126677025]}, {'ANN': [26]}, {'SVM': [1.6205244872553926, 'linear', 97, 0.001, 0.47224133253518186, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 86], 'KNN': [3, 'distance', 'auto', 53, 10, 'euclidean', None, None]}, {'SVM': [90.6772806327919, 'poly', 18, 0.001, 0.40367195686644597, True, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'DT': ['gini', 'best', None, 5, 5, 0.0, None, 96, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [29.320468307472748, 'rbf', 38, 0.001, 0.1960139761399078, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'RF': [137, 'entropy', None, 7, 8, 0.0, 'log2', None, 0.0, None, False, False, None, None, 68, False, None, 0.0, None]}, {'SVM': [24.445399323751506, 'linear', 70, 0.001, 0.7042850659482285, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'LR': ['l2', False, 0.0001, 56.50901591746285, True, 78.70295913262008, None, None, 'lbfgs', 77, 'ovr', 9, False, None, 0.24717973942429228]}, {'SVM': [38.615943839552926, 'poly', 54, 0.001, 0.33422522231596474, False, True, 0.001, 200, 'balanced', False, -1, 'ovr', False, 51], 'ANN': [90]}, {'KNN': [4, 'distance', 'auto', 56, 3, 'manhattan', None, None], 'DT': ['gini', 'best', None, 8, 4, 0.0, None, 34, None, 0.0, None, None, 0.0]}, {'KNN': [7, 'distance', 'auto', 65, 8, 'manhattan', None, None], 'RF': [161, 'gini', None, 6, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 95, False, 'balanced_subsample', 0.0, None]}, {'KNN': [2, 'uniform', 'auto', 38, 3, 'euclidean', None, None], 'LR': ['elasticnet', False, 0.0001, 0.531087951749798, True, 34.98982066433245, None, 19, 'liblinear', 112, 'ovr', 1, False, None, 0.41510791777699363]}, {'KNN': [9, 'uniform', 'auto', 62, 3, 'minkowski', None, None], 'ANN': [74]}, {'DT': ['gini', 'best', None, 5, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'RF': [178, 'entropy', None, 6, 2, 0.0, 'sqrt', None, 0.0, None, True, False, None, 45, 51, False, 'balanced', 0.0, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'LR': ['l1', True, 0.0001, 50.408784108164376, True, 75.49096784227251, 'balanced', None, 'saga', 96, 'ovr', 5, False, None, 0.9401969233820928]}, {'DT': ['entropy', 'best', None, 7, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'ANN': [41]}, {'RF': [109, 'gini', None, 3, 2, 0.0, 'auto', None, 0.0, None, True, False, None, 50, 9, False, 'balanced', 0.0, None], 'LR': ['l2', False, 0.0001, 11.642172089074975, True, 74.1340978383606, 'balanced', 49, 'sag', 175, 'ovr', 3, False, None, 1]}, {'RF': [128, 'entropy', None, 4, 2, 0.0, 'log2', None, 0.0, None, True, False, None, None, 35, False, None, 0.0, None], 'ANN': [95]}, {'LR': [None, True, 0.0001, 97.36593344266976, True, 40.677297188514046, 'balanced', 81, 'newton-cg', 195, 'ovr', 7, True, None, 1], 'ANN': [51]}, {'SVM': [45.00064934835307, 'rbf', 87, 0.001, 0.8483581652266433, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 50], 'KNN': [4, 'distance', 'auto', 58, 4, 'minkowski', None, None], 'DT': ['gini', 'best', None, 4, 8, 0.0, None, 8, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [14.349834674001327, 'linear', 100, 0.001, 0.6998560105273739, False, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'KNN': [1, 'uniform', 'auto', 99, 7, 'minkowski', None, None], 'RF': [168, 'gini', None, 4, 2, 0.0, None, None, 0.0, None, True, False, None, None, 77, Fals ...
# 5
# []
# gen 6
# population [{'SVM': [75.20723072692363, 'rbf', 97, 0.001, 0.8924063484233576, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, None]}, {'KNN': [3, 'distance', 'auto', 43, 8, 'euclidean', None, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0]}, {'RF': [125, 'gini', None, 3, 3, 0.0, 'log2', None, 0.0, None, False, False, None, None, 54, False, 'balanced_subsample', 0.0, None]}, {'LR': [None, True, 0.0001, 62.95029295560095, True, 40.736858002108114, 'balanced', None, 'liblinear', 95, 'ovr', 3, False, None, 0.6004743126677025]}, {'ANN': [26]}, {'SVM': [1.6205244872553926, 'linear', 97, 0.001, 0.47224133253518186, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 86], 'KNN': [3, 'distance', 'auto', 53, 10, 'euclidean', None, None]}, {'SVM': [90.6772806327919, 'poly', 18, 0.001, 0.40367195686644597, True, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'DT': ['gini', 'best', None, 5, 5, 0.0, None, 96, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [29.320468307472748, 'rbf', 38, 0.001, 0.1960139761399078, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'RF': [137, 'entropy', None, 7, 8, 0.0, 'log2', None, 0.0, None, False, False, None, None, 68, False, None, 0.0, None]}, {'SVM': [24.445399323751506, 'linear', 70, 0.001, 0.7042850659482285, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'LR': ['l2', False, 0.0001, 56.50901591746285, True, 78.70295913262008, None, None, 'lbfgs', 77, 'ovr', 9, False, None, 0.24717973942429228]}, {'SVM': [38.615943839552926, 'poly', 54, 0.001, 0.33422522231596474, False, True, 0.001, 200, 'balanced', False, -1, 'ovr', False, 51], 'ANN': [90]}, {'KNN': [4, 'distance', 'auto', 56, 3, 'manhattan', None, None], 'DT': ['gini', 'best', None, 8, 4, 0.0, None, 34, None, 0.0, None, None, 0.0]}, {'KNN': [7, 'distance', 'auto', 65, 8, 'manhattan', None, None], 'RF': [161, 'gini', None, 6, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 95, False, 'balanced_subsample', 0.0, None]}, {'KNN': [2, 'uniform', 'auto', 38, 3, 'euclidean', None, None], 'LR': ['elasticnet', False, 0.0001, 0.531087951749798, True, 34.98982066433245, None, 19, 'liblinear', 112, 'ovr', 1, False, None, 0.41510791777699363]}, {'KNN': [9, 'uniform', 'auto', 62, 3, 'minkowski', None, None], 'ANN': [74]}, {'DT': ['gini', 'best', None, 5, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'RF': [178, 'entropy', None, 6, 2, 0.0, 'sqrt', None, 0.0, None, True, False, None, 45, 51, False, 'balanced', 0.0, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'LR': ['l1', True, 0.0001, 50.408784108164376, True, 75.49096784227251, 'balanced', None, 'saga', 96, 'ovr', 5, False, None, 0.9401969233820928]}, {'DT': ['entropy', 'best', None, 7, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'ANN': [41]}, {'RF': [109, 'gini', None, 3, 2, 0.0, 'auto', None, 0.0, None, True, False, None, 50, 9, False, 'balanced', 0.0, None], 'LR': ['l2', False, 0.0001, 11.642172089074975, True, 74.1340978383606, 'balanced', 49, 'sag', 175, 'ovr', 3, False, None, 1]}, {'RF': [128, 'entropy', None, 4, 2, 0.0, 'log2', None, 0.0, None, True, False, None, None, 35, False, None, 0.0, None], 'ANN': [95]}, {'LR': [None, True, 0.0001, 97.36593344266976, True, 40.677297188514046, 'balanced', 81, 'newton-cg', 195, 'ovr', 7, True, None, 1], 'ANN': [51]}, {'SVM': [45.00064934835307, 'rbf', 87, 0.001, 0.8483581652266433, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 50], 'KNN': [4, 'distance', 'auto', 58, 4, 'minkowski', None, None], 'DT': ['gini', 'best', None, 4, 8, 0.0, None, 8, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [14.349834674001327, 'linear', 100, 0.001, 0.6998560105273739, False, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'KNN': [1, 'uniform', 'auto', 99, 7, 'minkowski', None, None], 'RF': [168, 'gini', None, 4, 2, 0.0, None, None, 0.0, None, True, False, None, None, 77, Fals ...
# 6
# []
# gen 7
# population [{'SVM': [75.20723072692363, 'rbf', 97, 0.001, 0.8924063484233576, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, None]}, {'KNN': [3, 'distance', 'auto', 43, 8, 'euclidean', None, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0]}, {'RF': [125, 'gini', None, 3, 3, 0.0, 'log2', None, 0.0, None, False, False, None, None, 54, False, 'balanced_subsample', 0.0, None]}, {'LR': [None, True, 0.0001, 62.95029295560095, True, 40.736858002108114, 'balanced', None, 'liblinear', 95, 'ovr', 3, False, None, 0.6004743126677025]}, {'ANN': [26]}, {'SVM': [1.6205244872553926, 'linear', 97, 0.001, 0.47224133253518186, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 86], 'KNN': [3, 'distance', 'auto', 53, 10, 'euclidean', None, None]}, {'SVM': [90.6772806327919, 'poly', 18, 0.001, 0.40367195686644597, True, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'DT': ['gini', 'best', None, 5, 5, 0.0, None, 96, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [29.320468307472748, 'rbf', 38, 0.001, 0.1960139761399078, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'RF': [137, 'entropy', None, 7, 8, 0.0, 'log2', None, 0.0, None, False, False, None, None, 68, False, None, 0.0, None]}, {'SVM': [24.445399323751506, 'linear', 70, 0.001, 0.7042850659482285, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'LR': ['l2', False, 0.0001, 56.50901591746285, True, 78.70295913262008, None, None, 'lbfgs', 77, 'ovr', 9, False, None, 0.24717973942429228]}, {'SVM': [38.615943839552926, 'poly', 54, 0.001, 0.33422522231596474, False, True, 0.001, 200, 'balanced', False, -1, 'ovr', False, 51], 'ANN': [90]}, {'KNN': [4, 'distance', 'auto', 56, 3, 'manhattan', None, None], 'DT': ['gini', 'best', None, 8, 4, 0.0, None, 34, None, 0.0, None, None, 0.0]}, {'KNN': [7, 'distance', 'auto', 65, 8, 'manhattan', None, None], 'RF': [161, 'gini', None, 6, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 95, False, 'balanced_subsample', 0.0, None]}, {'KNN': [2, 'uniform', 'auto', 38, 3, 'euclidean', None, None], 'LR': ['elasticnet', False, 0.0001, 0.531087951749798, True, 34.98982066433245, None, 19, 'liblinear', 112, 'ovr', 1, False, None, 0.41510791777699363]}, {'KNN': [9, 'uniform', 'auto', 62, 3, 'minkowski', None, None], 'ANN': [74]}, {'DT': ['gini', 'best', None, 5, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'RF': [178, 'entropy', None, 6, 2, 0.0, 'sqrt', None, 0.0, None, True, False, None, 45, 51, False, 'balanced', 0.0, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'LR': ['l1', True, 0.0001, 50.408784108164376, True, 75.49096784227251, 'balanced', None, 'saga', 96, 'ovr', 5, False, None, 0.9401969233820928]}, {'DT': ['entropy', 'best', None, 7, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'ANN': [41]}, {'RF': [109, 'gini', None, 3, 2, 0.0, 'auto', None, 0.0, None, True, False, None, 50, 9, False, 'balanced', 0.0, None], 'LR': ['l2', False, 0.0001, 11.642172089074975, True, 74.1340978383606, 'balanced', 49, 'sag', 175, 'ovr', 3, False, None, 1]}, {'RF': [128, 'entropy', None, 4, 2, 0.0, 'log2', None, 0.0, None, True, False, None, None, 35, False, None, 0.0, None], 'ANN': [95]}, {'LR': [None, True, 0.0001, 97.36593344266976, True, 40.677297188514046, 'balanced', 81, 'newton-cg', 195, 'ovr', 7, True, None, 1], 'ANN': [51]}, {'SVM': [45.00064934835307, 'rbf', 87, 0.001, 0.8483581652266433, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 50], 'KNN': [4, 'distance', 'auto', 58, 4, 'minkowski', None, None], 'DT': ['gini', 'best', None, 4, 8, 0.0, None, 8, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [14.349834674001327, 'linear', 100, 0.001, 0.6998560105273739, False, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'KNN': [1, 'uniform', 'auto', 99, 7, 'minkowski', None, None], 'RF': [168, 'gini', None, 4, 2, 0.0, None, None, 0.0, None, True, False, None, None, 77, Fals ...
# 7
# []
# gen 8
# population [{'SVM': [75.20723072692363, 'rbf', 97, 0.001, 0.8924063484233576, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, None]}, {'KNN': [3, 'distance', 'auto', 43, 8, 'euclidean', None, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0]}, {'RF': [125, 'gini', None, 3, 3, 0.0, 'log2', None, 0.0, None, False, False, None, None, 54, False, 'balanced_subsample', 0.0, None]}, {'LR': [None, True, 0.0001, 62.95029295560095, True, 40.736858002108114, 'balanced', None, 'liblinear', 95, 'ovr', 3, False, None, 0.6004743126677025]}, {'ANN': [26]}, {'SVM': [1.6205244872553926, 'linear', 97, 0.001, 0.47224133253518186, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 86], 'KNN': [3, 'distance', 'auto', 53, 10, 'euclidean', None, None]}, {'SVM': [90.6772806327919, 'poly', 18, 0.001, 0.40367195686644597, True, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'DT': ['gini', 'best', None, 5, 5, 0.0, None, 96, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [29.320468307472748, 'rbf', 38, 0.001, 0.1960139761399078, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'RF': [137, 'entropy', None, 7, 8, 0.0, 'log2', None, 0.0, None, False, False, None, None, 68, False, None, 0.0, None]}, {'SVM': [24.445399323751506, 'linear', 70, 0.001, 0.7042850659482285, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'LR': ['l2', False, 0.0001, 56.50901591746285, True, 78.70295913262008, None, None, 'lbfgs', 77, 'ovr', 9, False, None, 0.24717973942429228]}, {'SVM': [38.615943839552926, 'poly', 54, 0.001, 0.33422522231596474, False, True, 0.001, 200, 'balanced', False, -1, 'ovr', False, 51], 'ANN': [90]}, {'KNN': [4, 'distance', 'auto', 56, 3, 'manhattan', None, None], 'DT': ['gini', 'best', None, 8, 4, 0.0, None, 34, None, 0.0, None, None, 0.0]}, {'KNN': [7, 'distance', 'auto', 65, 8, 'manhattan', None, None], 'RF': [161, 'gini', None, 6, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 95, False, 'balanced_subsample', 0.0, None]}, {'KNN': [2, 'uniform', 'auto', 38, 3, 'euclidean', None, None], 'LR': ['elasticnet', False, 0.0001, 0.531087951749798, True, 34.98982066433245, None, 19, 'liblinear', 112, 'ovr', 1, False, None, 0.41510791777699363]}, {'KNN': [9, 'uniform', 'auto', 62, 3, 'minkowski', None, None], 'ANN': [74]}, {'DT': ['gini', 'best', None, 5, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'RF': [178, 'entropy', None, 6, 2, 0.0, 'sqrt', None, 0.0, None, True, False, None, 45, 51, False, 'balanced', 0.0, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'LR': ['l1', True, 0.0001, 50.408784108164376, True, 75.49096784227251, 'balanced', None, 'saga', 96, 'ovr', 5, False, None, 0.9401969233820928]}, {'DT': ['entropy', 'best', None, 7, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'ANN': [41]}, {'RF': [109, 'gini', None, 3, 2, 0.0, 'auto', None, 0.0, None, True, False, None, 50, 9, False, 'balanced', 0.0, None], 'LR': ['l2', False, 0.0001, 11.642172089074975, True, 74.1340978383606, 'balanced', 49, 'sag', 175, 'ovr', 3, False, None, 1]}, {'RF': [128, 'entropy', None, 4, 2, 0.0, 'log2', None, 0.0, None, True, False, None, None, 35, False, None, 0.0, None], 'ANN': [95]}, {'LR': [None, True, 0.0001, 97.36593344266976, True, 40.677297188514046, 'balanced', 81, 'newton-cg', 195, 'ovr', 7, True, None, 1], 'ANN': [51]}, {'SVM': [45.00064934835307, 'rbf', 87, 0.001, 0.8483581652266433, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 50], 'KNN': [4, 'distance', 'auto', 58, 4, 'minkowski', None, None], 'DT': ['gini', 'best', None, 4, 8, 0.0, None, 8, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [14.349834674001327, 'linear', 100, 0.001, 0.6998560105273739, False, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'KNN': [1, 'uniform', 'auto', 99, 7, 'minkowski', None, None], 'RF': [168, 'gini', None, 4, 2, 0.0, None, None, 0.0, None, True, False, None, None, 77, Fals ...
# 8
# []
# gen 9
# population [{'SVM': [75.20723072692363, 'rbf', 97, 0.001, 0.8924063484233576, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, None]}, {'KNN': [3, 'distance', 'auto', 43, 8, 'euclidean', None, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0]}, {'RF': [125, 'gini', None, 3, 3, 0.0, 'log2', None, 0.0, None, False, False, None, None, 54, False, 'balanced_subsample', 0.0, None]}, {'LR': [None, True, 0.0001, 62.95029295560095, True, 40.736858002108114, 'balanced', None, 'liblinear', 95, 'ovr', 3, False, None, 0.6004743126677025]}, {'ANN': [26]}, {'SVM': [1.6205244872553926, 'linear', 97, 0.001, 0.47224133253518186, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 86], 'KNN': [3, 'distance', 'auto', 53, 10, 'euclidean', None, None]}, {'SVM': [90.6772806327919, 'poly', 18, 0.001, 0.40367195686644597, True, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'DT': ['gini', 'best', None, 5, 5, 0.0, None, 96, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [29.320468307472748, 'rbf', 38, 0.001, 0.1960139761399078, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'RF': [137, 'entropy', None, 7, 8, 0.0, 'log2', None, 0.0, None, False, False, None, None, 68, False, None, 0.0, None]}, {'SVM': [24.445399323751506, 'linear', 70, 0.001, 0.7042850659482285, True, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 30], 'LR': ['l2', False, 0.0001, 56.50901591746285, True, 78.70295913262008, None, None, 'lbfgs', 77, 'ovr', 9, False, None, 0.24717973942429228]}, {'SVM': [38.615943839552926, 'poly', 54, 0.001, 0.33422522231596474, False, True, 0.001, 200, 'balanced', False, -1, 'ovr', False, 51], 'ANN': [90]}, {'KNN': [4, 'distance', 'auto', 56, 3, 'manhattan', None, None], 'DT': ['gini', 'best', None, 8, 4, 0.0, None, 34, None, 0.0, None, None, 0.0]}, {'KNN': [7, 'distance', 'auto', 65, 8, 'manhattan', None, None], 'RF': [161, 'gini', None, 6, 8, 0.0, 'sqrt', None, 0.0, None, True, False, None, None, 95, False, 'balanced_subsample', 0.0, None]}, {'KNN': [2, 'uniform', 'auto', 38, 3, 'euclidean', None, None], 'LR': ['elasticnet', False, 0.0001, 0.531087951749798, True, 34.98982066433245, None, 19, 'liblinear', 112, 'ovr', 1, False, None, 0.41510791777699363]}, {'KNN': [9, 'uniform', 'auto', 62, 3, 'minkowski', None, None], 'ANN': [74]}, {'DT': ['gini', 'best', None, 5, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'RF': [178, 'entropy', None, 6, 2, 0.0, 'sqrt', None, 0.0, None, True, False, None, 45, 51, False, 'balanced', 0.0, None]}, {'DT': ['entropy', 'best', None, 10, 8, 0.0, None, None, None, 0.0, None, 'balanced', 0.0], 'LR': ['l1', True, 0.0001, 50.408784108164376, True, 75.49096784227251, 'balanced', None, 'saga', 96, 'ovr', 5, False, None, 0.9401969233820928]}, {'DT': ['entropy', 'best', None, 7, 1, 0.0, None, None, None, 0.0, None, None, 0.0], 'ANN': [41]}, {'RF': [109, 'gini', None, 3, 2, 0.0, 'auto', None, 0.0, None, True, False, None, 50, 9, False, 'balanced', 0.0, None], 'LR': ['l2', False, 0.0001, 11.642172089074975, True, 74.1340978383606, 'balanced', 49, 'sag', 175, 'ovr', 3, False, None, 1]}, {'RF': [128, 'entropy', None, 4, 2, 0.0, 'log2', None, 0.0, None, True, False, None, None, 35, False, None, 0.0, None], 'ANN': [95]}, {'LR': [None, True, 0.0001, 97.36593344266976, True, 40.677297188514046, 'balanced', 81, 'newton-cg', 195, 'ovr', 7, True, None, 1], 'ANN': [51]}, {'SVM': [45.00064934835307, 'rbf', 87, 0.001, 0.8483581652266433, False, False, 0.001, 200, 'balanced', False, -1, 'ovr', False, 50], 'KNN': [4, 'distance', 'auto', 58, 4, 'minkowski', None, None], 'DT': ['gini', 'best', None, 4, 8, 0.0, None, 8, None, 0.0, None, 'balanced', 0.0]}, {'SVM': [14.349834674001327, 'linear', 100, 0.001, 0.6998560105273739, False, False, 0.001, 200, None, True, -1, 'ovr', False, None], 'KNN': [1, 'uniform', 'auto', 99, 7, 'minkowski', None, None], 'RF': [168, 'gini', None, 4, 2, 0.0, None, None, 0.0, None, True, False, None, None, 77, Fals ...
# 9
# []
# gen 10
# ...
# building tree 8 of 169
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    2.3s remaining:    0.0s
# building tree 9 of 169
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    2.6s remaining:    0.0s
# building tree 10 of 169
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    2.9s remaining:    0.0s
# building tree 11 of 169
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    3.2s remaining:    0.0s
# building tree 12 of 169
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    3.5s remaining:    0.0s
# building tree 13 of 169
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    3.8s remaining:    0.0s
# building tree 14 of 169
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    4.0s remaining:    0.0s
# building tree 15 of 169
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    4.4s remaining:    0.0s
# building tree 16 of 169
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    4.7s remaining:    0.0s
# building tree 17 of 169
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    5.0s remaining:    0.0s
# building tree 18 of 169
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    5.2s remaining:    0.0s
# building tree 19 of 169
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    5.5s remaining:    0.0s
# building tree 20 of 169
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    5.8s remaining:    0.0s
# building tree 21 of 169
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    6.1s remaining:    0.0s
# building tree 22 of 169
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    6.4s remaining:    0.0s
# building tree 23 of 169
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    6.7s remaining:    0.0s
# building tree 24 of 169
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    7.0s remaining:    0.0s
# building tree 25 of 169
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    7.3s remaining:    0.0s
# building tree 26 of 169
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    7.6s remaining:    0.0s
# building tree 27 of 169
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    7.9s remaining:    0.0s
# building tree 28 of 169
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    8.2s remaining:    0.0s
# building tree 29 of 169
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    8.5s remaining:    0.0s
# building tree 30 of 169
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    8.8s remaining:    0.0s
# building tree 31 of 169
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:    9.1s remaining:    0.0s
# building tree 32 of 169
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:    9.5s remaining:    0.0s
# building tree 33 of 169
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed:    9.7s remaining:    0.0s
# building tree 34 of 169
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed:   10.0s remaining:    0.0s
# building tree 35 of 169
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed:   10.3s remaining:    0.0s
# building tree 36 of 169
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:   10.6s remaining:    0.0s
# building tree 37 of 169
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed:   10.9s remaining:    0.0s
# building tree 38 of 169
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed:   11.1s remaining:    0.0s
# building tree 39 of 169
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed:   11.4s remaining:    0.0s
# building tree 40 of 169
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:   11.7s remaining:    0.0s
# building tree 41 of 169
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed:   12.0s remaining:    0.0s
# building tree 42 of 169
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:   12.3s remaining:    0.0s
# building tree 43 of 169
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed:   12.6s remaining:    0.0s
# building tree 44 of 169
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed:   12.9s remaining:    0.0s
# building tree 45 of 169
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:   13.2s remaining:    0.0s
# building tree 46 of 169
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed:   13.4s remaining:    0.0s
# building tree 47 of 169
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed:   13.7s remaining:    0.0s
# building tree 48 of 169
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed:   14.1s remaining:    0.0s
# building tree 49 of 169
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed:   14.3s remaining:    0.0s
# building tree 50 of 169
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:   14.6s remaining:    0.0s
# building tree 51 of 169
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed:   14.9s remaining:    0.0s
# building tree 52 of 169
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed:   15.2s remaining:    0.0s
# building tree 53 of 169
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed:   15.5s remaining:    0.0s
# building tree 54 of 169
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed:   15.8s remaining:    0.0s
# building tree 55 of 169
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed:   16.1s remaining:    0.0s
# building tree 56 of 169
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed:   16.4s remaining:    0.0s
# building tree 57 of 169
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed:   16.7s remaining:    0.0s
# building tree 58 of 169
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed:   17.0s remaining:    0.0s
# building tree 59 of 169
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed:   17.3s remaining:    0.0s
# building tree 60 of 169
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:   17.5s remaining:    0.0s
# building tree 61 of 169
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed:   17.8s remaining:    0.0s
# building tree 62 of 169
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed:   18.1s remaining:    0.0s
# building tree 63 of 169
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:   18.4s remaining:    0.0s
# building tree 64 of 169
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:   18.7s remaining:    0.0s
# building tree 65 of 169
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed:   19.0s remaining:    0.0s
# building tree 66 of 169
# [Parallel(n_jobs=1)]: Done  66 out of  66 | elapsed:   19.3s remaining:    0.0s
# building tree 67 of 169
# [Parallel(n_jobs=1)]: Done  67 out of  67 | elapsed:   19.6s remaining:    0.0s
# building tree 68 of 169
# [Parallel(n_jobs=1)]: Done  68 out of  68 | elapsed:   19.9s remaining:    0.0s
# building tree 69 of 169
# [Parallel(n_jobs=1)]: Done  69 out of  69 | elapsed:   20.2s remaining:    0.0s
# building tree 70 of 169
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed:   20.5s remaining:    0.0s
# building tree 71 of 169
# [Parallel(n_jobs=1)]: Done  71 out of  71 | elapsed:   20.7s remaining:    0.0s
# building tree 72 of 169
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed:   21.1s remaining:    0.0s
# building tree 73 of 169
# [Parallel(n_jobs=1)]: Done  73 out of  73 | elapsed:   21.4s remaining:    0.0s
# building tree 74 of 169
# [Parallel(n_jobs=1)]: Done  74 out of  74 | elapsed:   21.7s remaining:    0.0s
# building tree 75 of 169
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:   22.0s remaining:    0.0s
# building tree 76 of 169
# [Parallel(n_jobs=1)]: Done  76 out of  76 | elapsed:   22.3s remaining:    0.0s
# building tree 77 of 169
# [Parallel(n_jobs=1)]: Done  77 out of  77 | elapsed:   22.6s remaining:    0.0s
# building tree 78 of 169
# [Parallel(n_jobs=1)]: Done  78 out of  78 | elapsed:   22.9s remaining:    0.0s
# building tree 79 of 169
# [Parallel(n_jobs=1)]: Done  79 out of  79 | elapsed:   23.1s remaining:    0.0s
# building tree 80 of 169
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:   23.5s remaining:    0.0s
# building tree 81 of 169
# [Parallel(n_jobs=1)]: Done  81 out of  81 | elapsed:   23.8s remaining:    0.0s
# building tree 82 of 169
# [Parallel(n_jobs=1)]: Done  82 out of  82 | elapsed:   24.1s remaining:    0.0s
# building tree 83 of 169
# [Parallel(n_jobs=1)]: Done  83 out of  83 | elapsed:   24.4s remaining:    0.0s
# building tree 84 of 169
# [Parallel(n_jobs=1)]: Done  84 out of  84 | elapsed:   24.7s remaining:    0.0s
# building tree 85 of 169
# [Parallel(n_jobs=1)]: Done  85 out of  85 | elapsed:   24.9s remaining:    0.0s
# building tree 86 of 169
# [Parallel(n_jobs=1)]: Done  86 out of  86 | elapsed:   25.2s remaining:    0.0s
# building tree 87 of 169
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:   25.5s remaining:    0.0s
# building tree 88 of 169
# [Parallel(n_jobs=1)]: Done  88 out of  88 | elapsed:   25.8s remaining:    0.0s
# building tree 89 of 169
# [Parallel(n_jobs=1)]: Done  89 out of  89 | elapsed:   26.1s remaining:    0.0s
# building tree 90 of 169
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed:   26.4s remaining:    0.0s
# building tree 91 of 169
# [Parallel(n_jobs=1)]: Done  91 out of  91 | elapsed:   26.8s remaining:    0.0s
# building tree 92 of 169
# building tree 93 of 169
# building tree 94 of 169
# building tree 95 of 169
# building tree 96 of 169
# building tree 97 of 169
# building tree 98 of 169
# building tree 99 of 169
# building tree 100 of 169
# building tree 101 of 169
# building tree 102 of 169
# building tree 103 of 169
# building tree 104 of 169
# building tree 105 of 169
# building tree 106 of 169
# building tree 107 of 169
# building tree 108 of 169
# building tree 109 of 169
# building tree 110 of 169
# building tree 111 of 169
# building tree 112 of 169
# building tree 113 of 169
# building tree 114 of 169
# building tree 115 of 169
# building tree 116 of 169
# building tree 117 of 169
# building tree 118 of 169
# building tree 119 of 169
# building tree 120 of 169
# building tree 121 of 169
# building tree 122 of 169
# building tree 123 of 169
# building tree 124 of 169
# building tree 125 of 169
# building tree 126 of 169
# building tree 127 of 169
# building tree 128 of 169
# building tree 129 of 169
# building tree 130 of 169
# building tree 131 of 169
# building tree 132 of 169
# building tree 133 of 169
# building tree 134 of 169
# building tree 135 of 169
# building tree 136 of 169
# building tree 137 of 169
# building tree 138 of 169
# building tree 139 of 169
# building tree 140 of 169
# building tree 141 of 169
# building tree 142 of 169
# building tree 143 of 169
# building tree 144 of 169
# building tree 145 of 169
# building tree 146 of 169
# building tree 147 of 169
# building tree 148 of 169
# building tree 149 of 169
# building tree 150 of 169
# building tree 151 of 169
# building tree 152 of 169
# building tree 153 of 169
# building tree 154 of 169
# building tree 155 of 169
# building tree 156 of 169
# building tree 157 of 169
# building tree 158 of 169
# building tree 159 of 169
# building tree 160 of 169
# building tree 161 of 169
# building tree 162 of 169
# building tree 163 of 169
# building tree 164 of 169
# building tree 165 of 169
# building tree 166 of 169
# building tree 167 of 169
# building tree 168 of 169
# building tree 169 of 169
# [Parallel(n_jobs=1)]: Done 169 out of 169 | elapsed:   50.6s finished
# [LibSVM]
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# building tree 1 of 149
# building tree 2 of 149
# building tree 3 of 149
# building tree 4 of 149
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.4s remaining:    0.0s
# building tree 5 of 149
# building tree 6 of 149
# building tree 7 of 149
# building tree 8 of 149
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    0.6s remaining:    0.0s
# building tree 9 of 149
# building tree 10 of 149
# building tree 11 of 149
# building tree 12 of 149
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.9s remaining:    0.0s
# building tree 13 of 149
# building tree 14 of 149
# building tree 15 of 149
# building tree 16 of 149
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    1.0s remaining:    0.0s
# building tree 17 of 149
# building tree 18 of 149
# building tree 19 of 149
# building tree 20 of 149
# building tree 21 of 149
# building tree 22 of 149
# building tree 23 of 149
# building tree 24 of 149
# building tree 25 of 149
# building tree 26 of 149
# building tree 27 of 149
# building tree 28 of 149
# building tree 29 of 149
# building tree 30 of 149
# building tree 31 of 149
# building tree 32 of 149
# building tree 33 of 149
# building tree 34 of 149
# building tree 35 of 149
# building tree 36 of 149
# building tree 37 of 149
# building tree 38 of 149
# building tree 39 of 149
# building tree 40 of 149
# building tree 41 of 149
# building tree 42 of 149
# building tree 43 of 149
# building tree 44 of 149
# building tree 45 of 149
# building tree 46 of 149
# building tree 47 of 149
# building tree 48 of 149
# building tree 49 of 149
# building tree 50 of 149
# building tree 51 of 149
# building tree 52 of 149
# building tree 53 of 149
# building tree 54 of 149
# building tree 55 of 149
# building tree 56 of 149
# building tree 57 of 149
# building tree 58 of 149
# building tree 59 of 149
# building tree 60 of 149
# building tree 61 of 149
# building tree 62 of 149
# building tree 63 of 149
# building tree 64 of 149
# building tree 65 of 149
# building tree 66 of 149
# building tree 67 of 149
# building tree 68 of 149
# building tree 69 of 149
# building tree 70 of 149
# building tree 71 of 149
# building tree 72 of 149
# building tree 73 of 149
# building tree 74 of 149
# building tree 75 of 149
# building tree 76 of 149
# building tree 77 of 149
# building tree 78 of 149
# building tree 79 of 149
# building tree 80 of 149
# building tree 81 of 149
# building tree 82 of 149
# building tree 83 of 149
# building tree 84 of 149
# building tree 85 of 149
# building tree 86 of 149
# building tree 87 of 149
# building tree 88 of 149
# building tree 89 of 149
# building tree 90 of 149
# building tree 91 of 149
# building tree 92 of 149
# building tree 93 of 149
# building tree 94 of 149
# building tree 95 of 149
# building tree 96 of 149
# building tree 97 of 149
# building tree 98 of 149
# building tree 99 of 149
# building tree 100 of 149
# building tree 101 of 149
# building tree 102 of 149
# building tree 103 of 149
# building tree 104 of 149
# building tree 105 of 149
# building tree 106 of 149
# building tree 107 of 149
# building tree 108 of 149
# building tree 109 of 149
# building tree 110 of 149
# building tree 111 of 149
# building tree 112 of 149
# building tree 113 of 149
# building tree 114 of 149
# building tree 115 of 149
# building tree 116 of 149
# building tree 117 of 149
# building tree 118 of 149
# building tree 119 of 149
# building tree 120 of 149
# building tree 121 of 149
# building tree 122 of 149
# building tree 123 of 149
# building tree 124 of 149
# building tree 125 of 149
# building tree 126 of 149
# building tree 127 of 149
# building tree 128 of 149
# building tree 129 of 149
# building tree 130 of 149
# building tree 131 of 149
# building tree 132 of 149
# building tree 133 of 149
# building tree 134 of 149
# building tree 135 of 149
# building tree 136 of 149
# building tree 137 of 149
# building tree 138 of 149
# building tree 139 of 149
# building tree 140 of 149
# building tree 141 of 149
# building tree 142 of 149
# building tree 143 of 149
# building tree 144 of 149
# building tree 145 of 149
# building tree 146 of 149
# building tree 147 of 149
# building tree 148 of 149
# building tree 149 of 149
# [LibSVM]
# [Parallel(n_jobs=1)]: Done 149 out of 149 | elapsed:    8.5s finished

# %% [markdown]
# best_fits,models=GA()
# print(best_fits)

# %%
chromosome0=best_fits['0']
chromosome99=best_fits['99']

# %% [markdown]
# #validate on unseen data

# %%
print("equinox")
data = arff.loadarff('Equinox-3.4-OSA.arff')
data_value = pd.DataFrame(data[0])
PROMISE_data = data_value[:, 0:60]
PROMISE_target = data_value[:,60]
PROMISE_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(PROMISE_data)
X=PROMISE_data_minmax_scalled
y=PROMISE_target

# %%
y_pred0=model0.predict(X)
cm=confusion_matrix(y, y_pred0)
TN, FP, FN, TP = cm.ravel()
print( cm)
accuracy= (TP + TN)/(TP + TN + FP + FN)
print("accuracy:",accuracy)
mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
print("mcc:",mcc)
precision =(TP/(TP+FP))
recall= (TP/(TP+FN))
f1_score= 2 *(precision*recall)/(precision+recall)
print("f1_score:",f1_score)

# %%
y_pred99=model99.predict(X)
cm=confusion_matrix(y, y_pred99)
TN, FP, FN, TP = cm.ravel()
print( cm)
accuracy= (TP + TN)/(TP + TN + FP + FN)
print("accuracy:",accuracy)
mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
print("mcc:",mcc)
precision =(TP/(TP+FP))
recall= (TP/(TP+FN))
f1_score= 2 *(precision*recall)/(precision+recall)
print("f1_score:",f1_score)

# %%
print("Mylyn")
data = arff.loadarff('Mylyn-3.1-OSA.arff')
data_value = pd.DataFrame(data[0])
PROMISE_data = data_value[:, 0:60]
PROMISE_target = data_value[:,60]
PROMISE_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(PROMISE_data)
X=PROMISE_data_minmax_scalled
y=PROMISE_target
y_pred0=model0.predict(X)
cm=confusion_matrix(y, y_pred0)
TN, FP, FN, TP = cm.ravel()
print( cm)
accuracy= (TP + TN)/(TP + TN + FP + FN)
print("accuracy:",accuracy)
mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
print("mcc:",mcc)
precision =(TP/(TP+FP))
recall= (TP/(TP+FN))
f1_score= 2 *(precision*recall)/(precision+recall)
print("f1_score:",f1_score)

# %%
y_pred99=model99.predict(X)
cm=confusion_matrix(y, y_pred99)
TN, FP, FN, TP = cm.ravel()
print( cm)
accuracy= (TP + TN)/(TP + TN + FP + FN)
print("accuracy:",accuracy)
mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
print("mcc:",mcc)
precision =(TP/(TP+FP))
recall= (TP/(TP+FN))
f1_score= 2 *(precision*recall)/(precision+recall)
print("f1_score:",f1_score)

# %%
print("Eclipse_JDT_Core")

data = arff.loadarff('Eclipse_JDT_Core-3.4-OSA.arff')
data_value = pd.DataFrame(data[0])
PROMISE_data = data_value[:, 0:60]
PROMISE_target = data_value[:,60]
PROMISE_data_minmax_scalled = preprocessing.MinMaxScaler().fit_transform(PROMISE_data)
X=PROMISE_data_minmax_scalled
y=PROMISE_target
y_pred0=model0.predict(X)
cm=confusion_matrix(y, y_pred0)
TN, FP, FN, TP = cm.ravel()
print( cm)
accuracy= (TP + TN)/(TP + TN + FP + FN)
print("accuracy:",accuracy)
mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
print("mcc:",mcc)
precision =(TP/(TP+FP))
recall= (TP/(TP+FN))
f1_score= 2 *(precision*recall)/(precision+recall)
print("f1_score:",f1_score)

# %%
y_pred99=model99.predict(X)
cm=confusion_matrix(y, y_pred99)
TN, FP, FN, TP = cm.ravel()
print( cm)
accuracy= (TP + TN)/(TP + TN + FP + FN)
print("accuracy:",accuracy)
mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
print("mcc:",mcc)
precision =(TP/(TP+FP))
recall= (TP/(TP+FN))
f1_score= 2 *(precision*recall)/(precision+recall)
print("f1_score:",f1_score)

# %%
print("all")
BugPrediction_target,BugPrediction_data_normalized,BugPrediction_data_minmax_scalled,BugPrediction_data_standardized=BugPredictionDatasetPreprocess()

# %%
X=BugPrediction_data_minmax_scalled
y=BugPrediction_target
y_pred0=model0.predict(X)
cm=confusion_matrix(y, y_pred0)
TN, FP, FN, TP = cm.ravel()
print( cm)
accuracy= (TP + TN)/(TP + TN + FP + FN)
print("accuracy:",accuracy)
mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
print("mcc:",mcc)
precision =(TP/(TP+FP))
recall= (TP/(TP+FN))
f1_score= 2 *(precision*recall)/(precision+recall)
print("f1_score:",f1_score)

# %%
y_pred99=model99.predict(X)
cm=confusion_matrix(y, y_pred99)
TN, FP, FN, TP = cm.ravel()
print( cm)
accuracy= (TP + TN)/(TP + TN + FP + FN)
print("accuracy:",accuracy)
mcc= ((TP *TN) - (FP *FN))/(sqrt((TP +FP)*(TP +FN)*(TN +FP)*(TN +FN)))
print("mcc:",mcc)
precision =(TP/(TP+FP))
recall= (TP/(TP+FN))
f1_score= 2 *(precision*recall)/(precision+recall)
print("f1_score:",f1_score)
